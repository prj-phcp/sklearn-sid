# %% [markdown]
# # SYSID - Trabalho (ML - MISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import copy
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %%
#import sys
#sys.path.insert(0, os.path.abspath('..'))
from sklearn_sid.regressors.sklearn import SYSIDRegressor

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# /mnt/d/OneDrive/Mestrado/gits/sklearn-sid/Volve-Dataset/data/volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        #'AVG_DOWNHOLE_PRESSURE',
        #'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        #'AVG_WHT_P',
        #'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        #'BORE_OIL_VOL',
        'BORE_LIQ_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 1) (718, 1)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X_tr = X_scale.fit_transform(X1_tr)
X_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %%
basis_function = Polynomial(degree=1)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)

models.append(('ARMAX', model))

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %%
basis_function = Fourier(degree=2)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)
models.append(('NARMAX', model))

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    #{
    #    'activation'            : ['relu', 'logistic', 'tanh'],
    #    'early_stopping'        : [True, False],
    #    'alpha'                 : stats.loguniform(1e-9, 1e0),
    #    'hidden_layer_sizes'    : [(100,), (100, 100,), (100, 100, 100,), (100, 100, 100, 100,)],
    #    'max_iter'              : [10000],#stats.randint(200,10000),
    #    'batch_size'            : [32, 64, 128, 256, 'auto'],
    #    'solver'                : ['adam'], #'lbfgs'],
    #    'tol'                   : stats.loguniform(1e-7, 1e-1),
    #},
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    sidmodel = SYSIDRegressor(
        nX=6, ny=6,
        estimator=rdmsearch, 
        preprocessor=MinMaxScaler(),
        add_static=True
        )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
n_models = len(models)

results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

# %%
for model in models:
    print(model[0])
# Out:
# ARMAX
# NARMAX
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'SISO-Static.W1'
#Loop principal, iterando sobre as listas
for model in models[2:]:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1))
        r2_te_osa = r2_score(y_te, sidmodel.predict(X1_te, y=y_te, steps_ahead=1))
        try:
            r2_tr_fs = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr))
            r2_te_fs = r2_score(y_te, sidmodel.predict(X1_te, y=y_te))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = copy.deepcopy(sidmodel)
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(copy.deepcopy(sidmodel))
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr, label='Train')
    hist = ax[0].plot(best_model.predict(X1_tr, y=y_tr), label='Model') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,:], label='Test')
    hist = ax[1].plot(best_model.predict(X1_te, y=y_te)[n_train:,:], label='Model')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs', 'test_runs',f'{prefix}_{model_name}.pdf'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(best_model)
    try:
        results['PARS'].append(best_model.estimator.best_params_)
    except Exception:
        results['PARS'].append(best_model.final_model)
# Out:
# Starting evaluation of model: LinReg
#     Trying order: 2
#         R2 score OSA (Train): 0.8625305946781997
#         R2 score OSA (Test): 0.8654424539061061
#         R2 score FS (Train): 0.5842541570896504
#         R2 score FS (Test): 0.6121862991724882
#     Trying order: 3
#         R2 score OSA (Train): 0.8717237941477236
#         R2 score OSA (Test): 0.8665503789777118
#         R2 score FS (Train): 0.4446772176889018
#         R2 score FS (Test): 0.4421812683362598
#     Trying order: 4
#         R2 score OSA (Train): 0.8733490210630784
#         R2 score OSA (Test): 0.8663547584725474
#         R2 score FS (Train): 0.5376107184601056
#         R2 score FS (Test): 0.5398993708463761
#     Trying order: 5
#         R2 score OSA (Train): 0.8747993511780573
#         R2 score OSA (Test): 0.8677493769823339
#         R2 score FS (Train): 0.45566133093876227
#         R2 score FS (Test): 0.3982231844010502
#     Trying order: 6
#         R2 score OSA (Train): 0.8771584132570054
#         R2 score OSA (Test): 0.869025884698277
#         R2 score FS (Train): 0.5977836604789519
#         R2 score FS (Test): 0.6059905400174941
#     Trying order: 7
#         R2 score OSA (Train): 0.8772086278078781
#         R2 score OSA (Test): 0.8692496953519796
#         R2 score FS (Train): 0.6020294068867065
#         R2 score FS (Test): 0.6105230036988256
#     Trying order: 8
#         R2 score OSA (Train): 0.8776986583729364
#         R2 score OSA (Test): 0.8692559373864275
#         R2 score FS (Train): 0.61701138729722
#         R2 score FS (Test): 0.6252683202583202
#     Trying order: 9
#         R2 score OSA (Train): 0.8779180404562998
#         R2 score OSA (Test): 0.8694653854378874
#         R2 score FS (Train): 0.6281169965628242
#         R2 score FS (Test): 0.6387708596832165
#     Trying order: 10
#         R2 score OSA (Train): 0.8789895192898421
#         R2 score OSA (Test): 0.8703236764689883
#         R2 score FS (Train): 0.6381568698792579
#         R2 score FS (Test): 0.6453814250951659
#     Trying order: 11
#         R2 score OSA (Train): 0.8794370077040835
#         R2 score OSA (Test): 0.8705495515942947
#         R2 score FS (Train): 0.6397449125555996
#         R2 score FS (Test): 0.6429382164530062
#     Trying order: 12
#         R2 score OSA (Train): 0.8816050307828628
#         R2 score OSA (Test): 0.8710122004653122
#         R2 score FS (Train): 0.66037005974284
#         R2 score FS (Test): 0.6704597366001359
#     Trying order: 13
#         R2 score OSA (Train): 0.8831716153679917
#         R2 score OSA (Test): 0.8718160282408735
#         R2 score FS (Train): 0.6726517498639828
#         R2 score FS (Test): 0.6822882515504731
#     Trying order: 14
#         R2 score OSA (Train): 0.883571040848949
#         R2 score OSA (Test): 0.8718499898877141
#         R2 score FS (Train): 0.6752835430445827
#         R2 score FS (Test): 0.6835264700172803
#     Trying order: 15
#         R2 score OSA (Train): 0.8842275689299055
#         R2 score OSA (Test): 0.8726939921319549
#         R2 score FS (Train): 0.6577078010257802
#         R2 score FS (Test): 0.6514896190370998
#     Trying order: 16
#         R2 score OSA (Train): 0.8859598838174403
#         R2 score OSA (Test): 0.8740583524729015
#         R2 score FS (Train): 0.656784124933466
#         R2 score FS (Test): 0.6109702040283277
#     Trying order: 17
#         R2 score OSA (Train): 0.8866670496494817
#         R2 score OSA (Test): 0.8737815741626106
#         R2 score FS (Train): 0.6796382400239569
#         R2 score FS (Test): 0.6838971416912598
#     Trying order: 18
#         R2 score OSA (Train): 0.8873934522521415
#         R2 score OSA (Test): 0.8740536143038282
#         R2 score FS (Train): 0.6834754211369514
#         R2 score FS (Test): 0.6882798804787629
#     Trying order: 19
#         R2 score OSA (Train): 0.8874229063370486
#         R2 score OSA (Test): 0.8740018335723229
#         R2 score FS (Train): 0.6821561302947519
#         R2 score FS (Test): 0.6853463488680609
#     Trying order: 20
#         R2 score OSA (Train): 0.8878750365205947
#         R2 score OSA (Test): 0.8744318887522605
#         R2 score FS (Train): 0.6840164276824063
#         R2 score FS (Test): 0.6866840347780392
#
#     Tempo de execução: 0:00:09.427995
#     Best Order: 20
#     R2 score OSA (Train): 0.8878750365205947
#     R2 score OSA (Test): 0.8744318887522605
#     R2 score FS (Train): 0.6840164276824063
#     R2 score FS (Test): 0.6866840347780392
#
# Starting evaluation of model: PolyReg
#     Trying order: 2
#         R2 score OSA (Train): 0.8787346564501647
#         R2 score OSA (Test): 0.874570104554832
#         R2 score FS (Train): 0.638595741752084
#         R2 score FS (Test): 0.6581301162415828
#     Trying order: 3
#         R2 score OSA (Train): 0.8821729968740213
#         R2 score OSA (Test): 0.8773872062315613
#         R2 score FS (Train): 0.6273252490046239
#         R2 score FS (Test): 0.648066538107426
#     Trying order: 4
#         R2 score OSA (Train): 0.8822734996330925
#         R2 score OSA (Test): 0.8774498907042768
#         R2 score FS (Train): 0.6305144861034158
#         R2 score FS (Test): 0.6501917904177573
#     Trying order: 5
#         R2 score OSA (Train): 0.8830804100914664
#         R2 score OSA (Test): 0.8779501976668148
#         R2 score FS (Train): 0.6325552557038121
#         R2 score FS (Test): 0.6518301678001905
#     Trying order: 6
#         R2 score OSA (Train): 0.8850421764773357
#         R2 score OSA (Test): 0.8792129521428557
#         R2 score FS (Train): 0.6350677975099575
#         R2 score FS (Test): 0.6531156006124873
#     Trying order: 7
#         R2 score OSA (Train): 0.885051242888101
#         R2 score OSA (Test): 0.8792104643414514
#         R2 score FS (Train): 0.6351329344851808
#         R2 score FS (Test): 0.6531761077493279
#     Trying order: 8
#         R2 score OSA (Train): 0.8850711425935585
#         R2 score OSA (Test): 0.8792308442128286
#         R2 score FS (Train): 0.6349131011661987
#         R2 score FS (Test): 0.6529890077050996
#     Trying order: 9
#         R2 score OSA (Train): 0.8850738810731524
#         R2 score OSA (Test): 0.8792313649522354
#         R2 score FS (Train): 0.6348979475652379
#         R2 score FS (Test): 0.6529838876447425
#     Trying order: 10
#         R2 score OSA (Train): 0.8850798976478504
#         R2 score OSA (Test): 0.8792340873745113
#         R2 score FS (Train): 0.6349447128018917
#         R2 score FS (Test): 0.6530148701932127
#     Trying order: 11
#         R2 score OSA (Train): 0.8851079551643531
#         R2 score OSA (Test): 0.8792500962096281
#         R2 score FS (Train): 0.6350548873517627
#         R2 score FS (Test): 0.6530821017598447
#     Trying order: 12
#         R2 score OSA (Train): 0.8851198017638899
#         R2 score OSA (Test): 0.8792561795876741
#         R2 score FS (Train): 0.6351355277404871
#         R2 score FS (Test): 0.6531316691705934
#     Trying order: 13
#         R2 score OSA (Train): 0.885173175302834
#         R2 score OSA (Test): 0.8792890150696103
#         R2 score FS (Train): 0.6353299976768878
#         R2 score FS (Test): 0.6532475458197822
#     Trying order: 14
#         R2 score OSA (Train): 0.8852588432690186
#         R2 score OSA (Test): 0.8793416553710582
#         R2 score FS (Train): 0.6355087269044231
#         R2 score FS (Test): 0.6533618373242649
#     Trying order: 15
#         R2 score OSA (Train): 0.8852702851096701
#         R2 score OSA (Test): 0.8793484419875967
#         R2 score FS (Train): 0.6355118309699572
#         R2 score FS (Test): 0.6533640258575822
#     Trying order: 16
#         R2 score OSA (Train): 0.8852903820903342
#         R2 score OSA (Test): 0.879360194972126
#         R2 score FS (Train): 0.6355538091646069
#         R2 score FS (Test): 0.6533925290883393
#     Trying order: 17
#         R2 score OSA (Train): 0.8852933141009268
#         R2 score OSA (Test): 0.8793611718488761
#         R2 score FS (Train): 0.6355377496419088
#         R2 score FS (Test): 0.653383845173285
#     Trying order: 18
#         R2 score OSA (Train): 0.8853025911132647
#         R2 score OSA (Test): 0.8793658999569812
#         R2 score FS (Train): 0.6355821947457447
#         R2 score FS (Test): 0.6534117847818843
#     Trying order: 19
#         R2 score OSA (Train): 0.885486223466328
#         R2 score OSA (Test): 0.8794785901110029
#         R2 score FS (Train): 0.6361665924386084
#         R2 score FS (Test): 0.6537850502677254
#     Trying order: 20
#         R2 score OSA (Train): 0.8855994094947827
#         R2 score OSA (Test): 0.87954844676523
#         R2 score FS (Train): 0.6364287772825148
#         R2 score FS (Test): 0.6539552632407142
#
#     Tempo de execução: 0:00:24.439886
#     Best Order: 2
#     R2 score OSA (Train): 0.8787346564501647
#     R2 score OSA (Test): 0.874570104554832
#     R2 score FS (Train): 0.638595741752084
#     R2 score FS (Test): 0.6581301162415828
#
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.8636312763485924
#         R2 score OSA (Test): 0.8614151202092897
#         R2 score FS (Train): 0.5809215499368188
#         R2 score FS (Test): 0.6058207247216593
#     Trying order: 3
#         R2 score OSA (Train): 0.8726903565460742
#         R2 score OSA (Test): 0.8669971483170477
#         R2 score FS (Train): 0.5470230907018907
#         R2 score FS (Test): 0.5785475183560487
#     Trying order: 4
#         R2 score OSA (Train): 0.8795294849626883
#         R2 score OSA (Test): 0.8699300634073489
#         R2 score FS (Train): 0.5835480686528418
#         R2 score FS (Test): 0.6056886231694308
#     Trying order: 5
#         R2 score OSA (Train): 0.8814510491263718
#         R2 score OSA (Test): 0.8720822266901237
#         R2 score FS (Train): 0.5906985081454021
#         R2 score FS (Test): 0.6183981228024098
#     Trying order: 6
#         R2 score OSA (Train): 0.8891339049248101
#         R2 score OSA (Test): 0.8754381956075239
#         R2 score FS (Train): 0.649187249391676
#         R2 score FS (Test): 0.6726467900168285
#     Trying order: 7
#         R2 score OSA (Train): 0.8882544232656446
#         R2 score OSA (Test): 0.8751229111664613
#         R2 score FS (Train): 0.6573609860875028
#         R2 score FS (Test): 0.6786139916068528
#     Trying order: 8
#         R2 score OSA (Train): 0.8887645566553926
#         R2 score OSA (Test): 0.875932115011464
#         R2 score FS (Train): 0.6583143548003705
#         R2 score FS (Test): 0.6772799220490616
#     Trying order: 9
#         R2 score OSA (Train): 0.8876496163299208
#         R2 score OSA (Test): 0.8742365181082196
#         R2 score FS (Train): 0.6650518527191622
#         R2 score FS (Test): 0.6836047943185862
#     Trying order: 10
#         R2 score OSA (Train): 0.8927564651957707
#         R2 score OSA (Test): 0.8784392527257042
#         R2 score FS (Train): 0.685667232485784
#         R2 score FS (Test): 0.6989147325973437
#     Trying order: 11
#         R2 score OSA (Train): 0.8925630481188417
#         R2 score OSA (Test): 0.8775292623238246
#         R2 score FS (Train): 0.7011050052947086
#         R2 score FS (Test): 0.7126916939126537
#     Trying order: 12
#         R2 score OSA (Train): 0.8918799617372494
#         R2 score OSA (Test): 0.8747177754305719
#         R2 score FS (Train): 0.7059850094533755
#         R2 score FS (Test): 0.714511049278301
#     Trying order: 13
#         R2 score OSA (Train): 0.8938329274444545
#         R2 score OSA (Test): 0.8741208981204203
#         R2 score FS (Train): 0.7070505177572365
#         R2 score FS (Test): 0.715106049742209
#     Trying order: 14
#         R2 score OSA (Train): 0.896885457113572
#         R2 score OSA (Test): 0.8772329116958244
#         R2 score FS (Train): 0.711221726682449
#         R2 score FS (Test): 0.7198974175984463
#     Trying order: 15
#         R2 score OSA (Train): 0.898572507430282
#         R2 score OSA (Test): 0.8779542125720319
#         R2 score FS (Train): 0.7176563989155698
#         R2 score FS (Test): 0.7251047777578788
#     Trying order: 16
#         R2 score OSA (Train): 0.8990186922306584
#         R2 score OSA (Test): 0.8786966416062468
#         R2 score FS (Train): 0.7082602148322144
#         R2 score FS (Test): 0.7161172761263546
#     Trying order: 17
#         R2 score OSA (Train): 0.9009587472579041
#         R2 score OSA (Test): 0.8802950260925437
#         R2 score FS (Train): 0.7147912156066893
#         R2 score FS (Test): 0.724927778601715
#     Trying order: 18
#         R2 score OSA (Train): 0.9016875990104668
#         R2 score OSA (Test): 0.8806748257532593
#         R2 score FS (Train): 0.716079409483093
#         R2 score FS (Test): 0.7258929205258067
#     Trying order: 19
#         R2 score OSA (Train): 0.9004249476985946
#         R2 score OSA (Test): 0.8796115090745745
#         R2 score FS (Train): 0.7141163575594924
#         R2 score FS (Test): 0.7242643246807274
#     Trying order: 20
#         R2 score OSA (Train): 0.902947197951675
#         R2 score OSA (Test): 0.88011425813167
#         R2 score FS (Train): 0.718892908705357
#         R2 score FS (Test): 0.726458522203368
#
#     Tempo de execução: 0:10:16.056719
#     Best Order: 20
#     R2 score OSA (Train): 0.902947197951675
#     R2 score OSA (Test): 0.88011425813167
#     R2 score FS (Train): 0.718892908705357
#     R2 score FS (Test): 0.726458522203368
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 0.9276441636770317
#         R2 score OSA (Test): 0.8952515020100715
#         R2 score FS (Train): 0.6490365221881554
#         R2 score FS (Test): 0.6667181619639333
#     Trying order: 3
#         R2 score OSA (Train): 0.9227422728218596
#         R2 score OSA (Test): 0.8923356110506844
#         R2 score FS (Train): 0.6276839966942573
#         R2 score FS (Test): 0.6330208927327997
#     Trying order: 4
#         R2 score OSA (Train): 0.9162526938508947
#         R2 score OSA (Test): 0.8877965790646404
#         R2 score FS (Train): 0.6364607065217425
#         R2 score FS (Test): 0.6318503747639108
#     Trying order: 5
#         R2 score OSA (Train): 1.0
#         R2 score OSA (Test): 0.9256618668077566
#         R2 score FS (Train): 0.6845751579086241
#         R2 score FS (Test): 0.7028353168362484
#     Trying order: 6
#         R2 score OSA (Train): 1.0
#         R2 score OSA (Test): 0.9179344013102669
#         R2 score FS (Train): 0.679993380039059
#         R2 score FS (Test): 0.6942710348503092
#     Trying order: 7
#         R2 score OSA (Train): 1.0
#         R2 score OSA (Test): 0.9168722330112608
#         R2 score FS (Train): 0.6828129126664975
#         R2 score FS (Test): 0.6954124834840132
#     Trying order: 8
#         R2 score OSA (Train): 0.9999999999999841
#         R2 score OSA (Test): 0.915726571490068
#         R2 score FS (Train): 0.6789142906282803
#         R2 score FS (Test): 0.688572054007413
#     Trying order: 9
#         R2 score OSA (Train): 0.9999999999999872
#         R2 score OSA (Test): 0.9130408818791877
#         R2 score FS (Train): 0.6634989991333221
#         R2 score FS (Test): 0.6646753056531229
#     Trying order: 10
#         R2 score OSA (Train): 0.9999999999999923
#         R2 score OSA (Test): 0.9190128235960893
#         R2 score FS (Train): 0.6551496976703104
#         R2 score FS (Test): 0.6605950424333604
#     Trying order: 11
#         R2 score OSA (Train): 0.9999999999999963
#         R2 score OSA (Test): 0.9213893228738834
#         R2 score FS (Train): 0.6630678680512843
#         R2 score FS (Test): 0.6680169257600279
#     Trying order: 12
#         R2 score OSA (Train): 0.9999999999999922
#         R2 score OSA (Test): 0.9256690841012938
#         R2 score FS (Train): 0.6623140296652571
#         R2 score FS (Test): 0.6630808861988364
#     Trying order: 13
#         R2 score OSA (Train): 0.9999999999999933
#         R2 score OSA (Test): 0.9220283308816282
#         R2 score FS (Train): 0.6633972747436774
#         R2 score FS (Test): 0.6642537630891185
#     Trying order: 14
#         R2 score OSA (Train): 0.9999999999999929
#         R2 score OSA (Test): 0.9241329407138641
#         R2 score FS (Train): 0.6755780822858432
#         R2 score FS (Test): 0.6757399708464694
#     Trying order: 15
#         R2 score OSA (Train): 0.9999999999999976
#         R2 score OSA (Test): 0.9109440871303341
#         R2 score FS (Train): 0.6413801782114573
#         R2 score FS (Test): 0.6523017180917892
#     Trying order: 16
#         R2 score OSA (Train): 0.9999999999999949
#         R2 score OSA (Test): 0.9198013563063538
#         R2 score FS (Train): 0.6765795457992457
#         R2 score FS (Test): 0.6681772485807573
#     Trying order: 17
#         R2 score OSA (Train): 0.9999999999999942
#         R2 score OSA (Test): 0.9156795955523704
#         R2 score FS (Train): 0.6596621944220604
#         R2 score FS (Test): 0.6610948236891626
#     Trying order: 18
#         R2 score OSA (Train): 0.9999999999999968
#         R2 score OSA (Test): 0.9283029279476477
#         R2 score FS (Train): 0.6296685031627441
#         R2 score FS (Test): 0.6525870273087155
#     Trying order: 19
#         R2 score OSA (Train): 0.9999999999999977
#         R2 score OSA (Test): 0.9206993998385082
#         R2 score FS (Train): 0.6434314011102091
#         R2 score FS (Test): 0.6591688381006366
#     Trying order: 20
#         R2 score OSA (Train): 0.9999999999999966
#         R2 score OSA (Test): 0.9231227443903446
#         R2 score FS (Train): 0.6338915505632443
#         R2 score FS (Test): 0.6583738977575329
#
#     Tempo de execução: 0:02:04.710127
#     Best Order: 5
#     R2 score OSA (Train): 1.0
#     R2 score OSA (Test): 0.9256618668077566
#     R2 score FS (Train): 0.6845751579086241
#     R2 score FS (Test): 0.7028353168362484
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.9063573806666044
#         R2 score OSA (Test): 0.8855626965059356
#         R2 score FS (Train): 0.6530403556946152
#         R2 score FS (Test): 0.6830314735729864
#     Trying order: 3
#         R2 score OSA (Train): 0.9138811148126771
#         R2 score OSA (Test): 0.8876730211094171
#         R2 score FS (Train): 0.5883163056287739
#         R2 score FS (Test): 0.6322361947724333
#     Trying order: 4
#         R2 score OSA (Train): 0.9088094137949282
#         R2 score OSA (Test): 0.8942384742159607
#         R2 score FS (Train): 0.6182800746596826
#         R2 score FS (Test): 0.6497105648252601
#     Trying order: 5
#         R2 score OSA (Train): 0.8779635575550975
#         R2 score OSA (Test): 0.8569436368546484
#         R2 score FS (Train): 0.6946413692329141
#         R2 score FS (Test): 0.6928427217781383
#     Trying order: 6
#         R2 score OSA (Train): 0.9103035991212701
#         R2 score OSA (Test): 0.8840720420463926
#         R2 score FS (Train): 0.6275170238564779
#         R2 score FS (Test): 0.679659360670114
#     Trying order: 7
#         R2 score OSA (Train): 0.9098595175148417
#         R2 score OSA (Test): 0.8816057764061268
#         R2 score FS (Train): 0.6123595934158246
#         R2 score FS (Test): 0.6624301968849123
#     Trying order: 8
#         R2 score OSA (Train): 0.9137542557531352
#         R2 score OSA (Test): 0.8782286531907132
#         R2 score FS (Train): 0.6081201377743382
#         R2 score FS (Test): 0.6537934857093135
#     Trying order: 9
#         R2 score OSA (Train): 0.9156360724530921
#         R2 score OSA (Test): 0.8887953122426044
#         R2 score FS (Train): 0.565480105917965
#         R2 score FS (Test): 0.6276088471405468
#     Trying order: 10
#         R2 score OSA (Train): 0.9090390673530904
#         R2 score OSA (Test): 0.8859287375225708
#         R2 score FS (Train): 0.6487505415776051
#         R2 score FS (Test): 0.6598365803786099
#     Trying order: 11
#         R2 score OSA (Train): 0.9176947589302327
#         R2 score OSA (Test): 0.8987071715153521
#         R2 score FS (Train): 0.5811742430967715
#         R2 score FS (Test): 0.6374510210959456
#     Trying order: 12
#         R2 score OSA (Train): 0.9151013403423155
#         R2 score OSA (Test): 0.8862286240487407
#         R2 score FS (Train): 0.5693264834949305
#         R2 score FS (Test): 0.6288833873158967
#     Trying order: 13
#         R2 score OSA (Train): 0.9088286507164983
#         R2 score OSA (Test): 0.8692819159877917
#         R2 score FS (Train): 0.5785355764749698
#         R2 score FS (Test): 0.6389757834684366
#     Trying order: 14
#         R2 score OSA (Train): 0.914380194232592
#         R2 score OSA (Test): 0.8904317467892928
#         R2 score FS (Train): 0.6581898247087143
#         R2 score FS (Test): 0.6614036610333431
#     Trying order: 15
#         R2 score OSA (Train): 0.9158582184508693
#         R2 score OSA (Test): 0.8889873331572515
#         R2 score FS (Train): 0.5653334673137467
#         R2 score FS (Test): 0.6278802349776527
#     Trying order: 16
#         R2 score OSA (Train): 0.9158692828320005
#         R2 score OSA (Test): 0.8890493358863847
#         R2 score FS (Train): 0.5614791307553266
#         R2 score FS (Test): 0.6253642793572878
#     Trying order: 17
#         R2 score OSA (Train): 0.9036111611913752
#         R2 score OSA (Test): 0.8570234102168981
#         R2 score FS (Train): 0.7382258935920265
#         R2 score FS (Test): 0.715375760582802
#     Trying order: 18
#         R2 score OSA (Train): 0.9033941542216197
#         R2 score OSA (Test): 0.878200514545928
#         R2 score FS (Train): 0.6726603393383049
#         R2 score FS (Test): 0.7115659662886229
#     Trying order: 19
#         R2 score OSA (Train): 0.9064023581165325
#         R2 score OSA (Test): 0.8835022388341369
#         R2 score FS (Train): 0.5642922074464208
#         R2 score FS (Test): 0.5799370515381256
#     Trying order: 20
#         R2 score OSA (Train): 0.9097118767719466
#         R2 score OSA (Test): 0.8789413332347414
#         R2 score FS (Train): 0.7049619808940382
#         R2 score FS (Test): 0.7282400231747271
#
#     Tempo de execução: 0:00:44.099071
#     Best Order: 17
#     R2 score OSA (Train): 0.9036111611913752
#     R2 score OSA (Test): 0.8570234102168981
#     R2 score FS (Train): 0.7382258935920265
#     R2 score FS (Test): 0.715375760582802
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.9183517629989543
#         R2 score OSA (Test): 0.8973761827638099
#         R2 score FS (Train): 0.6918619456029531
#         R2 score FS (Test): 0.7032682700520987
#     Trying order: 3
#         R2 score OSA (Train): 0.9243540516637232
#         R2 score OSA (Test): 0.9037588954867409
#         R2 score FS (Train): 0.697519140266258
#         R2 score FS (Test): 0.705659170738001
#     Trying order: 4
#         R2 score OSA (Train): 0.9247514051998807
#         R2 score OSA (Test): 0.9061564235502886
#         R2 score FS (Train): 0.6992403188568053
#         R2 score FS (Test): 0.7067976734507361
#     Trying order: 5
#         R2 score OSA (Train): 0.9241221138327742
#         R2 score OSA (Test): 0.9043434338339583
#         R2 score FS (Train): 0.7109077088996225
#         R2 score FS (Test): 0.7189167858809334
#     Trying order: 6
#         R2 score OSA (Train): 0.9286990920162058
#         R2 score OSA (Test): 0.9065665679493287
#         R2 score FS (Train): 0.7142419871068997
#         R2 score FS (Test): 0.7202367193643286
#     Trying order: 7
#         R2 score OSA (Train): 0.9258085151551451
#         R2 score OSA (Test): 0.9029213496941777
#         R2 score FS (Train): 0.7097130420619947
#         R2 score FS (Test): 0.7126114212127717
#     Trying order: 8
#         R2 score OSA (Train): 0.9232911416971811
#         R2 score OSA (Test): 0.9021865759930363
#         R2 score FS (Train): 0.7141304799145565
#         R2 score FS (Test): 0.7185347962611622
#     Trying order: 9
#         R2 score OSA (Train): 0.9299648629144752
#         R2 score OSA (Test): 0.9078665775207022
#         R2 score FS (Train): 0.7337896677583262
#         R2 score FS (Test): 0.733719979320123
#     Trying order: 10
#         R2 score OSA (Train): 0.9316727527430251
#         R2 score OSA (Test): 0.9093873606761863
#         R2 score FS (Train): 0.7362251460472176
#         R2 score FS (Test): 0.7301304565710314
#     Trying order: 11
#         R2 score OSA (Train): 0.9348855044989863
#         R2 score OSA (Test): 0.9114911380124121
#         R2 score FS (Train): 0.7295335324102876
#         R2 score FS (Test): 0.728860974537176
#     Trying order: 12
#         R2 score OSA (Train): 0.933733878134896
#         R2 score OSA (Test): 0.9081602493090032
#         R2 score FS (Train): 0.7351761157893081
#         R2 score FS (Test): 0.7351170500221855
#     Trying order: 13
#         R2 score OSA (Train): 0.93059236012282
#         R2 score OSA (Test): 0.9082494528917033
#         R2 score FS (Train): 0.7265497265577621
#         R2 score FS (Test): 0.7314995705536961
#     Trying order: 14
#         R2 score OSA (Train): 0.9327738493387394
#         R2 score OSA (Test): 0.9075751254071742
#         R2 score FS (Train): 0.7494046087853764
#         R2 score FS (Test): 0.7381798875059407
#     Trying order: 15
#         R2 score OSA (Train): 0.9341635930458865
#         R2 score OSA (Test): 0.9062441545469999
#         R2 score FS (Train): 0.7430000565818373
#         R2 score FS (Test): 0.7384490876308398
#     Trying order: 16
#         R2 score OSA (Train): 0.9357089930642534
#         R2 score OSA (Test): 0.9088603634633838
#         R2 score FS (Train): 0.7497070068318513
#         R2 score FS (Test): 0.7470770832861331
#     Trying order: 17
#         R2 score OSA (Train): 0.9313500750776439
#         R2 score OSA (Test): 0.9099006675949242
#         R2 score FS (Train): 0.7379458551330178
#         R2 score FS (Test): 0.7399215353426187
#     Trying order: 18
#         R2 score OSA (Train): 0.9516840399205666
#         R2 score OSA (Test): 0.9228723374848864
#         R2 score FS (Train): 0.7659226744305484
#         R2 score FS (Test): 0.7588571977813712
#     Trying order: 19
#         R2 score OSA (Train): 0.9639523847297866
#         R2 score OSA (Test): 0.9310289570429935
#         R2 score FS (Train): 0.7718552377121748
#         R2 score FS (Test): 0.7615530804868114
#     Trying order: 20
#         R2 score OSA (Train): 0.9311861220228084
#         R2 score OSA (Test): 0.9080587266295994
#         R2 score FS (Train): 0.7523964146395561
#         R2 score FS (Test): 0.7436179906927103
#
#     Tempo de execução: 0:33:30.933337
#     Best Order: 19
#     R2 score OSA (Train): 0.9639523847297866
#     R2 score OSA (Test): 0.9310289570429935
#     R2 score FS (Train): 0.7718552377121748
#     R2 score FS (Test): 0.7615530804868114
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.9266477232836
#         R2 score OSA (Test): 0.8958472628416918
#         R2 score FS (Train): 0.6954959279250135
#         R2 score FS (Test): 0.7019824090001817
#     Trying order: 3
#         R2 score OSA (Train): 0.9352585555154078
#         R2 score OSA (Test): 0.9075189832179417
#         R2 score FS (Train): 0.679337070940655
#         R2 score FS (Test): 0.6859127916634655
#     Trying order: 4
#         R2 score OSA (Train): 0.9336414819080283
#         R2 score OSA (Test): 0.9072984988975967
#         R2 score FS (Train): 0.6686199901369115
#         R2 score FS (Test): 0.6882950931080735
#     Trying order: 5
#         R2 score OSA (Train): 0.9373380795625587
#         R2 score OSA (Test): 0.9081201193367275
#         R2 score FS (Train): 0.7061461755272975
#         R2 score FS (Test): 0.7113894636446186
#     Trying order: 6
#         R2 score OSA (Train): 0.967554941041904
#         R2 score OSA (Test): 0.9301296910327098
#         R2 score FS (Train): 0.7124057230923592
#         R2 score FS (Test): 0.7224611492073529
#     Trying order: 7
#         R2 score OSA (Train): 0.9399822706877068
#         R2 score OSA (Test): 0.9105760977785071
#         R2 score FS (Train): 0.6944872556130512
#         R2 score FS (Test): 0.7101821295454057
#     Trying order: 8
#         R2 score OSA (Train): 0.9420279350877381
#         R2 score OSA (Test): 0.9096490023686131
#         R2 score FS (Train): 0.6913464186730232
#         R2 score FS (Test): 0.6966782874633926
#     Trying order: 9
#         R2 score OSA (Train): 0.939334320885975
#         R2 score OSA (Test): 0.9106932613612352
#         R2 score FS (Train): 0.6957579300411997
#         R2 score FS (Test): 0.7060556305033896
#     Trying order: 10
#         R2 score OSA (Train): 0.9403983650143377
#         R2 score OSA (Test): 0.9122336824159267
#         R2 score FS (Train): 0.7050102593273813
#         R2 score FS (Test): 0.7200634033106095
#     Trying order: 11
#         R2 score OSA (Train): 0.9447072680119306
#         R2 score OSA (Test): 0.9140990900378342
#         R2 score FS (Train): 0.7218171958568063
#         R2 score FS (Test): 0.7244873866401444
#     Trying order: 12
#         R2 score OSA (Train): 0.9412794097838805
#         R2 score OSA (Test): 0.9148478114734172
#         R2 score FS (Train): 0.6957756753959208
#         R2 score FS (Test): 0.7067887099338102
#     Trying order: 13
#         R2 score OSA (Train): 0.9468798126344053
#         R2 score OSA (Test): 0.919771135648142
#         R2 score FS (Train): 0.722038157915929
#         R2 score FS (Test): 0.7319993096411941
#     Trying order: 14
#         R2 score OSA (Train): 0.9469559063705837
#         R2 score OSA (Test): 0.9195244699366599
#         R2 score FS (Train): 0.7073250042628331
#         R2 score FS (Test): 0.7227763933311675
#     Trying order: 15
#         R2 score OSA (Train): 0.9470660726861542
#         R2 score OSA (Test): 0.9159887904485755
#         R2 score FS (Train): 0.7257022701530993
#         R2 score FS (Test): 0.7302874519835507
#     Trying order: 16
#         R2 score OSA (Train): 0.977915943911564
#         R2 score OSA (Test): 0.9403391651118943
#         R2 score FS (Train): 0.7573895187392738
#         R2 score FS (Test): 0.750589628796083
#     Trying order: 17
#         R2 score OSA (Train): 0.9477989773537918
#         R2 score OSA (Test): 0.9167079903169268
#         R2 score FS (Train): 0.7342369990751563
#         R2 score FS (Test): 0.7328083667199679
#     Trying order: 18
#         R2 score OSA (Train): 0.9504199467057199
#         R2 score OSA (Test): 0.9167037025398204
#         R2 score FS (Train): 0.7373993880653258
#         R2 score FS (Test): 0.7396083818741004
#     Trying order: 19
#         R2 score OSA (Train): 0.9469336448579103
#         R2 score OSA (Test): 0.9183001247112705
#         R2 score FS (Train): 0.7349624202709553
#         R2 score FS (Test): 0.7407319235599434
#     Trying order: 20
#         R2 score OSA (Train): 0.9488077353611243
#         R2 score OSA (Test): 0.9131051903904361
#         R2 score FS (Train): 0.7382731646610563
#         R2 score FS (Test): 0.7377726719099434
#
#     Tempo de execução: 0:48:18.609617
#     Best Order: 16
#     R2 score OSA (Train): 0.977915943911564
#     R2 score OSA (Test): 0.9403391651118943
#     R2 score FS (Train): 0.7573895187392738
#     R2 score FS (Test): 0.750589628796083
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.9194802285050544
#         R2 score OSA (Test): 0.8985258866819925
#         R2 score FS (Train): 0.678884069761982
#         R2 score FS (Test): 0.6924775877837492
#     Trying order: 3
#         R2 score OSA (Train): 0.9221322660073221
#         R2 score OSA (Test): 0.8955179504718471
#         R2 score FS (Train): 0.6886952919190238
#         R2 score FS (Test): 0.6967581117571879
#     Trying order: 4
#         R2 score OSA (Train): 0.9272212411177384
#         R2 score OSA (Test): 0.8995210795829047
#         R2 score FS (Train): 0.6802438581749819
#         R2 score FS (Test): 0.6882032925236465
#     Trying order: 5
#         R2 score OSA (Train): 0.9623204990524419
#         R2 score OSA (Test): 0.9255643277599443
#         R2 score FS (Train): 0.7366215743403097
#         R2 score FS (Test): 0.7346079747639687
#     Trying order: 6
#         R2 score OSA (Train): 0.9279424375097041
#         R2 score OSA (Test): 0.901890163771395
#         R2 score FS (Train): 0.6868665604939885
#         R2 score FS (Test): 0.696811552893031
#     Trying order: 7
#         R2 score OSA (Train): 0.929391843822199
#         R2 score OSA (Test): 0.9012070429565612
#         R2 score FS (Train): 0.7129402524468409
#         R2 score FS (Test): 0.7110395139227913
#     Trying order: 8
#         R2 score OSA (Train): 0.929910039635187
#         R2 score OSA (Test): 0.8984231052221101
#         R2 score FS (Train): 0.7088575338797942
#         R2 score FS (Test): 0.709503994993583
#     Trying order: 9
#         R2 score OSA (Train): 0.9288368936618631
#         R2 score OSA (Test): 0.9013279972294302
#         R2 score FS (Train): 0.7056509755990141
#         R2 score FS (Test): 0.7083970333705634
#     Trying order: 10
#         R2 score OSA (Train): 0.9346424096125068
#         R2 score OSA (Test): 0.9051161344497016
#         R2 score FS (Train): 0.7072070848632158
#         R2 score FS (Test): 0.7102822468971743
#     Trying order: 11
#         R2 score OSA (Train): 0.9322550993034949
#         R2 score OSA (Test): 0.9033339000927765
#         R2 score FS (Train): 0.6997375025463044
#         R2 score FS (Test): 0.7052937306637607
#     Trying order: 12
#         R2 score OSA (Train): 0.9742667535173477
#         R2 score OSA (Test): 0.934799758720195
#         R2 score FS (Train): 0.7515782029892687
#         R2 score FS (Test): 0.7452625590414585
#     Trying order: 13
#         R2 score OSA (Train): 0.9354767759830318
#         R2 score OSA (Test): 0.9027354714218027
#         R2 score FS (Train): 0.7129832685668964
#         R2 score FS (Test): 0.7183519476879042
#     Trying order: 14
#         R2 score OSA (Train): 0.9726625970310026
#         R2 score OSA (Test): 0.9323388888666031
#         R2 score FS (Train): 0.74930489859694
#         R2 score FS (Test): 0.7487737791017262
#     Trying order: 15
#         R2 score OSA (Train): 0.9757929775356956
#         R2 score OSA (Test): 0.934615818158987
#         R2 score FS (Train): 0.751292750475881
#         R2 score FS (Test): 0.7482850326203775
#     Trying order: 16
#         R2 score OSA (Train): 0.9751370216078046
#         R2 score OSA (Test): 0.9345528093599923
#         R2 score FS (Train): 0.7563065698117196
#         R2 score FS (Test): 0.7558728914014997
#     Trying order: 17
#         R2 score OSA (Train): 0.9764438091643544
#         R2 score OSA (Test): 0.9331081288921065
#         R2 score FS (Train): 0.7455369697309644
#         R2 score FS (Test): 0.7480734597468968
#     Trying order: 18
#         R2 score OSA (Train): 0.9417003154768528
#         R2 score OSA (Test): 0.9097136321387752
#         R2 score FS (Train): 0.7244969917236614
#         R2 score FS (Test): 0.7323831814104877
#     Trying order: 19
#         R2 score OSA (Train): 0.9786971003419541
#         R2 score OSA (Test): 0.9355021769180899
#         R2 score FS (Train): 0.752880193678867
#         R2 score FS (Test): 0.7560928169032306
#     Trying order: 20
#         R2 score OSA (Train): 0.9434711446329299
#         R2 score OSA (Test): 0.914949872579863
#         R2 score FS (Train): 0.727621748719192
#         R2 score FS (Test): 0.7364614060260456
#
#     Tempo de execução: 0:29:29.167137
#     Best Order: 16
#     R2 score OSA (Train): 0.9751370216078046
#     R2 score OSA (Test): 0.9345528093599923
#     R2 score FS (Train): 0.7563065698117196
#     R2 score FS (Test): 0.7558728914014997
#
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.9073049605991187
#         R2 score OSA (Test): 0.8929687325063447
#         R2 score FS (Train): 0.6501571761565668
#         R2 score FS (Test): 0.6729456337030784
#     Trying order: 3
#         R2 score OSA (Train): 0.8988163652143856
#         R2 score OSA (Test): 0.8873936391522104
#         R2 score FS (Train): 0.6076335859555435
#         R2 score FS (Test): 0.643935648962762
#     Trying order: 4
#         R2 score OSA (Train): 0.9222359155502653
#         R2 score OSA (Test): 0.8993763109390374
#         R2 score FS (Train): 0.6545938122689214
#         R2 score FS (Test): 0.6745524712443555
#     Trying order: 5
#         R2 score OSA (Train): 0.9190100298196031
#         R2 score OSA (Test): 0.8946612527605148
#         R2 score FS (Train): 0.6786183767227091
#         R2 score FS (Test): 0.6943300633748821
#     Trying order: 6
#         R2 score OSA (Train): 0.9229428767562595
#         R2 score OSA (Test): 0.9001020226482174
#         R2 score FS (Train): 0.6579891177806753
#         R2 score FS (Test): 0.6838161184795146
#     Trying order: 7
#         R2 score OSA (Train): 0.9177857667160264
#         R2 score OSA (Test): 0.8956663248813997
#         R2 score FS (Train): 0.5888267647270949
#         R2 score FS (Test): 0.6304226007301279
#     Trying order: 8
#         R2 score OSA (Train): 0.9317609886558864
#         R2 score OSA (Test): 0.907090342378454
#         R2 score FS (Train): 0.6126759880158628
#         R2 score FS (Test): 0.647256687390199
#     Trying order: 9
#         R2 score OSA (Train): 0.9235122658377023
#         R2 score OSA (Test): 0.9007553360974696
#         R2 score FS (Train): 0.7126199438270997
#         R2 score FS (Test): 0.7231361664388144
#     Trying order: 10
#         R2 score OSA (Train): 0.9173230409877641
#         R2 score OSA (Test): 0.8971969027758747
#         R2 score FS (Train): 0.6669200758991762
#         R2 score FS (Test): 0.6898134132827263
#     Trying order: 11
#         R2 score OSA (Train): 0.930627685633467
#         R2 score OSA (Test): 0.9023488526149172
#         R2 score FS (Train): 0.7113224013964716
#         R2 score FS (Test): 0.7229867787380259
#     Trying order: 12
#         R2 score OSA (Train): 0.9259851867590836
#         R2 score OSA (Test): 0.8958118834109277
#         R2 score FS (Train): 0.7298080814526561
#         R2 score FS (Test): 0.7372492575273972
#     Trying order: 13
#         R2 score OSA (Train): 0.9296415091893812
#         R2 score OSA (Test): 0.8912418358877301
#         R2 score FS (Train): 0.7432178699265177
#         R2 score FS (Test): 0.7442688868234167
#     Trying order: 14
#         R2 score OSA (Train): 0.9175269426824066
#         R2 score OSA (Test): 0.8876194821354392
#         R2 score FS (Train): 0.7279239290962778
#         R2 score FS (Test): 0.7329097569127717
#     Trying order: 15
#         R2 score OSA (Train): 0.9479510678537464
#         R2 score OSA (Test): 0.9048719596276843
#         R2 score FS (Train): 0.6779730926392786
#         R2 score FS (Test): 0.7023738636901378
#     Trying order: 16
#         R2 score OSA (Train): 0.9168648387132265
#         R2 score OSA (Test): 0.8885403089426436
#         R2 score FS (Train): 0.7449451506892635
#         R2 score FS (Test): 0.7480389116731023
#     Trying order: 17
#         R2 score OSA (Train): 0.9391531639103591
#         R2 score OSA (Test): 0.9035038851092876
#         R2 score FS (Train): 0.6116051822435742
#         R2 score FS (Test): 0.6586851367676934
#     Trying order: 18
#         R2 score OSA (Train): 0.929922646816522
#         R2 score OSA (Test): 0.9030027765137565
#         R2 score FS (Train): 0.7306626568492329
#         R2 score FS (Test): 0.7377946197444081
#     Trying order: 19
#         R2 score OSA (Train): 0.9259408085664247
#         R2 score OSA (Test): 0.899620701009261
#         R2 score FS (Train): 0.7402943050397517
#         R2 score FS (Test): 0.7474398066573522
#     Trying order: 20
#         R2 score OSA (Train): 0.908036793933942
#         R2 score OSA (Test): 0.8864379122454422
#         R2 score FS (Train): 0.7285295682839407
#         R2 score FS (Test): 0.7361935776915649
#
#     Tempo de execução: 3:34:28.642109
#     Best Order: 16
#     R2 score OSA (Train): 0.9168648387132265
#     R2 score OSA (Test): 0.8885403089426436
#     R2 score FS (Train): 0.7449451506892635
#     R2 score FS (Test): 0.7480389116731023

# %%
pd.DataFrame(results)
# Out:
#               MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS
# 0            LinReg     20      0.887875     0.874432     0.684016  \
# 1           PolyReg      2      0.878735     0.874570     0.638596
# 2               SVM     20      0.902947     0.880114     0.718893
# 3               KNN      5      1.000000     0.925662     0.684575
# 4      DecisionTree     17      0.903611     0.857023     0.738226
# 5      RandomForest     19      0.963952     0.931029     0.771855
# 6  GradientBoosting     16      0.977916     0.940339     0.757390
# 7        ExtraTrees     16      0.975137     0.934553     0.756307
# 8               MLP     16      0.916865     0.888540     0.744945
#
#    R2 TEST FS                                          MODEL OBJ
# 0    0.686684  SYSIDRegressor(add_static=True,\n             ...  \
# 1    0.658130  SYSIDRegressor(add_static=True,\n             ...
# 2    0.726459  SYSIDRegressor(add_static=True,\n             ...
# 3    0.702835  SYSIDRegressor(add_static=True,\n             ...
# 4    0.715376  SYSIDRegressor(add_static=True,\n             ...
# 5    0.761553  SYSIDRegressor(add_static=True,\n             ...
# 6    0.750590  SYSIDRegressor(add_static=True,\n             ...
# 7    0.755873  SYSIDRegressor(add_static=True,\n             ...
# 8    0.748039  SYSIDRegressor(add_static=True,\n             ...
#
#                                                 PARS
# 0                                {'positive': False}
# 1                            {'Reg__positive': True}
# 2  {'C': 8.371287826575562, 'degree': 3, 'gamma':...
# 3          {'n_neighbors': 4, 'weights': 'distance'}
# 4  {'max_depth': 15, 'max_features': 0.8464632346...
# 5  {'max_depth': 7, 'max_features': 0.63893978454...
# 6  {'criterion': 'friedman_mse', 'learning_rate':...
# 7  {'criterion': 'squared_error', 'max_depth': 14...
# 8  {'activation': 'relu', 'alpha': 0.034328964195...

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#       MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS  R2 TEST FS
# 0    LinReg      2      0.862531     0.865442     0.584254    0.612186  \
# 1    LinReg      3      0.871724     0.866550     0.444677    0.442181
# 2    LinReg      4      0.873349     0.866355     0.537611    0.539899
# 3    LinReg      5      0.874799     0.867749     0.455661    0.398223
# 4    LinReg      6      0.877158     0.869026     0.597784    0.605991
# ..      ...    ...           ...          ...          ...         ...
# 166     MLP     16      0.916865     0.888540     0.744945    0.748039
# 167     MLP     17      0.939153     0.903504     0.611605    0.658685
# 168     MLP     18      0.929923     0.903003     0.730663    0.737795
# 169     MLP     19      0.925941     0.899621     0.740294    0.747440
# 170     MLP     20      0.908037     0.886438     0.728530    0.736194
#
#                                              MODEL OBJ
# 0    SYSIDRegressor(add_static=True,\n             ...
# 1    SYSIDRegressor(add_static=True,\n             ...
# 2    SYSIDRegressor(add_static=True,\n             ...
# 3    SYSIDRegressor(add_static=True,\n             ...
# 4    SYSIDRegressor(add_static=True,\n             ...
# ..                                                 ...
# 166  SYSIDRegressor(add_static=True,\n             ...
# 167  SYSIDRegressor(add_static=True,\n             ...
# 168  SYSIDRegressor(add_static=True,\n             ...
# 169  SYSIDRegressor(add_static=True,\n             ...
# 170  SYSIDRegressor(add_static=True,\n             ...
#
# [171 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[data_filt['R2 TEST FS'] >= 0]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', 'test_runs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/OneDrive/Mestrado/gits/sklearn-sid/Volve-Dataset/outputs/test_runs/SISO-Static.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# {'activation': 'relu', 'alpha': 0.03432896419556784, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (80, 80, 20, 20), 'max_iter': 10000, 'solver': 'adam', 'tol': 1.643128624493165e-05}

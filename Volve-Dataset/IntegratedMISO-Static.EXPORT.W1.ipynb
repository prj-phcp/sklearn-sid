# %% [markdown]
# # SYSID - Trabalho (ML - MISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import copy
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %%
#import sys
#sys.path.insert(0, os.path.abspath('..'))
from sklearn_sid.regressors.sklearn import SYSIDRegressor

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# /mnt/d/OneDrive/Mestrado/gits/sklearn-sid/Volve-Dataset/data/volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        'AVG_DOWNHOLE_PRESSURE',
        'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        'AVG_WHT_P',
        'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        #'BORE_OIL_VOL',
        'BORE_LIQ_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 5) (718, 5)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X_tr = X_scale.fit_transform(X1_tr)
X_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %%
basis_function = Polynomial(degree=1)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)

models.append(('ARMAX', model))

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %%
basis_function = Fourier(degree=2)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)
models.append(('NARMAX', model))

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    #{
    #    'activation'            : ['relu', 'logistic', 'tanh'],
    #    'early_stopping'        : [True, False],
    #    'alpha'                 : stats.loguniform(1e-9, 1e0),
    #    'hidden_layer_sizes'    : [(100,), (100, 100,), (100, 100, 100,), (100, 100, 100, 100,)],
    #    'max_iter'              : [10000],#stats.randint(200,10000),
    #    'batch_size'            : [32, 64, 128, 256, 'auto'],
    #    'solver'                : ['adam'], #'lbfgs'],
    #    'tol'                   : stats.loguniform(1e-7, 1e-1),
    #},
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    sidmodel = SYSIDRegressor(
        nX=6, ny=6,
        estimator=rdmsearch, 
        preprocessor=MinMaxScaler(),
        add_static=True
        )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
n_models = len(models)

results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

# %%
for model in models:
    print(model[0])
# Out:
# ARMAX
# NARMAX
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'MISO-Static.W1'
#Loop principal, iterando sobre as listas
for model in models[2:]:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1))
        r2_te_osa = r2_score(y_te, sidmodel.predict(X1_te, y=y_te, steps_ahead=1))
        try:
            r2_tr_fs = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr))
            r2_te_fs = r2_score(y_te, sidmodel.predict(X1_te, y=y_te))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = copy.deepcopy(sidmodel)
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(copy.deepcopy(sidmodel))
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr, label='Train')
    hist = ax[0].plot(best_model.predict(X1_tr, y=y_tr), label='Model') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,:], label='Test')
    hist = ax[1].plot(best_model.predict(X1_te, y=y_te)[n_train:,:], label='Model')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs', 'test_runs',f'{prefix}_{model_name}.pdf'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(best_model)
    try:
        results['PARS'].append(best_model.estimator.best_params_)
    except Exception:
        results['PARS'].append(best_model.final_model)
# Out:
# Starting evaluation of model: LinReg
#     Trying order: 2
#         R2 score OSA (Train): 0.8800983928991829
#         R2 score OSA (Test): 0.8374624679747777
#         R2 score FS (Train): 0.6895357652715931
#         R2 score FS (Test): 0.6976956717555416
#     Trying order: 3
#         R2 score OSA (Train): 0.8903307296770393
#         R2 score OSA (Test): 0.8311661375449376
#         R2 score FS (Train): 0.6635401922538303
#         R2 score FS (Test): 0.6719488893550012
#     Trying order: 4
#         R2 score OSA (Train): 0.8678113640721995
#         R2 score OSA (Test): 0.8588102583857492
#         R2 score FS (Train): 0.7083355989552299
#         R2 score FS (Test): 0.7122064322238875
#     Trying order: 5
#         R2 score OSA (Train): 0.8707287474647221
#         R2 score OSA (Test): 0.8613985686676344
#         R2 score FS (Train): 0.7107343739823393
#         R2 score FS (Test): 0.7121252928448059
#     Trying order: 6
#         R2 score OSA (Train): 0.8726717883737385
#         R2 score OSA (Test): 0.8631660568115652
#         R2 score FS (Train): 0.7117669716920976
#         R2 score FS (Test): 0.7119751398366043
#     Trying order: 7
#         R2 score OSA (Train): 0.8734504987640819
#         R2 score OSA (Test): 0.8630551243792837
#         R2 score FS (Train): 0.7114817522222585
#         R2 score FS (Test): 0.7115351709435883
#     Trying order: 8
#         R2 score OSA (Train): 0.8738740549069223
#         R2 score OSA (Test): 0.8635960259897391
#         R2 score FS (Train): 0.7118811534808935
#         R2 score FS (Test): 0.7113995061435188
#     Trying order: 9
#         R2 score OSA (Train): 0.874236594680135
#         R2 score OSA (Test): 0.8640496623366171
#         R2 score FS (Train): 0.7120000998230255
#         R2 score FS (Test): 0.7108498285312458
#     Trying order: 10
#         R2 score OSA (Train): 0.8748014939695294
#         R2 score OSA (Test): 0.8645036589624557
#         R2 score FS (Train): 0.7143542022054776
#         R2 score FS (Test): 0.7132631926802406
#     Trying order: 11
#         R2 score OSA (Train): 0.8752630536654987
#         R2 score OSA (Test): 0.8645218360885089
#         R2 score FS (Train): 0.7165655766820196
#         R2 score FS (Test): 0.7152149331019781
#     Trying order: 12
#         R2 score OSA (Train): 0.8766257282559698
#         R2 score OSA (Test): 0.8653855380755623
#         R2 score FS (Train): 0.7159325745617136
#         R2 score FS (Test): 0.7140749775221162
#     Trying order: 13
#         R2 score OSA (Train): 0.8768370608347623
#         R2 score OSA (Test): 0.8649729980655083
#         R2 score FS (Train): 0.7155605224812931
#         R2 score FS (Test): 0.7131804379070716
#     Trying order: 14
#         R2 score OSA (Train): 0.8772646810567426
#         R2 score OSA (Test): 0.8644895512993424
#         R2 score FS (Train): 0.713506459543626
#         R2 score FS (Test): 0.7110855998663567
#     Trying order: 15
#         R2 score OSA (Train): 0.8782870215602384
#         R2 score OSA (Test): 0.8650177430797472
#         R2 score FS (Train): 0.7100278355307027
#         R2 score FS (Test): 0.7061874782105967
#     Trying order: 16
#         R2 score OSA (Train): 0.8782870257691922
#         R2 score OSA (Test): 0.8650181174009518
#         R2 score FS (Train): 0.7099169704558779
#         R2 score FS (Test): 0.7061166798776859
#     Trying order: 17
#         R2 score OSA (Train): 0.8783002073230869
#         R2 score OSA (Test): 0.8650507673535457
#         R2 score FS (Train): 0.7101802969998884
#         R2 score FS (Test): 0.7063164368796779
#     Trying order: 18
#         R2 score OSA (Train): 0.8783018607868309
#         R2 score OSA (Test): 0.8650486554521217
#         R2 score FS (Train): 0.7100569538374042
#         R2 score FS (Test): 0.7062132937088024
#     Trying order: 19
#         R2 score OSA (Train): 0.8784849619936246
#         R2 score OSA (Test): 0.865335626653391
#         R2 score FS (Train): 0.7113165082862729
#         R2 score FS (Test): 0.706881926467668
#     Trying order: 20
#         R2 score OSA (Train): 0.8793173201592395
#         R2 score OSA (Test): 0.8656225174832448
#         R2 score FS (Train): 0.7110599416221282
#         R2 score FS (Test): 0.7055322046089916
#
#     Tempo de execução: 0:00:11.968335
#     Best Order: 11
#     R2 score OSA (Train): 0.8752630536654987
#     R2 score OSA (Test): 0.8645218360885089
#     R2 score FS (Train): 0.7165655766820196
#     R2 score FS (Test): 0.7152149331019781
#
# Starting evaluation of model: PolyReg
#     Trying order: 2
#         R2 score OSA (Train): 0.906016793886432
#         R2 score OSA (Test): 0.8762011767007934
#         R2 score FS (Train): 0.7501339842679366
#         R2 score FS (Test): 0.7483572570473819
#     Trying order: 3
#         R2 score OSA (Train): 0.9109878104999123
#         R2 score OSA (Test): 0.8805986203137974
#         R2 score FS (Train): 0.7488771276872662
#         R2 score FS (Test): 0.7495599728668052
#     Trying order: 4
#         R2 score OSA (Train): 0.9111911836089085
#         R2 score OSA (Test): 0.8834118888837255
#         R2 score FS (Train): 0.7541239153234607
#         R2 score FS (Test): 0.7532080936823677
#     Trying order: 5
#         R2 score OSA (Train): 0.9134825094179232
#         R2 score OSA (Test): 0.8852115412778851
#         R2 score FS (Train): 0.7570233475448356
#         R2 score FS (Test): 0.7553711237653006
#     Trying order: 6
#         R2 score OSA (Train): 0.9143712327611395
#         R2 score OSA (Test): 0.8837053422017751
#         R2 score FS (Train): 0.7567498087947128
#         R2 score FS (Test): 0.7552262440889002
#     Trying order: 7
#         R2 score OSA (Train): 0.9147844876133715
#         R2 score OSA (Test): 0.8855814922679041
#         R2 score FS (Train): 0.7562453133615816
#         R2 score FS (Test): 0.7548181009637409
#     Trying order: 8
#         R2 score OSA (Train): 0.9149127394689858
#         R2 score OSA (Test): 0.886402914337004
#         R2 score FS (Train): 0.756276891605774
#         R2 score FS (Test): 0.7547327340384584
#     Trying order: 9
#         R2 score OSA (Train): 0.915226933922798
#         R2 score OSA (Test): 0.8886476160739166
#         R2 score FS (Train): 0.7569969233540995
#         R2 score FS (Test): 0.7549162998796063
#     Trying order: 10
#         R2 score OSA (Train): 0.9154147910309149
#         R2 score OSA (Test): 0.88917444871276
#         R2 score FS (Train): 0.7573714532770613
#         R2 score FS (Test): 0.755316491039103
#     Trying order: 11
#         R2 score OSA (Train): 0.9155478378123421
#         R2 score OSA (Test): 0.8899332761842854
#         R2 score FS (Train): 0.7569352148543294
#         R2 score FS (Test): 0.755128650198223
#     Trying order: 12
#         R2 score OSA (Train): 0.9158738378235176
#         R2 score OSA (Test): 0.8941892213065632
#         R2 score FS (Train): 0.7571630940219436
#         R2 score FS (Test): 0.7544794855746233
#     Trying order: 13
#         R2 score OSA (Train): 0.9160613456657956
#         R2 score OSA (Test): 0.8944032649293607
#         R2 score FS (Train): 0.7572373258143992
#         R2 score FS (Test): 0.7550618127613105
#     Trying order: 14
#         R2 score OSA (Train): 0.9164483613261024
#         R2 score OSA (Test): 0.8938972601455809
#         R2 score FS (Train): 0.7552833490177961
#         R2 score FS (Test): 0.7535972895821044
#     Trying order: 15
#         R2 score OSA (Train): 0.9180241120923798
#         R2 score OSA (Test): 0.8972533213487396
#         R2 score FS (Train): 0.7512131638308333
#         R2 score FS (Test): 0.7475973016599868
#     Trying order: 16
#         R2 score OSA (Train): 0.9180439014766659
#         R2 score OSA (Test): 0.8973581848767833
#         R2 score FS (Train): 0.7512154023868618
#         R2 score FS (Test): 0.7476049452123448
#     Trying order: 17
#         R2 score OSA (Train): 0.9180727103427623
#         R2 score OSA (Test): 0.8974642138516207
#         R2 score FS (Train): 0.7510018567201135
#         R2 score FS (Test): 0.7476072470487265
#     Trying order: 18
#         R2 score OSA (Train): 0.9181485081890752
#         R2 score OSA (Test): 0.8977403940476114
#         R2 score FS (Train): 0.7506909430255011
#         R2 score FS (Test): 0.7472978614740521
#     Trying order: 19
#         R2 score OSA (Train): 0.9185285312231906
#         R2 score OSA (Test): 0.898876110349435
#         R2 score FS (Train): 0.7503871273907157
#         R2 score FS (Test): 0.7468816067558267
#     Trying order: 20
#         R2 score OSA (Train): 0.9196156520171566
#         R2 score OSA (Test): 0.8994026060895435
#         R2 score FS (Train): 0.7479545798946847
#         R2 score FS (Test): 0.7447007302833648
#
#     Tempo de execução: 0:03:50.241816
#     Best Order: 10
#     R2 score OSA (Train): 0.9154147910309149
#     R2 score OSA (Test): 0.88917444871276
#     R2 score FS (Train): 0.7573714532770613
#     R2 score FS (Test): 0.755316491039103
#
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.9088431346018843
#         R2 score OSA (Test): 0.8914503703983838
#         R2 score FS (Train): 0.7421340753804397
#         R2 score FS (Test): 0.7386528071553577
#     Trying order: 3
#         R2 score OSA (Train): 0.9203917963686098
#         R2 score OSA (Test): 0.8876211471918779
#         R2 score FS (Train): 0.7585361982116144
#         R2 score FS (Test): 0.7522692819975155
#     Trying order: 4
#         R2 score OSA (Train): 0.9184937261035435
#         R2 score OSA (Test): 0.8859037217276733
#         R2 score FS (Train): 0.7618480939337449
#         R2 score FS (Test): 0.7537089334948132
#     Trying order: 5
#         R2 score OSA (Train): 0.9087659798863053
#         R2 score OSA (Test): 0.880020009265535
#         R2 score FS (Train): 0.7609080023179748
#         R2 score FS (Test): 0.7494009819436398
#     Trying order: 6
#         R2 score OSA (Train): 0.9091774430401464
#         R2 score OSA (Test): 0.8801081953188128
#         R2 score FS (Train): 0.7528465066729031
#         R2 score FS (Test): 0.7449268155507973
#     Trying order: 7
#         R2 score OSA (Train): 0.8904440452339338
#         R2 score OSA (Test): 0.8698314148345505
#         R2 score FS (Train): 0.7410013171712685
#         R2 score FS (Test): 0.7337061377595464
#     Trying order: 8
#         R2 score OSA (Train): 0.91220626273401
#         R2 score OSA (Test): 0.8792648870300364
#         R2 score FS (Train): 0.7491304822410247
#         R2 score FS (Test): 0.73974341275716
#     Trying order: 9
#         R2 score OSA (Train): 0.8907104390679059
#         R2 score OSA (Test): 0.8706495606729361
#         R2 score FS (Train): 0.7446460053301224
#         R2 score FS (Test): 0.7379275626400055
#     Trying order: 10
#         R2 score OSA (Train): 0.8908112098348683
#         R2 score OSA (Test): 0.8698952363732774
#         R2 score FS (Train): 0.7455088222349018
#         R2 score FS (Test): 0.7392665457951213
#     Trying order: 11
#         R2 score OSA (Train): 0.8914788630132398
#         R2 score OSA (Test): 0.8679323820755543
#         R2 score FS (Train): 0.7473817160491749
#         R2 score FS (Test): 0.740081560922192
#     Trying order: 12
#         R2 score OSA (Train): 0.894359487553519
#         R2 score OSA (Test): 0.8684242007830757
#         R2 score FS (Train): 0.7499165368301455
#         R2 score FS (Test): 0.7420901786462331
#     Trying order: 13
#         R2 score OSA (Train): 0.8999198521503283
#         R2 score OSA (Test): 0.8721611567803644
#         R2 score FS (Train): 0.7514661256866824
#         R2 score FS (Test): 0.7460869438804136
#     Trying order: 14
#         R2 score OSA (Train): 0.9022891131342159
#         R2 score OSA (Test): 0.8712154640835112
#         R2 score FS (Train): 0.7487553656851519
#         R2 score FS (Test): 0.7438632783252037
#     Trying order: 15
#         R2 score OSA (Train): 0.9067573621904589
#         R2 score OSA (Test): 0.875025344553934
#         R2 score FS (Train): 0.7456671473253341
#         R2 score FS (Test): 0.7408406543000234
#     Trying order: 16
#         R2 score OSA (Train): 0.9099450293493068
#         R2 score OSA (Test): 0.8749860650562801
#         R2 score FS (Train): 0.7501890889025805
#         R2 score FS (Test): 0.7429542691084392
#     Trying order: 17
#         R2 score OSA (Train): 0.9113437490171904
#         R2 score OSA (Test): 0.8756775987089234
#         R2 score FS (Train): 0.7491617173857069
#         R2 score FS (Test): 0.7407231779412635
#     Trying order: 18
#         R2 score OSA (Train): 0.9108005305665554
#         R2 score OSA (Test): 0.8726359939518008
#         R2 score FS (Train): 0.7485556784029537
#         R2 score FS (Test): 0.738173446204611
#     Trying order: 19
#         R2 score OSA (Train): 0.9134086250450745
#         R2 score OSA (Test): 0.8737753397626893
#         R2 score FS (Train): 0.7516846260528848
#         R2 score FS (Test): 0.7397293032650205
#     Trying order: 20
#         R2 score OSA (Train): 0.9153256271480995
#         R2 score OSA (Test): 0.8740063485106643
#         R2 score FS (Train): 0.7542246046611842
#         R2 score FS (Test): 0.7402513749967587
#
#     Tempo de execução: 1:07:45.022202
#     Best Order: 4
#     R2 score OSA (Train): 0.9184937261035435
#     R2 score OSA (Test): 0.8859037217276733
#     R2 score FS (Train): 0.7618480939337449
#     R2 score FS (Test): 0.7537089334948132
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 0.9999999999999842
#         R2 score OSA (Test): 0.94556643199722
#         R2 score FS (Train): 0.7569144264408258
#         R2 score FS (Test): 0.7455420439639551
#     Trying order: 3
#         R2 score OSA (Train): 0.9999999999999951
#         R2 score OSA (Test): 0.9396773535229024
#         R2 score FS (Train): 0.7406001575048966
#         R2 score FS (Test): 0.7283864121553876
#     Trying order: 4
#         R2 score OSA (Train): 0.9999999999999837
#         R2 score OSA (Test): 0.9370211363443908
#         R2 score FS (Train): 0.7478222919353879
#         R2 score FS (Test): 0.7298922710710343
#     Trying order: 5
#         R2 score OSA (Train): 0.9999999999999902
#         R2 score OSA (Test): 0.9317985104731066
#         R2 score FS (Train): 0.7498995401339192
#         R2 score FS (Test): 0.7333163960119145
#     Trying order: 6
#         R2 score OSA (Train): 0.99999999999999
#         R2 score OSA (Test): 0.9295768556874949
#         R2 score FS (Train): 0.7571960941890706
#         R2 score FS (Test): 0.7241143512502681
#     Trying order: 7
#         R2 score OSA (Train): 0.9999999999999177
#         R2 score OSA (Test): 0.9326716513887272
#         R2 score FS (Train): 0.7337666570144596
#         R2 score FS (Test): 0.7011823425977537
#     Trying order: 8
#         R2 score OSA (Train): 0.9999999999998807
#         R2 score OSA (Test): 0.9338759020614145
#         R2 score FS (Train): 0.7286206749023405
#         R2 score FS (Test): 0.7043272673410617
#     Trying order: 9
#         R2 score OSA (Train): 0.999999999999993
#         R2 score OSA (Test): 0.924722534419943
#         R2 score FS (Train): 0.7420207527340263
#         R2 score FS (Test): 0.7160186505543975
#     Trying order: 10
#         R2 score OSA (Train): 0.9999999999999853
#         R2 score OSA (Test): 0.9290915459080017
#         R2 score FS (Train): 0.7349149073059237
#         R2 score FS (Test): 0.7329177287262053
#     Trying order: 11
#         R2 score OSA (Train): 0.9999999999999897
#         R2 score OSA (Test): 0.9265756387322273
#         R2 score FS (Train): 0.7413819058428445
#         R2 score FS (Test): 0.7365740163985011
#     Trying order: 12
#         R2 score OSA (Train): 0.9999999999999939
#         R2 score OSA (Test): 0.9169789211220387
#         R2 score FS (Train): 0.7414571811417866
#         R2 score FS (Test): 0.7159723928243473
#     Trying order: 13
#         R2 score OSA (Train): 0.9999999999999841
#         R2 score OSA (Test): 0.9201585101195605
#         R2 score FS (Train): 0.7491428628816537
#         R2 score FS (Test): 0.7210566511894567
#     Trying order: 14
#         R2 score OSA (Train): 0.99999999999996
#         R2 score OSA (Test): 0.9267893524098386
#         R2 score FS (Train): 0.744884327814399
#         R2 score FS (Test): 0.7141290662548474
#     Trying order: 15
#         R2 score OSA (Train): 0.9999999999999789
#         R2 score OSA (Test): 0.9175076112325189
#         R2 score FS (Train): 0.7416116460133797
#         R2 score FS (Test): 0.7018985753648219
#     Trying order: 16
#         R2 score OSA (Train): 0.9999999999999851
#         R2 score OSA (Test): 0.913023189938893
#         R2 score FS (Train): 0.7515748776525668
#         R2 score FS (Test): 0.6971810592296581
#     Trying order: 17
#         R2 score OSA (Train): 0.999999999999973
#         R2 score OSA (Test): 0.9192159199231859
#         R2 score FS (Train): 0.7405403800900321
#         R2 score FS (Test): 0.6977713125743268
#     Trying order: 18
#         R2 score OSA (Train): 0.9999999999999875
#         R2 score OSA (Test): 0.9121719366346976
#         R2 score FS (Train): 0.7518624015110758
#         R2 score FS (Test): 0.6999569345576078
#     Trying order: 19
#         R2 score OSA (Train): 0.9999999999999771
#         R2 score OSA (Test): 0.9198572344096567
#         R2 score FS (Train): 0.75264039007235
#         R2 score FS (Test): 0.7125232812741521
#     Trying order: 20
#         R2 score OSA (Train): 0.9999999999999777
#         R2 score OSA (Test): 0.9181783747094102
#         R2 score FS (Train): 0.7459501932676229
#         R2 score FS (Test): 0.7031377001896024
#
#     Tempo de execução: 0:01:54.973832
#     Best Order: 6
#     R2 score OSA (Train): 0.99999999999999
#     R2 score OSA (Test): 0.9295768556874949
#     R2 score FS (Train): 0.7571960941890706
#     R2 score FS (Test): 0.7241143512502681
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.9107817074231466
#         R2 score OSA (Test): 0.8863482481513847
#         R2 score FS (Train): 0.6697439321465415
#         R2 score FS (Test): 0.7020536825081609
#     Trying order: 3
#         R2 score OSA (Train): 0.9207130937237757
#         R2 score OSA (Test): 0.8928592349337313
#         R2 score FS (Train): 0.6143231193810452
#         R2 score FS (Test): 0.6687301594920092
#     Trying order: 4
#         R2 score OSA (Train): 0.9158474071109904
#         R2 score OSA (Test): 0.8959470345186717
#         R2 score FS (Train): 0.6478054501533368
#         R2 score FS (Test): 0.6879829244705501
#     Trying order: 5
#         R2 score OSA (Train): 0.9202149259122081
#         R2 score OSA (Test): 0.9003561610948165
#         R2 score FS (Train): 0.6846689798241126
#         R2 score FS (Test): 0.7169703274488834
#     Trying order: 6
#         R2 score OSA (Train): 0.8917484929135489
#         R2 score OSA (Test): 0.8763870118723919
#         R2 score FS (Train): 0.3931483125772912
#         R2 score FS (Test): 0.49476200683731986
#     Trying order: 7
#         R2 score OSA (Train): 0.9519456855537229
#         R2 score OSA (Test): 0.9151886940704295
#         R2 score FS (Train): 0.7472514850921177
#         R2 score FS (Test): 0.7404978677011789
#     Trying order: 8
#         R2 score OSA (Train): 0.9191816058455867
#         R2 score OSA (Test): 0.8729455263752292
#         R2 score FS (Train): 0.7609243757251212
#         R2 score FS (Test): 0.7445843744146727
#     Trying order: 9
#         R2 score OSA (Train): 0.8914131236577459
#         R2 score OSA (Test): 0.8633056069547509
#         R2 score FS (Train): 0.6844902355463316
#         R2 score FS (Test): 0.6975198707170613
#     Trying order: 10
#         R2 score OSA (Train): 0.9158497476090461
#         R2 score OSA (Test): 0.8851189951489924
#         R2 score FS (Train): 0.6742653734070675
#         R2 score FS (Test): 0.7042162726353856
#     Trying order: 11
#         R2 score OSA (Train): 0.921829863474636
#         R2 score OSA (Test): 0.8926790123338724
#         R2 score FS (Train): 0.4420947964541396
#         R2 score FS (Test): 0.5536499425980712
#     Trying order: 12
#         R2 score OSA (Train): 0.9196551812497624
#         R2 score OSA (Test): 0.8710786712070421
#         R2 score FS (Train): 0.7108837305584815
#         R2 score FS (Test): 0.717369653255833
#     Trying order: 13
#         R2 score OSA (Train): 0.9103140983559473
#         R2 score OSA (Test): 0.8869312059459593
#         R2 score FS (Train): 0.6664793793931201
#         R2 score FS (Test): 0.6886890171757076
#     Trying order: 14
#         R2 score OSA (Train): 0.9105780441035224
#         R2 score OSA (Test): 0.8858665537693495
#         R2 score FS (Train): 0.6701608498794357
#         R2 score FS (Test): 0.6907373358916864
#     Trying order: 15
#         R2 score OSA (Train): 0.9205266340342698
#         R2 score OSA (Test): 0.8867180933594728
#         R2 score FS (Train): 0.615121027640466
#         R2 score FS (Test): 0.6662901511133925
#     Trying order: 16
#         R2 score OSA (Train): 0.9222844599547686
#         R2 score OSA (Test): 0.8827329469173798
#         R2 score FS (Train): 0.6710799636291966
#         R2 score FS (Test): 0.701428609148183
#     Trying order: 17
#         R2 score OSA (Train): 0.9107117458822673
#         R2 score OSA (Test): 0.8864654730620545
#         R2 score FS (Train): 0.6248002996085177
#         R2 score FS (Test): 0.6557760907763945
#     Trying order: 18
#         R2 score OSA (Train): 0.9141879898645102
#         R2 score OSA (Test): 0.8819240422885913
#         R2 score FS (Train): 0.5599300244552188
#         R2 score FS (Test): 0.6194247725115942
#     Trying order: 19
#         R2 score OSA (Train): 0.9153055398626015
#         R2 score OSA (Test): 0.891822202594103
#         R2 score FS (Train): 0.7009288147824309
#         R2 score FS (Test): 0.724642753103591
#     Trying order: 20
#         R2 score OSA (Train): 0.9652018190957328
#         R2 score OSA (Test): 0.9166010559367079
#         R2 score FS (Train): 0.5364167893940268
#         R2 score FS (Test): 0.4964448711030911
#
#     Tempo de execução: 0:01:08.364210
#     Best Order: 8
#     R2 score OSA (Train): 0.9191816058455867
#     R2 score OSA (Test): 0.8729455263752292
#     R2 score FS (Train): 0.7609243757251212
#     R2 score FS (Test): 0.7445843744146727
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.9753571673002782
#         R2 score OSA (Test): 0.9376113691214363
#         R2 score FS (Train): 0.7554627771039198
#         R2 score FS (Test): 0.7519620629368935
#     Trying order: 3
#         R2 score OSA (Train): 0.9749240541532294
#         R2 score OSA (Test): 0.9352239870193697
#         R2 score FS (Train): 0.7641452588137754
#         R2 score FS (Test): 0.7607871865230055
#     Trying order: 4
#         R2 score OSA (Train): 0.9763179705039768
#         R2 score OSA (Test): 0.9359013614448607
#         R2 score FS (Train): 0.7536941300486496
#         R2 score FS (Test): 0.756827756592827
#     Trying order: 5
#         R2 score OSA (Train): 0.9751386451029596
#         R2 score OSA (Test): 0.9343710537694552
#         R2 score FS (Train): 0.7815623074238202
#         R2 score FS (Test): 0.7708819869761332
#     Trying order: 6
#         R2 score OSA (Train): 0.9752194085425056
#         R2 score OSA (Test): 0.936673528875411
#         R2 score FS (Train): 0.7733534107132534
#         R2 score FS (Test): 0.7704182554925068
#     Trying order: 7
#         R2 score OSA (Train): 0.9608416333165103
#         R2 score OSA (Test): 0.9264598742430243
#         R2 score FS (Train): 0.7686803808903415
#         R2 score FS (Test): 0.7626736974367271
#     Trying order: 8
#         R2 score OSA (Train): 0.974660471644841
#         R2 score OSA (Test): 0.9382695140590518
#         R2 score FS (Train): 0.7780848352579826
#         R2 score FS (Test): 0.770868455898035
#     Trying order: 9
#         R2 score OSA (Train): 0.961236617667977
#         R2 score OSA (Test): 0.9249362110185273
#         R2 score FS (Train): 0.7773884291004773
#         R2 score FS (Test): 0.7654906981266675
#     Trying order: 10
#         R2 score OSA (Train): 0.960992835218408
#         R2 score OSA (Test): 0.9265674915894672
#         R2 score FS (Train): 0.7791288435420837
#         R2 score FS (Test): 0.7700301725946375
#     Trying order: 11
#         R2 score OSA (Train): 0.975574989417155
#         R2 score OSA (Test): 0.9375213501270708
#         R2 score FS (Train): 0.7747558554011194
#         R2 score FS (Test): 0.7675331283752227
#     Trying order: 12
#         R2 score OSA (Train): 0.9767460723181406
#         R2 score OSA (Test): 0.9380157663560059
#         R2 score FS (Train): 0.7807436265707456
#         R2 score FS (Test): 0.7744050953548071
#     Trying order: 13
#         R2 score OSA (Train): 0.9730362060823039
#         R2 score OSA (Test): 0.9342797943213774
#         R2 score FS (Train): 0.7778863709932962
#         R2 score FS (Test): 0.7757634336191568
#     Trying order: 14
#         R2 score OSA (Train): 0.972154074849769
#         R2 score OSA (Test): 0.9316714111171539
#         R2 score FS (Train): 0.778924758540618
#         R2 score FS (Test): 0.7752959069722432
#     Trying order: 15
#         R2 score OSA (Train): 0.9784789317931242
#         R2 score OSA (Test): 0.9368007200914479
#         R2 score FS (Train): 0.7798828008426246
#         R2 score FS (Test): 0.7768131941063929
#     Trying order: 16
#         R2 score OSA (Train): 0.9769884343007031
#         R2 score OSA (Test): 0.9350657914037552
#         R2 score FS (Train): 0.7872996365394334
#         R2 score FS (Test): 0.7791437231679568
#     Trying order: 17
#         R2 score OSA (Train): 0.9764820622570876
#         R2 score OSA (Test): 0.934431480780753
#         R2 score FS (Train): 0.7860393366266974
#         R2 score FS (Test): 0.7779972436130789
#     Trying order: 18
#         R2 score OSA (Train): 0.974443829116961
#         R2 score OSA (Test): 0.9327624593188834
#         R2 score FS (Train): 0.7825460805021874
#         R2 score FS (Test): 0.7767420818815968
#     Trying order: 19
#         R2 score OSA (Train): 0.9736927388296768
#         R2 score OSA (Test): 0.9345071906195479
#         R2 score FS (Train): 0.781200565602697
#         R2 score FS (Test): 0.777194805004453
#     Trying order: 20
#         R2 score OSA (Train): 0.9789330005256955
#         R2 score OSA (Test): 0.938714418659157
#         R2 score FS (Train): 0.7887821400196285
#         R2 score FS (Test): 0.784000813879977
#
#     Tempo de execução: 0:46:36.353013
#     Best Order: 20
#     R2 score OSA (Train): 0.9789330005256955
#     R2 score OSA (Test): 0.938714418659157
#     R2 score FS (Train): 0.7887821400196285
#     R2 score FS (Test): 0.784000813879977
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.9519461702601077
#         R2 score OSA (Test): 0.9188204424852331
#         R2 score FS (Train): 0.760508153755183
#         R2 score FS (Test): 0.7496549150961592
#     Trying order: 3
#         R2 score OSA (Train): 0.984312862520831
#         R2 score OSA (Test): 0.9343382980115147
#         R2 score FS (Train): 0.74707528097461
#         R2 score FS (Test): 0.7469948083133107
#     Trying order: 4
#         R2 score OSA (Train): 0.9844307681827102
#         R2 score OSA (Test): 0.932831961453115
#         R2 score FS (Train): 0.7550536117911373
#         R2 score FS (Test): 0.7576336615348714
#     Trying order: 5
#         R2 score OSA (Train): 0.9882399882245013
#         R2 score OSA (Test): 0.9266469885564632
#         R2 score FS (Train): 0.7718891698110262
#         R2 score FS (Test): 0.7707237692331401
#     Trying order: 6
#         R2 score OSA (Train): 0.985490430754347
#         R2 score OSA (Test): 0.9349498956969067
#         R2 score FS (Train): 0.7568212878227734
#         R2 score FS (Test): 0.7585377208153098
#     Trying order: 7
#         R2 score OSA (Train): 0.9586606728329072
#         R2 score OSA (Test): 0.9206241887285858
#         R2 score FS (Train): 0.7553720781366794
#         R2 score FS (Test): 0.7488508310537945
#     Trying order: 8
#         R2 score OSA (Train): 0.9867184109676486
#         R2 score OSA (Test): 0.9354084202274733
#         R2 score FS (Train): 0.7540082476489491
#         R2 score FS (Test): 0.7543261600385304
#     Trying order: 9
#         R2 score OSA (Train): 0.985004708548504
#         R2 score OSA (Test): 0.9360885810755356
#         R2 score FS (Train): 0.768581668049634
#         R2 score FS (Test): 0.7609190558740191
#     Trying order: 10
#         R2 score OSA (Train): 0.9580349827981044
#         R2 score OSA (Test): 0.9239740632283354
#         R2 score FS (Train): 0.7723513215042337
#         R2 score FS (Test): 0.7612783582024286
#     Trying order: 11
#         R2 score OSA (Train): 0.9870467143304272
#         R2 score OSA (Test): 0.9300105925332469
#         R2 score FS (Train): 0.7678484530750622
#         R2 score FS (Test): 0.7634904707912993
#     Trying order: 12
#         R2 score OSA (Train): 0.9870662368082281
#         R2 score OSA (Test): 0.926085333772051
#         R2 score FS (Train): 0.7674798374915597
#         R2 score FS (Test): 0.7671085540987265
#     Trying order: 13
#         R2 score OSA (Train): 0.9638795748223293
#         R2 score OSA (Test): 0.9268570384503928
#         R2 score FS (Train): 0.7691914819338711
#         R2 score FS (Test): 0.7642432880758236
#     Trying order: 14
#         R2 score OSA (Train): 0.9914879568026437
#         R2 score OSA (Test): 0.9341349876194478
#         R2 score FS (Train): 0.781134208935597
#         R2 score FS (Test): 0.7724043416025046
#     Trying order: 15
#         R2 score OSA (Train): 0.9907954694375654
#         R2 score OSA (Test): 0.9341431265643484
#         R2 score FS (Train): 0.7730692640844761
#         R2 score FS (Test): 0.7701969138086492
#     Trying order: 16
#         R2 score OSA (Train): 0.9890822729841161
#         R2 score OSA (Test): 0.9322414405684804
#         R2 score FS (Train): 0.7721368261203229
#         R2 score FS (Test): 0.7701142691945582
#     Trying order: 17
#         R2 score OSA (Train): 0.9897363982629933
#         R2 score OSA (Test): 0.9332659895040278
#         R2 score FS (Train): 0.7874244078695125
#         R2 score FS (Test): 0.7788988714583847
#     Trying order: 18
#         R2 score OSA (Train): 0.9625505527369285
#         R2 score OSA (Test): 0.9219997798488453
#         R2 score FS (Train): 0.7817764375047981
#         R2 score FS (Test): 0.7667463862424215
#     Trying order: 19
#         R2 score OSA (Train): 0.9896567686005667
#         R2 score OSA (Test): 0.9392852952427581
#         R2 score FS (Train): 0.7723427547398647
#         R2 score FS (Test): 0.7713813685906101
#     Trying order: 20
#         R2 score OSA (Train): 0.9914905886080695
#         R2 score OSA (Test): 0.9413973950401039
#         R2 score FS (Train): 0.7757100853619766
#         R2 score FS (Test): 0.7703987118466042
#
#     Tempo de execução: 1:10:31.543174
#     Best Order: 17
#     R2 score OSA (Train): 0.9897363982629933
#     R2 score OSA (Test): 0.9332659895040278
#     R2 score FS (Train): 0.7874244078695125
#     R2 score FS (Test): 0.7788988714583847
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.9808363553380912
#         R2 score OSA (Test): 0.9470239382727628
#         R2 score FS (Train): 0.7807910458374279
#         R2 score FS (Test): 0.77395165282314
#     Trying order: 3
#         R2 score OSA (Train): 0.9843657484782403
#         R2 score OSA (Test): 0.9420538494746805
#         R2 score FS (Train): 0.77583512198909
#         R2 score FS (Test): 0.76663217407191
#     Trying order: 4
#         R2 score OSA (Train): 0.9851959869726916
#         R2 score OSA (Test): 0.9408840523646158
#         R2 score FS (Train): 0.773385714944347
#         R2 score FS (Test): 0.7635728076003669
#     Trying order: 5
#         R2 score OSA (Train): 0.9850113396239989
#         R2 score OSA (Test): 0.9406778675148709
#         R2 score FS (Train): 0.7828752555725302
#         R2 score FS (Test): 0.7742033504303699
#     Trying order: 6
#         R2 score OSA (Train): 0.987324299444789
#         R2 score OSA (Test): 0.945144099281372
#         R2 score FS (Train): 0.78390301888252
#         R2 score FS (Test): 0.7748883972029379
#     Trying order: 7
#         R2 score OSA (Train): 0.9873839659538299
#         R2 score OSA (Test): 0.9448453385399583
#         R2 score FS (Train): 0.7829261579808443
#         R2 score FS (Test): 0.7749182376832161
#     Trying order: 8
#         R2 score OSA (Train): 0.9883066326155044
#         R2 score OSA (Test): 0.9460701744239487
#         R2 score FS (Train): 0.7913819921490677
#         R2 score FS (Test): 0.7830450723003595
#     Trying order: 9
#         R2 score OSA (Train): 0.986867580606902
#         R2 score OSA (Test): 0.9454072301146694
#         R2 score FS (Train): 0.7835329404511504
#         R2 score FS (Test): 0.7751078184568116
#     Trying order: 10
#         R2 score OSA (Train): 0.9882421398882825
#         R2 score OSA (Test): 0.9439385331005385
#         R2 score FS (Train): 0.7855973429047247
#         R2 score FS (Test): 0.7754805687288003
#     Trying order: 11
#         R2 score OSA (Train): 0.9883644640797385
#         R2 score OSA (Test): 0.940931219273166
#         R2 score FS (Train): 0.7838088461941495
#         R2 score FS (Test): 0.7773148059957027
#     Trying order: 12
#         R2 score OSA (Train): 0.9890032680624161
#         R2 score OSA (Test): 0.9441661675021173
#         R2 score FS (Train): 0.7816438923625262
#         R2 score FS (Test): 0.7774921700430285
#     Trying order: 13
#         R2 score OSA (Train): 0.9902332742882947
#         R2 score OSA (Test): 0.9431350644008221
#         R2 score FS (Train): 0.7857603597477081
#         R2 score FS (Test): 0.7816811738626701
#     Trying order: 14
#         R2 score OSA (Train): 0.9907245176128914
#         R2 score OSA (Test): 0.9471001040938715
#         R2 score FS (Train): 0.7865295750711545
#         R2 score FS (Test): 0.7824254378037043
#     Trying order: 15
#         R2 score OSA (Train): 0.990881758842118
#         R2 score OSA (Test): 0.9441653391704685
#         R2 score FS (Train): 0.7867571116782575
#         R2 score FS (Test): 0.7739400479119412
#     Trying order: 16
#         R2 score OSA (Train): 0.991000847933403
#         R2 score OSA (Test): 0.9463521576906729
#         R2 score FS (Train): 0.7855486372337643
#         R2 score FS (Test): 0.7758317200898348
#     Trying order: 17
#         R2 score OSA (Train): 0.9641219737842815
#         R2 score OSA (Test): 0.9266450023034247
#         R2 score FS (Train): 0.7791128136505433
#         R2 score FS (Test): 0.7681917397263343
#     Trying order: 18
#         R2 score OSA (Train): 0.9909722498258213
#         R2 score OSA (Test): 0.9435275489967831
#         R2 score FS (Train): 0.7869504778838347
#         R2 score FS (Test): 0.7750520561578151
#     Trying order: 19
#         R2 score OSA (Train): 0.9909130284815235
#         R2 score OSA (Test): 0.9452389684614598
#         R2 score FS (Train): 0.7841442830376225
#         R2 score FS (Test): 0.7764821962743786
#     Trying order: 20
#         R2 score OSA (Train): 0.9630545313153571
#         R2 score OSA (Test): 0.928591699403848
#         R2 score FS (Train): 0.7757749749293437
#         R2 score FS (Test): 0.7649624070370512
#
#     Tempo de execução: 0:55:17.463752
#     Best Order: 8
#     R2 score OSA (Train): 0.9883066326155044
#     R2 score OSA (Test): 0.9460701744239487
#     R2 score FS (Train): 0.7913819921490677
#     R2 score FS (Test): 0.7830450723003595
#
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.9317560435246128
#         R2 score OSA (Test): 0.9159239930934803
#         R2 score FS (Train): 0.7529723663839926
#         R2 score FS (Test): 0.7554771132909877
#     Trying order: 3
#         R2 score OSA (Train): 0.9388088335411267
#         R2 score OSA (Test): 0.9118264186959115
#         R2 score FS (Train): 0.7233806886145561
#         R2 score FS (Test): 0.7302640337496814
#     Trying order: 4
#         R2 score OSA (Train): 0.9544356207180177
#         R2 score OSA (Test): 0.8699773857038177
#         R2 score FS (Train): 0.7706207724703384
#         R2 score FS (Test): 0.7647023876100476
#     Trying order: 5
#         R2 score OSA (Train): 0.947646532599189
#         R2 score OSA (Test): 0.9118541066089403
#         R2 score FS (Train): 0.7783097175811722
#         R2 score FS (Test): 0.7678782454246846
#     Trying order: 6
#         R2 score OSA (Train): 0.9178748922629578
#         R2 score OSA (Test): 0.8873347216626863
#         R2 score FS (Train): 0.7799551059585369
#         R2 score FS (Test): 0.7664055931701197
#     Trying order: 7
#         R2 score OSA (Train): 0.9546667778555438
#         R2 score OSA (Test): 0.9143441277048217
#         R2 score FS (Train): 0.778143813677451
#         R2 score FS (Test): 0.7732500966345686
#     Trying order: 8
#         R2 score OSA (Train): 0.9204248244087044
#         R2 score OSA (Test): 0.891068055280757
#         R2 score FS (Train): 0.6499361944557489
#         R2 score FS (Test): 0.6781268166776745
#     Trying order: 9
#         R2 score OSA (Train): 0.9370444641158513
#         R2 score OSA (Test): 0.9076610254368208
#         R2 score FS (Train): 0.7488987580886817
#         R2 score FS (Test): 0.7544150082318919
#     Trying order: 10
#         R2 score OSA (Train): 0.9511287335906681
#         R2 score OSA (Test): 0.9175859237837982
#         R2 score FS (Train): 0.7823807236022767
#         R2 score FS (Test): 0.7781987521941833
#     Trying order: 11
#         R2 score OSA (Train): 0.932180800292585
#         R2 score OSA (Test): 0.90206089585796
#         R2 score FS (Train): 0.7525464960059777
#         R2 score FS (Test): 0.7526536133046208
#     Trying order: 12
#         R2 score OSA (Train): 0.9500203965170413
#         R2 score OSA (Test): 0.9100142549507686
#         R2 score FS (Train): 0.7923308848678771
#         R2 score FS (Test): 0.7887622404320016
#     Trying order: 13
#         R2 score OSA (Train): 0.9032958182198076
#         R2 score OSA (Test): 0.8836051130913501
#         R2 score FS (Train): 0.7533563216941197
#         R2 score FS (Test): 0.7531268679226211
#     Trying order: 14
#         R2 score OSA (Train): 0.9874372808481544
#         R2 score OSA (Test): 0.8833340628808131
#         R2 score FS (Train): 0.7742158461688651
#         R2 score FS (Test): 0.7207689108593985
#     Trying order: 15
#         R2 score OSA (Train): 0.9528079074268156
#         R2 score OSA (Test): 0.9120457185220435
#         R2 score FS (Train): 0.7739705395562623
#         R2 score FS (Test): 0.7701871381141325
#     Trying order: 16
#         R2 score OSA (Train): 0.9747647319071483
#         R2 score OSA (Test): 0.9145955425085026
#         R2 score FS (Train): 0.734545283113782
#         R2 score FS (Test): 0.7274009344061082
#     Trying order: 17
#         R2 score OSA (Train): 0.9877015212499551
#         R2 score OSA (Test): 0.9155261271997172
#         R2 score FS (Train): 0.7673144205052287
#         R2 score FS (Test): 0.7393530401336209
#     Trying order: 18
#         R2 score OSA (Train): 0.9115212001694357
#         R2 score OSA (Test): 0.8847027803364318
#         R2 score FS (Train): 0.7648004739686523
#         R2 score FS (Test): 0.7589711201921497
#     Trying order: 19
#         R2 score OSA (Train): 0.9281915449526881
#         R2 score OSA (Test): 0.8991156931904675
#         R2 score FS (Train): 0.7689047017973982
#         R2 score FS (Test): 0.7704773298326562
#     Trying order: 20
#         R2 score OSA (Train): 0.9567864983747277
#         R2 score OSA (Test): 0.8990799161510904
#         R2 score FS (Train): 0.7496450956516769
#         R2 score FS (Test): 0.7287723801725243
#
#     Tempo de execução: 3:37:27.165138
#     Best Order: 12
#     R2 score OSA (Train): 0.9500203965170413
#     R2 score OSA (Test): 0.9100142549507686
#     R2 score FS (Train): 0.7923308848678771
#     R2 score FS (Test): 0.7887622404320016

# %%
pd.DataFrame(results)
# Out:
#               MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS
# 0            LinReg     11      0.875263     0.864522     0.716566  \
# 1           PolyReg     10      0.915415     0.889174     0.757371
# 2               SVM      4      0.918494     0.885904     0.761848
# 3               KNN      6      1.000000     0.929577     0.757196
# 4      DecisionTree      8      0.919182     0.872946     0.760924
# 5      RandomForest     20      0.978933     0.938714     0.788782
# 6  GradientBoosting     17      0.989736     0.933266     0.787424
# 7        ExtraTrees      8      0.988307     0.946070     0.791382
# 8               MLP     12      0.950020     0.910014     0.792331
#
#    R2 TEST FS                                          MODEL OBJ
# 0    0.715215  SYSIDRegressor(add_static=True,\n             ...  \
# 1    0.755316  SYSIDRegressor(add_static=True,\n             ...
# 2    0.753709  SYSIDRegressor(add_static=True,\n             ...
# 3    0.724114  SYSIDRegressor(add_static=True,\n             ...
# 4    0.744584  SYSIDRegressor(add_static=True,\n             ...
# 5    0.784001  SYSIDRegressor(add_static=True,\n             ...
# 6    0.778899  SYSIDRegressor(add_static=True,\n             ...
# 7    0.783045  SYSIDRegressor(add_static=True,\n             ...
# 8    0.788762  SYSIDRegressor(add_static=True,\n             ...
#
#                                                 PARS
# 0                                 {'positive': True}
# 1                            {'Reg__positive': True}
# 2  {'C': 0.5252086606388584, 'degree': 3, 'gamma'...
# 3          {'n_neighbors': 3, 'weights': 'distance'}
# 4  {'max_depth': 16, 'max_features': 0.5379855975...
# 5  {'max_depth': 15, 'max_features': 0.4813329840...
# 6  {'criterion': 'friedman_mse', 'learning_rate':...
# 7  {'criterion': 'squared_error', 'max_depth': 14...
# 8  {'activation': 'relu', 'alpha': 0.000204614794...

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#       MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS  R2 TEST FS
# 0    LinReg      2      0.880098     0.837462     0.689536    0.697696  \
# 1    LinReg      3      0.890331     0.831166     0.663540    0.671949
# 2    LinReg      4      0.867811     0.858810     0.708336    0.712206
# 3    LinReg      5      0.870729     0.861399     0.710734    0.712125
# 4    LinReg      6      0.872672     0.863166     0.711767    0.711975
# ..      ...    ...           ...          ...          ...         ...
# 166     MLP     16      0.974765     0.914596     0.734545    0.727401
# 167     MLP     17      0.987702     0.915526     0.767314    0.739353
# 168     MLP     18      0.911521     0.884703     0.764800    0.758971
# 169     MLP     19      0.928192     0.899116     0.768905    0.770477
# 170     MLP     20      0.956786     0.899080     0.749645    0.728772
#
#                                              MODEL OBJ
# 0    SYSIDRegressor(add_static=True,\n             ...
# 1    SYSIDRegressor(add_static=True,\n             ...
# 2    SYSIDRegressor(add_static=True,\n             ...
# 3    SYSIDRegressor(add_static=True,\n             ...
# 4    SYSIDRegressor(add_static=True,\n             ...
# ..                                                 ...
# 166  SYSIDRegressor(add_static=True,\n             ...
# 167  SYSIDRegressor(add_static=True,\n             ...
# 168  SYSIDRegressor(add_static=True,\n             ...
# 169  SYSIDRegressor(add_static=True,\n             ...
# 170  SYSIDRegressor(add_static=True,\n             ...
#
# [171 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[data_filt['R2 TEST FS'] >= 0]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', 'test_runs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/OneDrive/Mestrado/gits/sklearn-sid/Volve-Dataset/outputs/test_runs/MISO-Static.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# {'activation': 'relu', 'alpha': 0.00020461479485383763, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (80, 60, 80, 40), 'max_iter': 10000, 'solver': 'adam', 'tol': 0.0003762217327987109}

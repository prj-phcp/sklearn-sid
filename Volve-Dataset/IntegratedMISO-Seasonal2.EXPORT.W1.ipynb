# %% [markdown]
# # SYSID - Trabalho (ML - SISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import copy
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.multioutput import MultiOutputRegressor

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

#Seasonal decomposition
from statsmodels.tsa.seasonal import seasonal_decompose

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %%
from sklearn_sid.regressors.sklearn import SYSIDRegressor
from sklearn_sid.preprocessors.fourier_decompose import SFFTEnergyExpansor, SFFTFrequencyExpansor
from sklearn_sid.preprocessors.seasonal_decompose import SeasonalDecomposeExpansor

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/data/volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        'AVG_DOWNHOLE_PRESSURE',
        'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        'AVG_WHT_P',
        'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        #'BORE_OIL_VOL',
        'BORE_LIQ_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 5) (718, 5)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X1_tr = X_scale.fit_transform(X1_tr)
X1_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ### 1.4 - Decompondo a série

# %%
period=30
kr = True
fft_y = SeasonalDecomposeExpansor(period=period, keep_residuals=kr)
fft_X = SeasonalDecomposeExpansor(period=period, keep_residuals=kr)
y_tr_copy = y_tr.copy()
X1_tr_copy = X1_tr.copy()
y_tr = fft_y.fit_transform(y_tr)
y_te = fft_y.transform(y_te)
X1_tr = fft_X.fit_transform(X1_tr)
X1_te = fft_X.transform(X1_te)

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 15) (718, 15)

# %%
fig, ax = plt.subplots(2,1, figsize=(20,14))

for i in range(X1_te.shape[1]):
    try:
        ax[0].plot(y_tr[:,i], label=f'Energy level {i+1}')
    except Exception:
        pass
    try:
        ax[1].plot(X1_tr[:,i], label=f'Energy level {i+1}')
    except Exception:
        pass
ax[0].plot(y_tr.sum(axis=1), label='Reconstituted data')
ax[1].plot(X1_tr.sum(axis=1), label='Reconstituted data')
ax[0].plot(y_tr_copy, 'k--', label='Real data')
ax[1].plot(X1_tr_copy, 'k--', label='Real data')
ax[0].legend()
ax[1].legend()

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    if model[0] == 'MLP':
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=rdmsearch, 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    else:
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=MultiOutputRegressor(rdmsearch, n_jobs=1), 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

#models = models[-1:]

# %%
for model in models:
    print(model[0])
# Out:
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'MISO-Seasonal.W1'
#Loop principal, iterando sobre as listas
for model in models[2:]:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1).sum(axis=1))
        r2_te_osa = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te, steps_ahead=1).sum(axis=1))
        try:
            r2_tr_fs = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr).sum(axis=1))
            r2_te_fs = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te).sum(axis=1))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = copy.deepcopy(sidmodel)
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(copy.deepcopy(sidmodel))
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr.sum(axis=1), label='Train')
    hist = ax[0].plot(best_model.predict(X1_tr, y=y_tr).sum(axis=1), label='Model') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,:].sum(axis=1), label='Test')
    hist = ax[1].plot(best_model.predict(X1_te, y=y_te)[n_train:,:].sum(axis=1), label='Model')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs', 'test_runs',f'{prefix}_{model_name}.pdf'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(best_model)
    try:
        results['PARS'].append(None)
    except Exception:
        results['PARS'].append(best_model.final_model)
# Out:
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.754727123285181
#         R2 score OSA (Test): 0.7422353811870969
#         R2 score FS (Train): 0.5702854145738591
#         R2 score FS (Test): 0.5792304515634591
#     Trying order: 3
#         R2 score OSA (Train): 0.7546337404634671
#         R2 score OSA (Test): 0.7346979163652555
#         R2 score FS (Train): 0.5820673340593114
#         R2 score FS (Test): 0.589971262783004
#     Trying order: 4
#         R2 score OSA (Train): 0.7753908104532499
#         R2 score OSA (Test): 0.7364828229956
#         R2 score FS (Train): 0.625882383587986
#         R2 score FS (Test): 0.6124510986966867
#     Trying order: 5
#         R2 score OSA (Train): 0.7703231761157958
#         R2 score OSA (Test): 0.7257857406705523
#         R2 score FS (Train): 0.6212313063325619
#         R2 score FS (Test): 0.5966771517217659
#     Trying order: 6
#         R2 score OSA (Train): 0.7662251748879166
#         R2 score OSA (Test): 0.7364081650781538
#         R2 score FS (Train): 0.6041058263299577
#         R2 score FS (Test): 0.5954404126825419
#     Trying order: 7
#         R2 score OSA (Train): 0.7626029412320977
#         R2 score OSA (Test): 0.7283763765621095
#         R2 score FS (Train): 0.6036458024927269
#         R2 score FS (Test): 0.5908101588324153
#     Trying order: 8
#         R2 score OSA (Train): 0.7749767877937609
#         R2 score OSA (Test): 0.7284683436361755
#         R2 score FS (Train): 0.6297273792844804
#         R2 score FS (Test): 0.6079106864544153
#     Trying order: 9
#         R2 score OSA (Train): 0.7794929553426705
#         R2 score OSA (Test): 0.7170701247972879
#         R2 score FS (Train): 0.6448142424813684
#         R2 score FS (Test): 0.6080701929528981
#     Trying order: 10
#         R2 score OSA (Train): 0.7873719597071238
#         R2 score OSA (Test): 0.716620704447409
#         R2 score FS (Train): 0.6566353384619869
#         R2 score FS (Test): 0.6124366320058188
#     Trying order: 11
#         R2 score OSA (Train): 0.7871446713195012
#         R2 score OSA (Test): 0.7211760736876305
#         R2 score FS (Train): 0.6598449564257873
#         R2 score FS (Test): 0.6214796733151222
#     Trying order: 12
#         R2 score OSA (Train): 0.7913098308384785
#         R2 score OSA (Test): 0.7231354950784412
#         R2 score FS (Train): 0.66518239439184
#         R2 score FS (Test): 0.6249178505178311
#     Trying order: 13
#         R2 score OSA (Train): 0.7966440289670472
#         R2 score OSA (Test): 0.7263781924090162
#         R2 score FS (Train): 0.6636199609807669
#         R2 score FS (Test): 0.630063268561257
#     Trying order: 14
#         R2 score OSA (Train): 0.786880347603428
#         R2 score OSA (Test): 0.7288029935708494
#         R2 score FS (Train): 0.6475155721078727
#         R2 score FS (Test): 0.6393546273582291
#     Trying order: 15
#         R2 score OSA (Train): 0.793700467596914
#         R2 score OSA (Test): 0.7281410999831283
#         R2 score FS (Train): 0.654442750002806
#         R2 score FS (Test): 0.641417146065547
#     Trying order: 16
#         R2 score OSA (Train): 0.8022363008198958
#         R2 score OSA (Test): 0.7255768851113717
#         R2 score FS (Train): 0.6604807540163106
#         R2 score FS (Test): 0.6383373431345853
#     Trying order: 17
#         R2 score OSA (Train): 0.77301250817182
#         R2 score OSA (Test): 0.7297745806891546
#         R2 score FS (Train): 0.5992704288641476
#         R2 score FS (Test): 0.5747769276776871
#     Trying order: 18
#         R2 score OSA (Train): 0.8107715918051889
#         R2 score OSA (Test): 0.7106502846305115
#         R2 score FS (Train): 0.6541090123687467
#         R2 score FS (Test): 0.6325954304133001
#     Trying order: 19
#         R2 score OSA (Train): 0.7659376404107288
#         R2 score OSA (Test): 0.7239553875140528
#         R2 score FS (Train): 0.5989475721711119
#         R2 score FS (Test): 0.5831285929500671
#     Trying order: 20
#         R2 score OSA (Train): 0.7684231344621505
#         R2 score OSA (Test): 0.7245289981762039
#         R2 score FS (Train): 0.6027534091205977
#         R2 score FS (Test): 0.5883829756398965
#
#     Tempo de execução: 4:08:30.602763
#     Best Order: 12
#     R2 score OSA (Train): 0.7913098308384785
#     R2 score OSA (Test): 0.7231354950784412
#     R2 score FS (Train): 0.66518239439184
#     R2 score FS (Test): 0.6249178505178311
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 0.9999999999999687
#         R2 score OSA (Test): 0.7547037674630555
#         R2 score FS (Train): 0.6724497458382037
#         R2 score FS (Test): 0.6078667430729967
#     Trying order: 3
#         R2 score OSA (Train): 0.8264378573854033
#         R2 score OSA (Test): 0.7445165236406515
#         R2 score FS (Train): 0.6567019190414578
#         R2 score FS (Test): 0.6058947069232881
#     Trying order: 4
#         R2 score OSA (Train): 0.999999999999963
#         R2 score OSA (Test): 0.7782026733045917
#         R2 score FS (Train): 0.7145493614894165
#         R2 score FS (Test): 0.6122637428399116
#     Trying order: 5
#         R2 score OSA (Train): 0.9999999999999722
#         R2 score OSA (Test): 0.7876238404254619
#         R2 score FS (Train): 0.7294495399350585
#         R2 score FS (Test): 0.6251778668192873
#     Trying order: 6
#         R2 score OSA (Train): 0.9999999999999597
#         R2 score OSA (Test): 0.7846942666339388
#         R2 score FS (Train): 0.725178965213016
#         R2 score FS (Test): 0.6163003579926853
#     Trying order: 7
#         R2 score OSA (Train): 0.9999999999999728
#         R2 score OSA (Test): 0.7723291488272799
#         R2 score FS (Train): 0.7249901991509345
#         R2 score FS (Test): 0.617897156444313
#     Trying order: 8
#         R2 score OSA (Train): 0.9999999999999575
#         R2 score OSA (Test): 0.7770529345025627
#         R2 score FS (Train): 0.7341128631379562
#         R2 score FS (Test): 0.6362627145759351
#     Trying order: 9
#         R2 score OSA (Train): 0.9999999999999413
#         R2 score OSA (Test): 0.7719684861581806
#         R2 score FS (Train): 0.7533054860296328
#         R2 score FS (Test): 0.6362735620876374
#     Trying order: 10
#         R2 score OSA (Train): 0.9999999999999692
#         R2 score OSA (Test): 0.7795657732344318
#         R2 score FS (Train): 0.7599805098832864
#         R2 score FS (Test): 0.6181223205524522
#     Trying order: 11
#         R2 score OSA (Train): 0.9999999999999799
#         R2 score OSA (Test): 0.7803246872889839
#         R2 score FS (Train): 0.7594360526334176
#         R2 score FS (Test): 0.6359200659451945
#     Trying order: 12
#         R2 score OSA (Train): 0.999999999999968
#         R2 score OSA (Test): 0.7647042941429065
#         R2 score FS (Train): 0.7706456754580476
#         R2 score FS (Test): 0.6531169415719231
#     Trying order: 13
#         R2 score OSA (Train): 0.999999999999985
#         R2 score OSA (Test): 0.7808159809565377
#         R2 score FS (Train): 0.7837272815069118
#         R2 score FS (Test): 0.6659608362385071
#     Trying order: 14
#         R2 score OSA (Train): 0.9999999999999786
#         R2 score OSA (Test): 0.783863422791912
#         R2 score FS (Train): 0.7822018642856454
#         R2 score FS (Test): 0.6696610649468944
#     Trying order: 15
#         R2 score OSA (Train): 0.9999999999999848
#         R2 score OSA (Test): 0.7679115080566341
#         R2 score FS (Train): 0.7837016323481952
#         R2 score FS (Test): 0.6597249402192251
#     Trying order: 16
#         R2 score OSA (Train): 0.9999999999999929
#         R2 score OSA (Test): 0.7625486025678336
#         R2 score FS (Train): 0.7795973631027382
#         R2 score FS (Test): 0.6472038932072091
#     Trying order: 17
#         R2 score OSA (Train): 0.9999999999999902
#         R2 score OSA (Test): 0.7539817471624065
#         R2 score FS (Train): 0.7795633405053076
#         R2 score FS (Test): 0.6402872697873069
#     Trying order: 18
#         R2 score OSA (Train): 0.9999999999999887
#         R2 score OSA (Test): 0.7435432243473137
#         R2 score FS (Train): 0.7795029617008572
#         R2 score FS (Test): 0.6504299329467151
#     Trying order: 19
#         R2 score OSA (Train): 0.9999999999999888
#         R2 score OSA (Test): 0.7332924407482633
#         R2 score FS (Train): 0.7814462583731246
#         R2 score FS (Test): 0.6597969339713791
#     Trying order: 20
#         R2 score OSA (Train): 0.9999999999999729
#         R2 score OSA (Test): 0.7360533396120937
#         R2 score FS (Train): 0.7695606883625252
#         R2 score FS (Test): 0.6531846826272686
#
#     Tempo de execução: 0:12:50.375334
#     Best Order: 13
#     R2 score OSA (Train): 0.999999999999985
#     R2 score OSA (Test): 0.7808159809565377
#     R2 score FS (Train): 0.7837272815069118
#     R2 score FS (Test): 0.6659608362385071
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.7933739470396308
#         R2 score OSA (Test): 0.7450430561403998
#         R2 score FS (Train): -2.7715562248134806
#         R2 score FS (Test): -3.173896598532634
#     Trying order: 3
#         R2 score OSA (Train): 0.8391331340418452
#         R2 score OSA (Test): 0.7554130952918467
#         R2 score FS (Train): 0.1751068098511538
#         R2 score FS (Test): 0.10007601929266474
#     Trying order: 4
#         R2 score OSA (Train): 0.8285480883152495
#         R2 score OSA (Test): 0.7538527264348995
#         R2 score FS (Train): -0.05435784945998012
#         R2 score FS (Test): -0.27747586439989846
#     Trying order: 5
#         R2 score OSA (Train): 0.8499165811294762
#         R2 score OSA (Test): 0.7463365021306974
#         R2 score FS (Train): 0.5474385203265316
#         R2 score FS (Test): 0.5089736156848093
#     Trying order: 6
#         R2 score OSA (Train): 0.8287093351957446
#         R2 score OSA (Test): 0.740338462446584
#         R2 score FS (Train): -1.0809003904778218
#         R2 score FS (Test): -1.2439241647767187
#     Trying order: 7
#         R2 score OSA (Train): 0.8435215705879424
#         R2 score OSA (Test): 0.7719964823307043
#         R2 score FS (Train): -0.38706289849688735
#         R2 score FS (Test): -0.4935262690918465
#     Trying order: 8
#         R2 score OSA (Train): 0.8308335585879134
#         R2 score OSA (Test): 0.7739947466715085
#         R2 score FS (Train): -1.4319831980664866
#         R2 score FS (Test): -1.4736482029678237
#     Trying order: 9
#         R2 score OSA (Train): 0.8869760561002877
#         R2 score OSA (Test): 0.7722867552983668
#         R2 score FS (Train): -0.009427267896441327
#         R2 score FS (Test): -0.09511073631829192
#     Trying order: 10
#         R2 score OSA (Train): 0.8766945110780359
#         R2 score OSA (Test): 0.7696731580598932
#         R2 score FS (Train): -0.8878468900818852
#         R2 score FS (Test): -1.4378163671828417
#     Trying order: 11
#         R2 score OSA (Train): 0.8778890099723073
#         R2 score OSA (Test): 0.746102062747851
#         R2 score FS (Train): 0.01855494223811638
#         R2 score FS (Test): -0.09829159773605323
#     Trying order: 12
#         R2 score OSA (Train): 0.8745115179541123
#         R2 score OSA (Test): 0.763524266973551
#         R2 score FS (Train): 0.48816199155517137
#         R2 score FS (Test): 0.4946531492213958
#     Trying order: 13
#         R2 score OSA (Train): 0.8642141375758461
#         R2 score OSA (Test): 0.7816077175562514
#         R2 score FS (Train): -1.6587949044474972
#         R2 score FS (Test): -1.9807049356589927
#     Trying order: 14
#         R2 score OSA (Train): 0.8514332939209734
#         R2 score OSA (Test): 0.7689831847026811
#         R2 score FS (Train): 0.04428500930117363
#         R2 score FS (Test): -0.03799408756863287
#     Trying order: 15
#         R2 score OSA (Train): 0.8815426789027777
#         R2 score OSA (Test): 0.7753424846976947
#         R2 score FS (Train): -0.8453476528753243
#         R2 score FS (Test): -1.273891502499458
#     Trying order: 16
#         R2 score OSA (Train): 0.8601755448237015
#         R2 score OSA (Test): 0.7637566255738014
#         R2 score FS (Train): -1.8031295845984632
#         R2 score FS (Test): -2.2515173942296833
#     Trying order: 17
#         R2 score OSA (Train): 0.888821807676513
#         R2 score OSA (Test): 0.7580689781527423
#         R2 score FS (Train): -0.17963466646015203
#         R2 score FS (Test): -0.9003128881554736
#     Trying order: 18
#         R2 score OSA (Train): 0.8765561910363902
#         R2 score OSA (Test): 0.775999501201055
#         R2 score FS (Train): -0.6495076289607522
#         R2 score FS (Test): -1.165414229297555
#     Trying order: 19
#         R2 score OSA (Train): 0.8169541497909361
#         R2 score OSA (Test): 0.7501068403723539
#         R2 score FS (Train): 0.23768526504739995
#         R2 score FS (Test): 0.18976971970525847
#     Trying order: 20
#         R2 score OSA (Train): 0.8818655020122697
#         R2 score OSA (Test): 0.7889589149665022
#         R2 score FS (Train): -0.5625719319602476
#         R2 score FS (Test): -1.0630220329147018
#
#     Tempo de execução: 0:08:29.658672
#     Best Order: 5
#     R2 score OSA (Train): 0.8499165811294762
#     R2 score OSA (Test): 0.7463365021306974
#     R2 score FS (Train): 0.5474385203265316
#     R2 score FS (Test): 0.5089736156848093
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.9450318487881791
#         R2 score OSA (Test): 0.8564456021569733
#         R2 score FS (Train): 0.7072359330870668
#         R2 score FS (Test): 0.6763100295061573
#     Trying order: 3
#         R2 score OSA (Train): 0.9538398524131616
#         R2 score OSA (Test): 0.8625494914518026
#         R2 score FS (Train): 0.6714561607380254
#         R2 score FS (Test): 0.6525689744410386
#     Trying order: 4
#         R2 score OSA (Train): 0.9494005449285904
#         R2 score OSA (Test): 0.8513780000541507
#         R2 score FS (Train): 0.7034223688399046
#         R2 score FS (Test): 0.6658792388983727
#     Trying order: 5
#         R2 score OSA (Train): 0.9498103887221868
#         R2 score OSA (Test): 0.8531223675633861
#         R2 score FS (Train): 0.7023770879146533
#         R2 score FS (Test): 0.6662662661952736
#     Trying order: 6
#         R2 score OSA (Train): 0.9530418512751909
#         R2 score OSA (Test): 0.8543318628048067
#         R2 score FS (Train): 0.6908351978281752
#         R2 score FS (Test): 0.6510625377348808
#     Trying order: 7
#         R2 score OSA (Train): 0.9271969746487484
#         R2 score OSA (Test): 0.8421042346342075
#         R2 score FS (Train): 0.7203908317869123
#         R2 score FS (Test): 0.6832616357106925
#     Trying order: 8
#         R2 score OSA (Train): 0.9539672180282018
#         R2 score OSA (Test): 0.856723819046396
#         R2 score FS (Train): 0.711930387926843
#         R2 score FS (Test): 0.6754592651850178
#     Trying order: 9
#         R2 score OSA (Train): 0.9534749016530841
#         R2 score OSA (Test): 0.8603115867607216
#         R2 score FS (Train): 0.7199703762263923
#         R2 score FS (Test): 0.6770910151651162
#     Trying order: 10
#         R2 score OSA (Train): 0.9304691262811063
#         R2 score OSA (Test): 0.837933575671004
#         R2 score FS (Train): 0.7118590091819561
#         R2 score FS (Test): 0.6710907455707968
#     Trying order: 11
#         R2 score OSA (Train): 0.9527750898857783
#         R2 score OSA (Test): 0.8573500370922597
#         R2 score FS (Train): 0.7101152574328577
#         R2 score FS (Test): 0.6852550525245087
#     Trying order: 12
#         R2 score OSA (Train): 0.9305710404789608
#         R2 score OSA (Test): 0.8499064700759569
#         R2 score FS (Train): 0.6848556561913901
#         R2 score FS (Test): 0.6565136095953445
#     Trying order: 13
#         R2 score OSA (Train): 0.9358523298040072
#         R2 score OSA (Test): 0.8492558050352141
#         R2 score FS (Train): 0.713357543055545
#         R2 score FS (Test): 0.6698395070335954
#     Trying order: 14
#         R2 score OSA (Train): 0.9502787311296609
#         R2 score OSA (Test): 0.8589035866824193
#         R2 score FS (Train): 0.7146027853056214
#         R2 score FS (Test): 0.6879722925146211
#     Trying order: 15
#         R2 score OSA (Train): 0.9331624385668713
#         R2 score OSA (Test): 0.8500715813900404
#         R2 score FS (Train): 0.7286715170484905
#         R2 score FS (Test): 0.6864732329437795
#     Trying order: 16
#         R2 score OSA (Train): 0.9355722835363898
#         R2 score OSA (Test): 0.8496467012385707
#         R2 score FS (Train): 0.7291342229973511
#         R2 score FS (Test): 0.6963062735399852
#     Trying order: 17
#         R2 score OSA (Train): 0.9317439296464262
#         R2 score OSA (Test): 0.8507288011257572
#         R2 score FS (Train): 0.7111245610153487
#         R2 score FS (Test): 0.6762535897792822
#     Trying order: 18
#         R2 score OSA (Train): 0.9538908039944481
#         R2 score OSA (Test): 0.8582840631150566
#         R2 score FS (Train): 0.7152197781875844
#         R2 score FS (Test): 0.6875122047058057
#     Trying order: 19
#         R2 score OSA (Train): 0.9346195515121972
#         R2 score OSA (Test): 0.8527506010684094
#         R2 score FS (Train): 0.7014692324207599
#         R2 score FS (Test): 0.6694369303548487
#     Trying order: 20
#         R2 score OSA (Train): 0.9391500601186112
#         R2 score OSA (Test): 0.8470690034923004
#         R2 score FS (Train): 0.752582076963709
#         R2 score FS (Test): 0.7141822756419542
#
#     Tempo de execução: 5:45:14.507246
#     Best Order: 20
#     R2 score OSA (Train): 0.9391500601186112
#     R2 score OSA (Test): 0.8470690034923004
#     R2 score FS (Train): 0.752582076963709
#     R2 score FS (Test): 0.7141822756419542
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.916923296278641
#         R2 score OSA (Test): 0.8386947961358422
#         R2 score FS (Train): 0.6566697998458202
#         R2 score FS (Test): 0.6231755748296668
#     Trying order: 3
#         R2 score OSA (Train): 0.9148389875894417
#         R2 score OSA (Test): 0.8358960789739636
#         R2 score FS (Train): 0.6744407018337586
#         R2 score FS (Test): 0.623704077527097
#     Trying order: 4
#         R2 score OSA (Train): 0.928010437120395
#         R2 score OSA (Test): 0.8390816414664486
#         R2 score FS (Train): 0.675246026202728
#         R2 score FS (Test): 0.608288404302522
#     Trying order: 5
#         R2 score OSA (Train): 0.939038516230537
#         R2 score OSA (Test): 0.8445664705834117
#         R2 score FS (Train): 0.6997214216258004
#         R2 score FS (Test): 0.654719025759229
#     Trying order: 6
#         R2 score OSA (Train): 0.9282114802737961
#         R2 score OSA (Test): 0.8386632699811664
#         R2 score FS (Train): 0.6322509372757203
#         R2 score FS (Test): 0.5894673724426363
#     Trying order: 7
#         R2 score OSA (Train): 0.9292053879114193
#         R2 score OSA (Test): 0.844037139555643
#         R2 score FS (Train): 0.6803404362610428
#         R2 score FS (Test): 0.6174657357851447
#     Trying order: 8
#         R2 score OSA (Train): 0.9269931466304746
#         R2 score OSA (Test): 0.8359202687587205
#         R2 score FS (Train): 0.6631825897958374
#         R2 score FS (Test): 0.6106043218666688
#     Trying order: 9
#         R2 score OSA (Train): 0.9319407239060871
#         R2 score OSA (Test): 0.8488222099533719
#         R2 score FS (Train): 0.696740040104086
#         R2 score FS (Test): 0.643070595594129
#     Trying order: 10
#         R2 score OSA (Train): 0.9323655750186322
#         R2 score OSA (Test): 0.8457648599770484
#         R2 score FS (Train): 0.6494447165423378
#         R2 score FS (Test): 0.6098410597979955
#     Trying order: 11
#         R2 score OSA (Train): 0.9386654695119524
#         R2 score OSA (Test): 0.8502469560786292
#         R2 score FS (Train): 0.6820575708786132
#         R2 score FS (Test): 0.6265270941499834
#     Trying order: 12
#         R2 score OSA (Train): 0.9369968661088592
#         R2 score OSA (Test): 0.8474722682823246
#         R2 score FS (Train): 0.709657621765639
#         R2 score FS (Test): 0.6730750812743913
#     Trying order: 13
#         R2 score OSA (Train): 0.9369695940476754
#         R2 score OSA (Test): 0.845679153415531
#         R2 score FS (Train): 0.694718031791135
#         R2 score FS (Test): 0.6568187755200887
#     Trying order: 14
#         R2 score OSA (Train): 0.937879566951936
#         R2 score OSA (Test): 0.8526857064177685
#         R2 score FS (Train): 0.6781762510345914
#         R2 score FS (Test): 0.6167549402548743
#     Trying order: 15
#         R2 score OSA (Train): 0.9332559374998117
#         R2 score OSA (Test): 0.8552286804598893
#         R2 score FS (Train): 0.6822219556633077
#         R2 score FS (Test): 0.6551349255523526
#     Trying order: 16
#         R2 score OSA (Train): 0.9374394480599639
#         R2 score OSA (Test): 0.8517069255103562
#         R2 score FS (Train): 0.6663903391811634
#         R2 score FS (Test): 0.6227389538233625
#     Trying order: 17
#         R2 score OSA (Train): 0.9382581309234761
#         R2 score OSA (Test): 0.8565363108507726
#         R2 score FS (Train): 0.6845571062207698
#         R2 score FS (Test): 0.6475069913809063
#     Trying order: 18
#         R2 score OSA (Train): 0.9503341918983312
#         R2 score OSA (Test): 0.8633968319906141
#         R2 score FS (Train): 0.7314939841591585
#         R2 score FS (Test): 0.7037276621367912
#     Trying order: 19
#         R2 score OSA (Train): 0.9491110469441005
#         R2 score OSA (Test): 0.8640199512816623
#         R2 score FS (Train): 0.7054911675952746
#         R2 score FS (Test): 0.6697469217222656
#     Trying order: 20
#         R2 score OSA (Train): 0.9516168716207541
#         R2 score OSA (Test): 0.8621033370830081
#         R2 score FS (Train): 0.7422286463417317
#         R2 score FS (Test): 0.7009914698365864
#
#     Tempo de execução: 6:01:41.084305
#     Best Order: 20
#     R2 score OSA (Train): 0.9516168716207541
#     R2 score OSA (Test): 0.8621033370830081
#     R2 score FS (Train): 0.7422286463417317
#     R2 score FS (Test): 0.7009914698365864
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.9392890823835013
#         R2 score OSA (Test): 0.8556830608058397
#         R2 score FS (Train): 0.7249471442721336
#         R2 score FS (Test): 0.6800694677620049
#     Trying order: 3
#         R2 score OSA (Train): 0.9729854183084033
#         R2 score OSA (Test): 0.8776240976356295
#         R2 score FS (Train): 0.735922176510716
#         R2 score FS (Test): 0.7018214796820765
#     Trying order: 4
#         R2 score OSA (Train): 0.9754845475451176
#         R2 score OSA (Test): 0.8796544388939376
#         R2 score FS (Train): 0.7207507365009518
#         R2 score FS (Test): 0.6881569643959948
#     Trying order: 5
#         R2 score OSA (Train): 0.979805951681285
#         R2 score OSA (Test): 0.8777265492969801
#         R2 score FS (Train): 0.7446607565290148
#         R2 score FS (Test): 0.6968225848664303
#     Trying order: 6
#         R2 score OSA (Train): 0.964009552106933
#         R2 score OSA (Test): 0.8673237382820946
#         R2 score FS (Train): 0.735445431887205
#         R2 score FS (Test): 0.6825276930931412
#     Trying order: 7
#         R2 score OSA (Train): 0.9820515289798973
#         R2 score OSA (Test): 0.8770434639099617
#         R2 score FS (Train): 0.7368420380135727
#         R2 score FS (Test): 0.702728546838282
#     Trying order: 8
#         R2 score OSA (Train): 0.9843841368725962
#         R2 score OSA (Test): 0.8794123828374896
#         R2 score FS (Train): 0.7490561023962216
#         R2 score FS (Test): 0.7101332683372628
#     Trying order: 9
#         R2 score OSA (Train): 0.9685618092206835
#         R2 score OSA (Test): 0.8697802655175759
#         R2 score FS (Train): 0.7341048389755409
#         R2 score FS (Test): 0.6933605384273385
#     Trying order: 10
#         R2 score OSA (Train): 0.9861508089770195
#         R2 score OSA (Test): 0.8858316948652983
#         R2 score FS (Train): 0.7508382008187702
#         R2 score FS (Test): 0.7202212707463918
#     Trying order: 11
#         R2 score OSA (Train): 0.9858826614472534
#         R2 score OSA (Test): 0.888650141723463
#         R2 score FS (Train): 0.7452134045256793
#         R2 score FS (Test): 0.7193646077326405
#     Trying order: 12
#         R2 score OSA (Train): 0.9190449319454994
#         R2 score OSA (Test): 0.8466547318400296
#         R2 score FS (Train): 0.7189720081769349
#         R2 score FS (Test): 0.6788336467700282
#     Trying order: 13
#         R2 score OSA (Train): 0.9864933563465033
#         R2 score OSA (Test): 0.8903606095526758
#         R2 score FS (Train): 0.759937772558805
#         R2 score FS (Test): 0.7323875555070823
#     Trying order: 14
#         R2 score OSA (Train): 0.9738167169709648
#         R2 score OSA (Test): 0.8792461159316807
#         R2 score FS (Train): 0.7619479997066831
#         R2 score FS (Test): 0.7327436321170734
#     Trying order: 15
#         R2 score OSA (Train): 0.9666725823827788
#         R2 score OSA (Test): 0.8692316700345535
#         R2 score FS (Train): 0.7670603497317219
#         R2 score FS (Test): 0.7329772400449958
#     Trying order: 16
#         R2 score OSA (Train): 0.965642278266194
#         R2 score OSA (Test): 0.8661832247479714
#         R2 score FS (Train): 0.7652363882302771
#         R2 score FS (Test): 0.7324151116199852
#     Trying order: 17
#         R2 score OSA (Train): 0.9750150329777689
#         R2 score OSA (Test): 0.8741717825381995
#         R2 score FS (Train): 0.7551193968557312
#         R2 score FS (Test): 0.7126643167802921
#     Trying order: 18
#         R2 score OSA (Train): 0.9763883465585484
#         R2 score OSA (Test): 0.8739063036337327
#         R2 score FS (Train): 0.7555750351729158
#         R2 score FS (Test): 0.7247277876133396
#     Trying order: 19
#         R2 score OSA (Train): 0.9690606642097327
#         R2 score OSA (Test): 0.8680893770176751
#         R2 score FS (Train): 0.764201708143588
#         R2 score FS (Test): 0.7206740700233853
#     Trying order: 20
#         R2 score OSA (Train): 0.9754520215086017
#         R2 score OSA (Test): 0.8736778382127472
#         R2 score FS (Train): 0.7652015113043051
#         R2 score FS (Test): 0.7257375701847364
#
#     Tempo de execução: 8:22:00.371716
#     Best Order: 15
#     R2 score OSA (Train): 0.9666725823827788
#     R2 score OSA (Test): 0.8692316700345535
#     R2 score FS (Train): 0.7670603497317219
#     R2 score FS (Test): 0.7329772400449958
#
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.93619765885926
#         R2 score OSA (Test): 0.8102149302429128
#         R2 score FS (Train): 0.6744013211433413
#         R2 score FS (Test): 0.5908374028090264
#     Trying order: 3
#         R2 score OSA (Train): 0.9315979781926088
#         R2 score OSA (Test): 0.630120735483465
#         R2 score FS (Train): 0.7248686712107191
#         R2 score FS (Test): 0.37759170701246625
#     Trying order: 4
#         R2 score OSA (Train): 0.934279414685196
#         R2 score OSA (Test): 0.6411379066110441
#         R2 score FS (Train): 0.6872528351379175
#         R2 score FS (Test): 0.4778731948349242
#     Trying order: 5
#         R2 score OSA (Train): 0.9613783790284312
#         R2 score OSA (Test): 0.6621370196660932
#         R2 score FS (Train): 0.6935531022974297
#         R2 score FS (Test): 0.4756235964218065
#     Trying order: 6
#         R2 score OSA (Train): 0.9762872227770355
#         R2 score OSA (Test): 0.7435274615908569
#         R2 score FS (Train): 0.7020897411997885
#         R2 score FS (Test): 0.6024126801978998
#     Trying order: 7
#         R2 score OSA (Train): 0.9671190441619344
#         R2 score OSA (Test): 0.6500708856229814
#         R2 score FS (Train): 0.7394537515306796
#         R2 score FS (Test): 0.5465350120966692
#     Trying order: 8
#         R2 score OSA (Train): 0.9803737269089051
#         R2 score OSA (Test): 0.4684135360071897
#         R2 score FS (Train): 0.7557952717998084
#         R2 score FS (Test): 0.3542408964028916
#     Trying order: 9
#         R2 score OSA (Train): 0.9634027776243748
#         R2 score OSA (Test): 0.5843709931218695
#         R2 score FS (Train): 0.7102067270164528
#         R2 score FS (Test): 0.5118786212933253
#     Trying order: 10
#         R2 score OSA (Train): 0.9733429460639201
#         R2 score OSA (Test): 0.5535270084248156
#         R2 score FS (Train): 0.7141507710201109
#         R2 score FS (Test): 0.38174369610609327
#     Trying order: 11
#         R2 score OSA (Train): 0.9839087630306796
#         R2 score OSA (Test): 0.4561460497133749
#         R2 score FS (Train): 0.7596723360739549
#         R2 score FS (Test): 0.2975279159144897
#     Trying order: 12
#         R2 score OSA (Train): 0.9405146421293084
#         R2 score OSA (Test): 0.5863710763159472
#         R2 score FS (Train): 0.7021905296098561
#         R2 score FS (Test): 0.4422499831770932
#     Trying order: 13
#         R2 score OSA (Train): 0.9730684810263763
#         R2 score OSA (Test): 0.6010676024841648
#         R2 score FS (Train): 0.7301720348722476
#         R2 score FS (Test): 0.4459684396869268
#     Trying order: 14
#         R2 score OSA (Train): 0.9763406102768601
#         R2 score OSA (Test): 0.6013225907131763
#         R2 score FS (Train): 0.7235708053117821
#         R2 score FS (Test): 0.48460638235380427
#     Trying order: 15
#         R2 score OSA (Train): 0.9265981458424936
#         R2 score OSA (Test): 0.5603039062529984
#         R2 score FS (Train): 0.7122382251192914
#         R2 score FS (Test): 0.4969289647542986
#     Trying order: 16
#         R2 score OSA (Train): 0.9840283460029182
#         R2 score OSA (Test): 0.46859082456187473
#         R2 score FS (Train): 0.7354081560748201
#         R2 score FS (Test): 0.29552405188581143
#     Trying order: 17
#         R2 score OSA (Train): 0.9701933676293467
#         R2 score OSA (Test): 0.4831895336456621
#         R2 score FS (Train): 0.6750699141130436
#         R2 score FS (Test): 0.3381207328543988
#     Trying order: 18
#         R2 score OSA (Train): 0.9732070670167882
#         R2 score OSA (Test): 0.5263324932262919
#         R2 score FS (Train): 0.7377836495201303
#         R2 score FS (Test): 0.3700825375538982
#     Trying order: 19
#         R2 score OSA (Train): 0.9745926841966832
#         R2 score OSA (Test): 0.3943751992368032
#         R2 score FS (Train): 0.71555012541202
#         R2 score FS (Test): 0.20638432339025448
#     Trying order: 20
#         R2 score OSA (Train): 0.9895932721338556
#         R2 score OSA (Test): 0.5650975088704167
#         R2 score FS (Train): 0.7538014658165575
#         R2 score FS (Test): 0.4366380693247277
#
#     Tempo de execução: 7:45:17.004607
#     Best Order: 11
#     R2 score OSA (Train): 0.9839087630306796
#     R2 score OSA (Test): 0.4561460497133749
#     R2 score FS (Train): 0.7596723360739549
#     R2 score FS (Test): 0.2975279159144897

# %%
pd.DataFrame(results)
# Out:
#               MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS
# 0               SVM     12      0.791310     0.723135     0.665182  \
# 1               KNN     13      1.000000     0.780816     0.783727
# 2      DecisionTree      5      0.849917     0.746337     0.547439
# 3      RandomForest     20      0.939150     0.847069     0.752582
# 4  GradientBoosting     20      0.951617     0.862103     0.742229
# 5        ExtraTrees     15      0.966673     0.869232     0.767060
# 6               MLP     11      0.983909     0.456146     0.759672
#
#    R2 TEST FS                                          MODEL OBJ  PARS
# 0    0.624918  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 1    0.665961  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 2    0.508974  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 3    0.714182  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 4    0.700991  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 5    0.732977  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 6    0.297528  SYSIDRegressor(estimator=RandomizedSearchCV(cv...  None

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#     MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS  R2 TEST FS
# 0     SVM      2      0.754727     0.742235     0.570285    0.579230  \
# 1     SVM      3      0.754634     0.734698     0.582067    0.589971
# 2     SVM      4      0.775391     0.736483     0.625882    0.612451
# 3     SVM      5      0.770323     0.725786     0.621231    0.596677
# 4     SVM      6      0.766225     0.736408     0.604106    0.595440
# ..    ...    ...           ...          ...          ...         ...
# 128   MLP     16      0.984028     0.468591     0.735408    0.295524
# 129   MLP     17      0.970193     0.483190     0.675070    0.338121
# 130   MLP     18      0.973207     0.526332     0.737784    0.370083
# 131   MLP     19      0.974593     0.394375     0.715550    0.206384
# 132   MLP     20      0.989593     0.565098     0.753801    0.436638
#
#                                              MODEL OBJ
# 0    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 1    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 2    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 3    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 4    SYSIDRegressor(estimator=MultiOutputRegressor(...
# ..                                                 ...
# 128  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 129  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 130  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 131  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 132  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
#
# [133 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[data_filt['R2 TEST FS'] >= 0]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', 'test_runs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/outputs/test_runs/MISO-Seasonal.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# None

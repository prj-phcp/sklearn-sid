# %% [markdown]
# # SYSID - Trabalho (ML - SISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import copy
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.multioutput import MultiOutputRegressor

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

#Seasonal decomposition
from statsmodels.tsa.seasonal import seasonal_decompose

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %%
import sys
sys.path.insert(0, os.path.abspath('..'))
from sklearn_sid.regressors.sklearn import SYSIDRegressor

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/data/volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        #'AVG_DOWNHOLE_PRESSURE',
        #'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        #'AVG_WHT_P',
        #'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        #'BORE_OIL_VOL',
        'BORE_LIQ_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 1) (718, 1)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X_tr = X_scale.fit_transform(X1_tr)
X_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ### 1.4 - Decompondo a série

# %%
decomp = seasonal_decompose(y_te, model='additive', period=15, extrapolate_trend='freq')
fig = decomp.plot()

# %%
y_te = np.vstack([
    decomp.trend,
    decomp.seasonal,
    decomp.resid,
]).T

y_tr = y_te[:n_train,:]

print(y_tr.shape, y_te.shape)
# Out:
# (502, 3) (718, 3)

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %%
basis_function = Polynomial(degree=1)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)

models.append(('ARMAX', model))

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %%
basis_function = Polynomial(degree=2)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)
models.append(('NARMAX', model))

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    if model[0] == 'MLP':
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=rdmsearch, 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    else:
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=MultiOutputRegressor(rdmsearch, n_jobs=1), 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

#models = models[-1:]

# %%
for model in models:
    print(model[0])
# Out:
# ARMAX
# NARMAX
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'SISO-Seasonal.W1'
#Loop principal, iterando sobre as listas
for model in models[4:]:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1).sum(axis=1))
        r2_te_osa = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te, steps_ahead=1).sum(axis=1))
        try:
            r2_tr_fs = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr).sum(axis=1))
            r2_te_fs = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te).sum(axis=1))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = copy.deepcopy(sidmodel)
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(copy.deepcopy(sidmodel))
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr.sum(axis=1), label='Train')
    hist = ax[0].plot(best_model.predict(X1_tr, y=y_tr).sum(axis=1), label='Model') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,:].sum(axis=1), label='Test')
    hist = ax[1].plot(best_model.predict(X1_te, y=y_te)[n_train:,:].sum(axis=1), label='Model')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs', 'test_runs',f'{prefix}_{model_name}.pdf'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(best_model)
    try:
        results['PARS'].append(None)
    except Exception:
        results['PARS'].append(best_model.final_model)
# Out:
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.7948798255358165
#         R2 score OSA (Test): 0.7930569761637656
#         R2 score FS (Train): 0.35160208904068546
#         R2 score FS (Test): 0.3758325144886555
#     Trying order: 3
#         R2 score OSA (Train): 0.7753154738086675
#         R2 score OSA (Test): 0.7729813253000647
#         R2 score FS (Train): -0.7453757032835886
#         R2 score FS (Test): -0.7137210369140792
#     Trying order: 4
#         R2 score OSA (Train): 0.8017750396393639
#         R2 score OSA (Test): 0.7964005172983474
#         R2 score FS (Train): 0.18850717351094826
#         R2 score FS (Test): 0.1969364699688645
#     Trying order: 5
#         R2 score OSA (Train): 0.8337430783195463
#         R2 score OSA (Test): 0.8187132102880897
#         R2 score FS (Train): 0.3549214351641342
#         R2 score FS (Test): 0.36720904883853045
#     Trying order: 6
#         R2 score OSA (Train): 0.8120475950326782
#         R2 score OSA (Test): 0.8036809015215316
#         R2 score FS (Train): 0.24737658047522437
#         R2 score FS (Test): 0.2523031933101615
#     Trying order: 7
#         R2 score OSA (Train): 0.8358188382958278
#         R2 score OSA (Test): 0.831532898021904
#         R2 score FS (Train): 0.3226281404161252
#         R2 score FS (Test): 0.3359190029281086
#     Trying order: 8
#         R2 score OSA (Train): 0.8561278800801093
#         R2 score OSA (Test): 0.8581350710196131
#         R2 score FS (Train): 0.20497517973716517
#         R2 score FS (Test): 0.23090937431770198
#     Trying order: 9
#         R2 score OSA (Train): 0.8862941949354884
#         R2 score OSA (Test): 0.8790841314360698
#         R2 score FS (Train): -267441740.99438602
#         R2 score FS (Test): -536096237.6371246
#     Trying order: 10
#         R2 score OSA (Train): 0.8892658993407181
#         R2 score OSA (Test): 0.8758826120463268
#         R2 score FS (Train): -183768.07363602656
#         R2 score FS (Test): -302232.13194898417
#     Trying order: 11
#         R2 score OSA (Train): 0.9037935181538198
#         R2 score OSA (Test): 0.8957872794555843
#         R2 score FS (Train): -8083664.262744618
#         R2 score FS (Test): -326146116.9324127
#     Trying order: 12
#         R2 score OSA (Train): 0.9056625501420553
#         R2 score OSA (Test): 0.8969528015591884
#         R2 score FS (Train): -554082.522359399
#         R2 score FS (Test): -12524094.117729662
#     Trying order: 13
#         R2 score OSA (Train): 0.9247158710383042
#         R2 score OSA (Test): 0.921054270296259
#         R2 score FS (Train): -58227842945.48935
#         R2 score FS (Test): -1308637509518009.2
#     Trying order: 14
#         R2 score OSA (Train): 0.9367834462188038
#         R2 score OSA (Test): 0.93683030529532
#         R2 score FS (Train): -6.375815199326475e+20
#         R2 score FS (Test): -5.912603529619444e+29
#     Trying order: 15
#         R2 score OSA (Train): 0.9367053148741837
#         R2 score OSA (Test): 0.9377378948520309
#         R2 score FS (Train): -1.115265851639031e+19
#         R2 score FS (Test): -6.602111494247522e+26
#     Trying order: 16
#         R2 score OSA (Train): 0.9371050477649201
#         R2 score OSA (Test): 0.9345902035831741
#         R2 score FS (Train): -8.721896976533706e+17
#         R2 score FS (Test): -1.4169142123638237e+25
#     Trying order: 17
#         R2 score OSA (Train): 0.9276193228888843
#         R2 score OSA (Test): 0.925429625405454
#         R2 score FS (Train): -6.850528424638804e+18
#         R2 score FS (Test): -2.479820910029643e+26
#     Trying order: 18
#         R2 score OSA (Train): 0.9252490609414834
#         R2 score OSA (Test): 0.9224871799487119
#         R2 score FS (Train): -9.419293000452803e+17
#         R2 score FS (Test): -2.3680815658690823e+25
#     Trying order: 19
#         R2 score OSA (Train): 0.9258553349556462
#         R2 score OSA (Test): 0.9223480075311139
#         R2 score FS (Train): -7610678412223.914
#         R2 score FS (Test): -6.988192807571355e+17
#     Trying order: 20
#         R2 score OSA (Train): 0.9243940515623938
#         R2 score OSA (Test): 0.9220519329148243
#         R2 score FS (Train): -5034137952783433.0
#         R2 score FS (Test): -1.583820556023711e+22
#
#     Tempo de execução: 0:07:35.414437
#     Best Order: 5
#     R2 score OSA (Train): 0.8337430783195463
#     R2 score OSA (Test): 0.8187132102880897
#     R2 score FS (Train): 0.3549214351641342
#     R2 score FS (Test): 0.36720904883853045
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 1.0
#         R2 score OSA (Test): 0.9332675492711701
#         R2 score FS (Train): 0.2713894736802681
#         R2 score FS (Test): 0.30742727180990725
#     Trying order: 3
#         R2 score OSA (Train): 1.0
#         R2 score OSA (Test): 0.9260057435034433
#         R2 score FS (Train): 0.27263248701414755
#         R2 score FS (Test): 0.27577314789965857
#     Trying order: 4
#         R2 score OSA (Train): 0.999999999999931
#         R2 score OSA (Test): 0.9340285274923961
#         R2 score FS (Train): 0.1763677349810835
#         R2 score FS (Test): 0.22449878807943435
#     Trying order: 5
#         R2 score OSA (Train): 0.9999999999999281
#         R2 score OSA (Test): 0.9194065224372725
#         R2 score FS (Train): 0.316774519892129
#         R2 score FS (Test): 0.3295208040825851
#     Trying order: 6
#         R2 score OSA (Train): 0.999999999999973
#         R2 score OSA (Test): 0.9155211202450756
#         R2 score FS (Train): 0.39587782631044455
#         R2 score FS (Test): 0.4303626806718511
#     Trying order: 7
#         R2 score OSA (Train): 0.999999999999975
#         R2 score OSA (Test): 0.9194249556818381
#         R2 score FS (Train): 0.4969968183459532
#         R2 score FS (Test): 0.522093311493221
#     Trying order: 8
#         R2 score OSA (Train): 0.9999999999999777
#         R2 score OSA (Test): 0.9209898823844883
#         R2 score FS (Train): 0.5178418347818663
#         R2 score FS (Test): 0.5422305825356115
#     Trying order: 9
#         R2 score OSA (Train): 0.999999999999987
#         R2 score OSA (Test): 0.9208444070406804
#         R2 score FS (Train): 0.5216126697391071
#         R2 score FS (Test): 0.5548724175023179
#     Trying order: 10
#         R2 score OSA (Train): 0.9999999999999865
#         R2 score OSA (Test): 0.9196287974703059
#         R2 score FS (Train): 0.5273709784999431
#         R2 score FS (Test): 0.5630678828814408
#     Trying order: 11
#         R2 score OSA (Train): 0.9999999999999893
#         R2 score OSA (Test): 0.9166309793590054
#         R2 score FS (Train): 0.5355061815151317
#         R2 score FS (Test): 0.5656189974404187
#     Trying order: 12
#         R2 score OSA (Train): 0.9999999999999711
#         R2 score OSA (Test): 0.9105806792818154
#         R2 score FS (Train): 0.5296357250349684
#         R2 score FS (Test): 0.5610735679951702
#     Trying order: 13
#         R2 score OSA (Train): 0.9999999999999811
#         R2 score OSA (Test): 0.910079918962046
#         R2 score FS (Train): 0.5509761425883803
#         R2 score FS (Test): 0.5837793278140342
#     Trying order: 14
#         R2 score OSA (Train): 0.9999999999999866
#         R2 score OSA (Test): 0.9024948244709123
#         R2 score FS (Train): 0.5194439429850357
#         R2 score FS (Test): 0.5648073219688997
#     Trying order: 15
#         R2 score OSA (Train): 0.999999999999988
#         R2 score OSA (Test): 0.9174559743601157
#         R2 score FS (Train): 0.5809373476476047
#         R2 score FS (Test): 0.598875757551929
#     Trying order: 16
#         R2 score OSA (Train): 0.999999999999987
#         R2 score OSA (Test): 0.9112204040833467
#         R2 score FS (Train): 0.5754369404808268
#         R2 score FS (Test): 0.6092557564104235
#     Trying order: 17
#         R2 score OSA (Train): 0.9999999999999932
#         R2 score OSA (Test): 0.8956979901975066
#         R2 score FS (Train): 0.548586174478196
#         R2 score FS (Test): 0.5756798304086304
#     Trying order: 18
#         R2 score OSA (Train): 0.9999999999999792
#         R2 score OSA (Test): 0.9100323536354893
#         R2 score FS (Train): 0.565259604064045
#         R2 score FS (Test): 0.5960608929188661
#     Trying order: 19
#         R2 score OSA (Train): 0.9999999999999843
#         R2 score OSA (Test): 0.9141580619150813
#         R2 score FS (Train): 0.5863821118431334
#         R2 score FS (Test): 0.6148816409331674
#     Trying order: 20
#         R2 score OSA (Train): 0.9999999999999865
#         R2 score OSA (Test): 0.9066454194615877
#         R2 score FS (Train): 0.5973697360564794
#         R2 score FS (Test): 0.6095667199268824
#
#     Tempo de execução: 0:06:54.578039
#     Best Order: 20
#     R2 score OSA (Train): 0.9999999999999865
#     R2 score OSA (Test): 0.9066454194615877
#     R2 score FS (Train): 0.5973697360564794
#     R2 score FS (Test): 0.6095667199268824
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.8544994611523686
#         R2 score OSA (Test): 0.8458737415758728
#         R2 score FS (Train): -0.5061268775196781
#         R2 score FS (Test): -0.5453340588380868
#     Trying order: 3
#         R2 score OSA (Train): 0.8609645550135792
#         R2 score OSA (Test): 0.84802669314504
#         R2 score FS (Train): 0.4878572471524021
#         R2 score FS (Test): 0.5063185063086033
#     Trying order: 4
#         R2 score OSA (Train): 0.8762865651289697
#         R2 score OSA (Test): 0.8519977255534168
#         R2 score FS (Train): 0.3160862857835972
#         R2 score FS (Test): 0.34214769099675024
#     Trying order: 5
#         R2 score OSA (Train): 0.8594384023936922
#         R2 score OSA (Test): 0.8493639438398121
#         R2 score FS (Train): 0.22723173743008884
#         R2 score FS (Test): 0.20190994180748423
#     Trying order: 6
#         R2 score OSA (Train): 0.8363264588218047
#         R2 score OSA (Test): 0.8257193080072501
#         R2 score FS (Train): 0.3422940642700997
#         R2 score FS (Test): 0.336348862822749
#     Trying order: 7
#         R2 score OSA (Train): 0.8666520193437584
#         R2 score OSA (Test): 0.8269841189690849
#         R2 score FS (Train): -0.04472236345733771
#         R2 score FS (Test): -0.08486736133073935
#     Trying order: 8
#         R2 score OSA (Train): 0.882475260383647
#         R2 score OSA (Test): 0.8590942272075587
#         R2 score FS (Train): 0.21427398965379485
#         R2 score FS (Test): 0.21576351797234583
#     Trying order: 9
#         R2 score OSA (Train): 0.8493573215551871
#         R2 score OSA (Test): 0.8403588320564984
#         R2 score FS (Train): 0.339629918358195
#         R2 score FS (Test): 0.3229573910654615
#     Trying order: 10
#         R2 score OSA (Train): 0.8557409164226616
#         R2 score OSA (Test): 0.8348707017326267
#         R2 score FS (Train): 0.3551636630132484
#         R2 score FS (Test): 0.34816289703255576
#     Trying order: 11
#         R2 score OSA (Train): 0.8565228149398081
#         R2 score OSA (Test): 0.8375029500435025
#         R2 score FS (Train): -0.22049511137553734
#         R2 score FS (Test): -0.26411167969617444
#     Trying order: 12
#         R2 score OSA (Train): 0.8578737435693633
#         R2 score OSA (Test): 0.8402006572887822
#         R2 score FS (Train): -0.4394016385884927
#         R2 score FS (Test): -0.4769684830878176
#     Trying order: 13
#         R2 score OSA (Train): 0.9257303095619829
#         R2 score OSA (Test): 0.8779198682295
#         R2 score FS (Train): -0.023433345835788932
#         R2 score FS (Test): -0.06386184492699831
#     Trying order: 14
#         R2 score OSA (Train): 0.9307838118264765
#         R2 score OSA (Test): 0.8666602207949655
#         R2 score FS (Train): -0.231886073444304
#         R2 score FS (Test): -0.2835195969134956
#     Trying order: 15
#         R2 score OSA (Train): 0.8606431570835086
#         R2 score OSA (Test): 0.8412625377374141
#         R2 score FS (Train): -0.14485546969746044
#         R2 score FS (Test): -0.16305123142769462
#     Trying order: 16
#         R2 score OSA (Train): 0.8877499939562401
#         R2 score OSA (Test): 0.8651615181669708
#         R2 score FS (Train): 0.14630755718847688
#         R2 score FS (Test): 0.1391952107616662
#     Trying order: 17
#         R2 score OSA (Train): 0.8545779868914334
#         R2 score OSA (Test): 0.8329768316250249
#         R2 score FS (Train): -0.2855459006375094
#         R2 score FS (Test): -0.3330155299984787
#     Trying order: 18
#         R2 score OSA (Train): 0.8487500078702742
#         R2 score OSA (Test): 0.8260927322113498
#         R2 score FS (Train): 0.009775243412456058
#         R2 score FS (Test): -0.015305179722493234
#     Trying order: 19
#         R2 score OSA (Train): 0.9065027609876699
#         R2 score OSA (Test): 0.8630347639485914
#         R2 score FS (Train): -0.1638265821861713
#         R2 score FS (Test): -0.1660303752654717
#     Trying order: 20
#         R2 score OSA (Train): 0.849655594410339
#         R2 score OSA (Test): 0.8232036962627338
#         R2 score FS (Train): 0.0478393110156643
#         R2 score FS (Test): 0.0646213265233474
#
#     Tempo de execução: 0:02:54.952789
#     Best Order: 3
#     R2 score OSA (Train): 0.8609645550135792
#     R2 score OSA (Test): 0.84802669314504
#     R2 score FS (Train): 0.4878572471524021
#     R2 score FS (Test): 0.5063185063086033
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.8616332617708424
#         R2 score OSA (Test): 0.8524657555703857
#         R2 score FS (Train): 0.2864865367214986
#         R2 score FS (Test): 0.3101311403085588
#     Trying order: 3
#         R2 score OSA (Train): 0.8671016046162264
#         R2 score OSA (Test): 0.8576903344096525
#         R2 score FS (Train): 0.22042510927565329
#         R2 score FS (Test): 0.2027755219588837
#     Trying order: 4
#         R2 score OSA (Train): 0.9008471117420466
#         R2 score OSA (Test): 0.8837622249296243
#         R2 score FS (Train): 0.17954988612810974
#         R2 score FS (Test): 0.173531716023116
#     Trying order: 5
#         R2 score OSA (Train): 0.9291930132135615
#         R2 score OSA (Test): 0.9010688808114148
#         R2 score FS (Train): 0.21836929770963043
#         R2 score FS (Test): 0.1946802355205326
#     Trying order: 6
#         R2 score OSA (Train): 0.9388965601377497
#         R2 score OSA (Test): 0.9072356245114095
#         R2 score FS (Train): 0.1954734489847051
#         R2 score FS (Test): 0.18029041029324455
#     Trying order: 7
#         R2 score OSA (Train): 0.9375794228464729
#         R2 score OSA (Test): 0.9085995377569982
#         R2 score FS (Train): 0.11378019374549253
#         R2 score FS (Test): 0.09260312880548804
#     Trying order: 8
#         R2 score OSA (Train): 0.9384434304565213
#         R2 score OSA (Test): 0.9096184542712629
#         R2 score FS (Train): 0.3408676039609948
#         R2 score FS (Test): 0.3544355356957134
#     Trying order: 9
#         R2 score OSA (Train): 0.9433205114462341
#         R2 score OSA (Test): 0.913116572246797
#         R2 score FS (Train): 0.3043503561166484
#         R2 score FS (Test): 0.3239908163688253
#     Trying order: 10
#         R2 score OSA (Train): 0.9445538212988986
#         R2 score OSA (Test): 0.9112555087077999
#         R2 score FS (Train): 0.3288287711483854
#         R2 score FS (Test): 0.29154742536962364
#     Trying order: 11
#         R2 score OSA (Train): 0.944896875528955
#         R2 score OSA (Test): 0.9130069271114498
#         R2 score FS (Train): 0.17919817636775603
#         R2 score FS (Test): 0.17176141318328464
#     Trying order: 12
#         R2 score OSA (Train): 0.942915401905565
#         R2 score OSA (Test): 0.9130086698124218
#         R2 score FS (Train): 0.10737210879721826
#         R2 score FS (Test): 0.12005714733352157
#     Trying order: 13
#         R2 score OSA (Train): 0.9450576958834599
#         R2 score OSA (Test): 0.9156016422592586
#         R2 score FS (Train): 0.3129621785928678
#         R2 score FS (Test): 0.324101744186057
#     Trying order: 14
#         R2 score OSA (Train): 0.9627253925961115
#         R2 score OSA (Test): 0.9273462810196644
#         R2 score FS (Train): 0.3265278833698285
#         R2 score FS (Test): 0.3313003468962189
#     Trying order: 15
#         R2 score OSA (Train): 0.9486939100278905
#         R2 score OSA (Test): 0.9156054823726056
#         R2 score FS (Train): 0.23177064384302803
#         R2 score FS (Test): 0.2427797483320886
#     Trying order: 16
#         R2 score OSA (Train): 0.9436978397952926
#         R2 score OSA (Test): 0.911862355328637
#         R2 score FS (Train): 0.10821896436909795
#         R2 score FS (Test): 0.11540569329983752
#     Trying order: 17
#         R2 score OSA (Train): 0.9605850123907221
#         R2 score OSA (Test): 0.9252448375105174
#         R2 score FS (Train): 0.27930748361144264
#         R2 score FS (Test): 0.3205406037101338
#     Trying order: 18
#         R2 score OSA (Train): 0.9630764011678574
#         R2 score OSA (Test): 0.9266276930096818
#         R2 score FS (Train): 0.22064579841557408
#         R2 score FS (Test): 0.2854341135017828
#     Trying order: 19
#         R2 score OSA (Train): 0.9652224804105707
#         R2 score OSA (Test): 0.9272489066197795
#         R2 score FS (Train): 0.2534396225933625
#         R2 score FS (Test): 0.2596082873521254
#     Trying order: 20
#         R2 score OSA (Train): 0.9627766291437978
#         R2 score OSA (Test): 0.9251552976900088
#         R2 score FS (Train): 0.35508307688088936
#         R2 score FS (Test): 0.3573241654417283
#
#     Tempo de execução: 2:03:03.663618
#     Best Order: 20
#     R2 score OSA (Train): 0.9627766291437978
#     R2 score OSA (Test): 0.9251552976900088
#     R2 score FS (Train): 0.35508307688088936
#     R2 score FS (Test): 0.3573241654417283
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.8732347626318765
#         R2 score OSA (Test): 0.8600848549200856
#         R2 score FS (Train): 0.1543573702048493
#         R2 score FS (Test): 0.22386604760745366
#     Trying order: 3
#         R2 score OSA (Train): 0.8671428415630063
#         R2 score OSA (Test): 0.8585452262738422
#         R2 score FS (Train): 0.18637145623660478
#         R2 score FS (Test): 0.23991625175682996
#     Trying order: 4
#         R2 score OSA (Train): 0.8903940078963883
#         R2 score OSA (Test): 0.8746069566834895
#         R2 score FS (Train): 0.4003079622718453
#         R2 score FS (Test): 0.39263933242194615
#     Trying order: 5
#         R2 score OSA (Train): 0.9374978807150702
#         R2 score OSA (Test): 0.9023499197407522
#         R2 score FS (Train): 0.06675554235745373
#         R2 score FS (Test): 0.15578728197801883
#     Trying order: 6
#         R2 score OSA (Train): 0.9422540287486331
#         R2 score OSA (Test): 0.9057726982829006
#         R2 score FS (Train): 0.24020561412527863
#         R2 score FS (Test): 0.16892767647989115
#     Trying order: 7
#         R2 score OSA (Train): 0.9475780290367889
#         R2 score OSA (Test): 0.914419763405441
#         R2 score FS (Train): 0.35584519493166467
#         R2 score FS (Test): 0.3434117721716249
#     Trying order: 8
#         R2 score OSA (Train): 0.9812272750731025
#         R2 score OSA (Test): 0.9380977767754488
#         R2 score FS (Train): 0.02427011026111714
#         R2 score FS (Test): 0.039622470984297053
#     Trying order: 9
#         R2 score OSA (Train): 0.9805337158670595
#         R2 score OSA (Test): 0.9341116198920559
#         R2 score FS (Train): 0.0857625272549899
#         R2 score FS (Test): 0.10032461357847222
#     Trying order: 10
#         R2 score OSA (Train): 0.9513479568516998
#         R2 score OSA (Test): 0.9196541113776177
#         R2 score FS (Train): 0.3478841919935475
#         R2 score FS (Test): 0.3467921467048992
#     Trying order: 11
#         R2 score OSA (Train): 0.9838470169772557
#         R2 score OSA (Test): 0.9443568416743305
#         R2 score FS (Train): 0.35311192541092395
#         R2 score FS (Test): 0.37521274655842163
#     Trying order: 12
#         R2 score OSA (Train): 0.9826870778064811
#         R2 score OSA (Test): 0.9329770246280817
#         R2 score FS (Train): 0.3450071724254108
#         R2 score FS (Test): 0.33344642573205996
#     Trying order: 13
#         R2 score OSA (Train): 0.982432983572821
#         R2 score OSA (Test): 0.9358707998118162
#         R2 score FS (Train): 0.22452553264261166
#         R2 score FS (Test): 0.18803688268063
#     Trying order: 14
#         R2 score OSA (Train): 0.9855706170861382
#         R2 score OSA (Test): 0.9412894365373664
#         R2 score FS (Train): 0.34181606925191355
#         R2 score FS (Test): 0.35610881201357925
#     Trying order: 15
#         R2 score OSA (Train): 0.9529640281542396
#         R2 score OSA (Test): 0.9158734079336379
#         R2 score FS (Train): 0.24058258646041597
#         R2 score FS (Test): 0.24236381708160426
#     Trying order: 16
#         R2 score OSA (Train): 0.9541334165779061
#         R2 score OSA (Test): 0.9184604805586757
#         R2 score FS (Train): 0.3604966319567645
#         R2 score FS (Test): 0.3633660442046531
#     Trying order: 17
#         R2 score OSA (Train): 0.9823317855011849
#         R2 score OSA (Test): 0.9341984168195177
#         R2 score FS (Train): 0.1601819353057765
#         R2 score FS (Test): 0.16481238261997544
#     Trying order: 18
#         R2 score OSA (Train): 0.9516696639608774
#         R2 score OSA (Test): 0.9156478201584662
#         R2 score FS (Train): 0.219228859845916
#         R2 score FS (Test): 0.27945453868164594
#     Trying order: 19
#         R2 score OSA (Train): 0.9842171698323976
#         R2 score OSA (Test): 0.9415996906666622
#         R2 score FS (Train): 0.2905718802135072
#         R2 score FS (Test): 0.26925820404560674
#     Trying order: 20
#         R2 score OSA (Train): 0.9536602408610569
#         R2 score OSA (Test): 0.9155964335173427
#         R2 score FS (Train): 0.3866393784944433
#         R2 score FS (Test): 0.36959775933043415
#
#     Tempo de execução: 3:03:56.158990
#     Best Order: 4
#     R2 score OSA (Train): 0.8903940078963883
#     R2 score OSA (Test): 0.8746069566834895
#     R2 score FS (Train): 0.4003079622718453
#     R2 score FS (Test): 0.39263933242194615
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.8422764352200306
#         R2 score OSA (Test): 0.8352686471290066
#         R2 score FS (Train): 0.19859715783976528
#         R2 score FS (Test): 0.2245285715706964
#     Trying order: 3
#         R2 score OSA (Train): 0.8394231243965945
#         R2 score OSA (Test): 0.8312903573971131
#         R2 score FS (Train): -0.20805649226037337
#         R2 score FS (Test): -0.20478070636975865
#     Trying order: 4
#         R2 score OSA (Train): 0.8572918292534774
#         R2 score OSA (Test): 0.8461285506486932
#         R2 score FS (Train): 0.019193131329852564
#         R2 score FS (Test): 0.053726193541657086
#     Trying order: 5
#         R2 score OSA (Train): 0.9628117569941248
#         R2 score OSA (Test): 0.9208117662169611
#         R2 score FS (Train): 0.23075442657612555
#         R2 score FS (Test): 0.246262825123306
#     Trying order: 6
#         R2 score OSA (Train): 0.9383584643665693
#         R2 score OSA (Test): 0.9077548915094981
#         R2 score FS (Train): 0.04973332627538174
#         R2 score FS (Test): 0.07894141515842013
#     Trying order: 7
#         R2 score OSA (Train): 0.9557914032869425
#         R2 score OSA (Test): 0.9192263560113738
#         R2 score FS (Train): 0.1678093832646591
#         R2 score FS (Test): 0.22164456680868583
#     Trying order: 8
#         R2 score OSA (Train): 0.9772356570783378
#         R2 score OSA (Test): 0.9347348507298333
#         R2 score FS (Train): -0.02691217756637765
#         R2 score FS (Test): 0.035399526541314175
#     Trying order: 9
#         R2 score OSA (Train): 0.9779676250624496
#         R2 score OSA (Test): 0.9352115239570216
#         R2 score FS (Train): 0.22372920968752041
#         R2 score FS (Test): 0.26579104188485825
#     Trying order: 10
#         R2 score OSA (Train): 0.9528643734593956
#         R2 score OSA (Test): 0.920730444059969
#         R2 score FS (Train): 0.32980578506654445
#         R2 score FS (Test): 0.34459369862657285
#     Trying order: 11
#         R2 score OSA (Train): 0.9801849172646364
#         R2 score OSA (Test): 0.9394706697304038
#         R2 score FS (Train): 0.30902797130335014
#         R2 score FS (Test): 0.3668153130937072
#     Trying order: 12
#         R2 score OSA (Train): 0.9646755027728864
#         R2 score OSA (Test): 0.9284992241372064
#         R2 score FS (Train): 0.2535926097443516
#         R2 score FS (Test): 0.2710642541501791
#     Trying order: 13
#         R2 score OSA (Train): 0.9804880719606766
#         R2 score OSA (Test): 0.9385834488526388
#         R2 score FS (Train): 0.33685510818258
#         R2 score FS (Test): 0.40050627934635985
#     Trying order: 14
#         R2 score OSA (Train): 0.9812593815733122
#         R2 score OSA (Test): 0.9414263782034263
#         R2 score FS (Train): 0.34852823375244824
#         R2 score FS (Test): 0.3821063309719478
#     Trying order: 15
#         R2 score OSA (Train): 0.983363915158914
#         R2 score OSA (Test): 0.9414229376948177
#         R2 score FS (Train): 0.2606687584736024
#         R2 score FS (Test): 0.331519094274743
#     Trying order: 16
#         R2 score OSA (Train): 0.9614051922365997
#         R2 score OSA (Test): 0.9274489368970265
#         R2 score FS (Train): 0.3268605040107815
#         R2 score FS (Test): 0.397185487324785
#     Trying order: 17
#         R2 score OSA (Train): 0.9828525848826973
#         R2 score OSA (Test): 0.9371747784815972
#         R2 score FS (Train): 0.23037772822941172
#         R2 score FS (Test): 0.29255141323148526
#     Trying order: 18
#         R2 score OSA (Train): 0.9836143687568976
#         R2 score OSA (Test): 0.9387955852129587
#         R2 score FS (Train): 0.3456009265773331
#         R2 score FS (Test): 0.4182156860599634
#     Trying order: 19
#         R2 score OSA (Train): 0.9838487456843463
#         R2 score OSA (Test): 0.9395982893351698
#         R2 score FS (Train): 0.24726655965707034
#         R2 score FS (Test): 0.33387899702980395
#     Trying order: 20
#         R2 score OSA (Train): 0.9626854680577437
#         R2 score OSA (Test): 0.9238443386761129
#         R2 score FS (Train): 0.4151367972755421
#         R2 score FS (Test): 0.45632923471284526
#
#     Tempo de execução: 2:57:56.481093
#     Best Order: 20
#     R2 score OSA (Train): 0.9626854680577437
#     R2 score OSA (Test): 0.9238443386761129
#     R2 score FS (Train): 0.4151367972755421
#     R2 score FS (Test): 0.45632923471284526
#
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.8596411798162803
#         R2 score OSA (Test): 0.8452774235241668
#         R2 score FS (Train): -138.62720768079785
#         R2 score FS (Test): -141.20805422835522
#     Trying order: 3
#         R2 score OSA (Train): 0.8880983911854223
#         R2 score OSA (Test): 0.8553849055444867
#         R2 score FS (Train): 0.3900858276884325
#         R2 score FS (Test): 0.41394898036170746
#     Trying order: 4
#         R2 score OSA (Train): 0.9119788517204015
#         R2 score OSA (Test): 0.8912535368524215
#         R2 score FS (Train): 0.37577748781845255
#         R2 score FS (Test): 0.39216271193166086
#     Trying order: 5
#         R2 score OSA (Train): 0.9231481470214185
#         R2 score OSA (Test): 0.8928436550609204
#         R2 score FS (Train): 0.3558734109785161
#         R2 score FS (Test): 0.3849560123529233
#     Trying order: 6
#         R2 score OSA (Train): 0.9391265245823084
#         R2 score OSA (Test): 0.9078933609899126
#         R2 score FS (Train): -1.3153644271409224
#         R2 score FS (Test): -0.7150902024133268
#     Trying order: 7
#         R2 score OSA (Train): 0.9744412836815447
#         R2 score OSA (Test): 0.9344715008240351
#         R2 score FS (Train): -0.18590215090960283
#         R2 score FS (Test): -0.1015928605696812
#     Trying order: 8
#         R2 score OSA (Train): 0.9596492578922716
#         R2 score OSA (Test): 0.9307929542172495
#         R2 score FS (Train): 0.3005616914898602
#         R2 score FS (Test): 0.2789611908026264
#     Trying order: 9
#         R2 score OSA (Train): 0.9597785304970439
#         R2 score OSA (Test): 0.9365006653728654
#         R2 score FS (Train): 0.2688594217457635
#         R2 score FS (Test): 0.3152960652505781
#     Trying order: 10
#         R2 score OSA (Train): 0.9719051547094889
#         R2 score OSA (Test): 0.9369025878308397
#         R2 score FS (Train): -10.80549608005734
#         R2 score FS (Test): -16.494041032106892
#     Trying order: 11
#         R2 score OSA (Train): 0.9657981020032612
#         R2 score OSA (Test): 0.9372117273803487
#         R2 score FS (Train): 0.0362782392323352
#         R2 score FS (Test): -4.0675962499859395
#     Trying order: 12
#         R2 score OSA (Train): 0.9727901198680446
#         R2 score OSA (Test): 0.9376749700761093
#         R2 score FS (Train): 0.21223109109358462
#         R2 score FS (Test): 0.2528114443477768
#     Trying order: 13
#         R2 score OSA (Train): 0.9788730140589981
#         R2 score OSA (Test): 0.9436621676833636
#         R2 score FS (Train): -3.7573717959432837
#         R2 score FS (Test): -8.15050771996521
#     Trying order: 14
#         R2 score OSA (Train): 0.9821319916405354
#         R2 score OSA (Test): 0.9439458036396114
#         R2 score FS (Train): -2.5193014305976473
#         R2 score FS (Test): -2.0165979425268357
#     Trying order: 15
#         R2 score OSA (Train): 0.981907725720807
#         R2 score OSA (Test): 0.9454367286109758
#         R2 score FS (Train): -40.68181517243323
#         R2 score FS (Test): -68.22313804655475
#     Trying order: 16
#         R2 score OSA (Train): 0.9808413993122643
#         R2 score OSA (Test): 0.9412609205025588
#         R2 score FS (Train): -2.8055981378618285e+22
#         R2 score FS (Test): -9.153365311200663e+34
#     Trying order: 17
#         R2 score OSA (Train): 0.9810034971354736
#         R2 score OSA (Test): 0.9489966946661548
#         R2 score FS (Train): -0.35864191511502086
#         R2 score FS (Test): -0.27521278357142687
#     Trying order: 18
#         R2 score OSA (Train): 0.9877347683153241
#         R2 score OSA (Test): 0.9488336300925674
#         R2 score FS (Train): -1.5275347642310102
#         R2 score FS (Test): -1.550983484386717
#     Trying order: 19
#         R2 score OSA (Train): 0.9843455712294699
#         R2 score OSA (Test): 0.9448939111760887
#         R2 score FS (Train): -73.39867771621944
#         R2 score FS (Test): -309.80729197544264
#     Trying order: 20
#         R2 score OSA (Train): 0.9872592749311146
#         R2 score OSA (Test): 0.9515964365035321
#         R2 score FS (Train): -0.10231203602391847
#         R2 score FS (Test): -0.053008688956626804
#
#     Tempo de execução: 4:28:49.342114
#     Best Order: 3
#     R2 score OSA (Train): 0.8880983911854223
#     R2 score OSA (Test): 0.8553849055444867
#     R2 score FS (Train): 0.3900858276884325
#     R2 score FS (Test): 0.41394898036170746

# %%
pd.DataFrame(results)
# Out:
#               MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS
# 0               SVM      5      0.833743     0.818713     0.354921  \
# 1               KNN     20      1.000000     0.906645     0.597370
# 2      DecisionTree      3      0.860965     0.848027     0.487857
# 3      RandomForest     20      0.962777     0.925155     0.355083
# 4  GradientBoosting      4      0.890394     0.874607     0.400308
# 5        ExtraTrees     20      0.962685     0.923844     0.415137
# 6               MLP      3      0.888098     0.855385     0.390086
#
#    R2 TEST FS                                          MODEL OBJ  PARS
# 0    0.367209  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 1    0.609567  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 2    0.506319  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 3    0.357324  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 4    0.392639  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 5    0.456329  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 6    0.413949  SYSIDRegressor(estimator=RandomizedSearchCV(cv...  None

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#     MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA   R2 TRAIN FS    R2 TEST FS
# 0     SVM      2      0.794880     0.793057  3.516021e-01  3.758325e-01  \
# 1     SVM      3      0.775315     0.772981 -7.453757e-01 -7.137210e-01
# 2     SVM      4      0.801775     0.796401  1.885072e-01  1.969365e-01
# 3     SVM      5      0.833743     0.818713  3.549214e-01  3.672090e-01
# 4     SVM      6      0.812048     0.803681  2.473766e-01  2.523032e-01
# ..    ...    ...           ...          ...           ...           ...
# 128   MLP     16      0.980841     0.941261 -2.805598e+22 -9.153365e+34
# 129   MLP     17      0.981003     0.948997 -3.586419e-01 -2.752128e-01
# 130   MLP     18      0.987735     0.948834 -1.527535e+00 -1.550983e+00
# 131   MLP     19      0.984346     0.944894 -7.339868e+01 -3.098073e+02
# 132   MLP     20      0.987259     0.951596 -1.023120e-01 -5.300869e-02
#
#                                              MODEL OBJ
# 0    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 1    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 2    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 3    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 4    SYSIDRegressor(estimator=MultiOutputRegressor(...
# ..                                                 ...
# 128  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 129  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 130  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 131  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 132  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
#
# [133 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[data_filt['R2 TEST FS'] >= 0]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', 'test_runs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/outputs/test_runs/SISO-Decomp.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# None

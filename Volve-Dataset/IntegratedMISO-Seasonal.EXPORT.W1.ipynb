# %% [markdown]
# # SYSID - Trabalho (ML - SISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import copy
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.multioutput import MultiOutputRegressor

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

#Seasonal decomposition
from statsmodels.tsa.seasonal import seasonal_decompose

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %%
import sys
sys.path.insert(0, os.path.abspath('..'))
from sklearn_sid.regressors.sklearn import SYSIDRegressor

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/data/volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        'AVG_DOWNHOLE_PRESSURE',
        'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        'AVG_WHT_P',
        'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        #'BORE_OIL_VOL',
        'BORE_LIQ_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 5) (718, 5)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X_tr = X_scale.fit_transform(X1_tr)
X_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ### 1.4 - Decompondo a série

# %%
decomp = seasonal_decompose(y_te, model='additive', period=15, extrapolate_trend='freq')
fig = decomp.plot()

# %%
y_te = np.vstack([
    decomp.trend,
    decomp.seasonal,
    decomp.resid,
]).T

y_tr = y_te[:n_train,:]

print(y_tr.shape, y_te.shape)
# Out:
# (502, 3) (718, 3)

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %%
basis_function = Polynomial(degree=1)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)

models.append(('ARMAX', model))

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %%
basis_function = Polynomial(degree=2)
n = 2
na = n
nb = [n] * X1.shape[1]
ne = 1
n_terms = 6
model = FROLS(
    order_selection=True,
    ylag=na, xlag=nb,elag=ne,
    basis_function=basis_function,
    n_info_values=100,
    #n_terms=n_terms,
    model_type='NARMAX',
    #extended_least_squares=True,
)
models.append(('NARMAX', model))

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    if model[0] == 'MLP':
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=rdmsearch, 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    else:
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=MultiOutputRegressor(rdmsearch, n_jobs=1), 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

#models = models[-1:]

# %%
for model in models:
    print(model[0])
# Out:
# ARMAX
# NARMAX
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'MISO-Seasonal.W1'
#Loop principal, iterando sobre as listas
for model in models[4:]:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1).sum(axis=1))
        r2_te_osa = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te, steps_ahead=1).sum(axis=1))
        try:
            r2_tr_fs = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr).sum(axis=1))
            r2_te_fs = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te).sum(axis=1))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = copy.deepcopy(sidmodel)
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(copy.deepcopy(sidmodel))
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr.sum(axis=1), label='Train')
    hist = ax[0].plot(best_model.predict(X1_tr, y=y_tr).sum(axis=1), label='Model') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,:].sum(axis=1), label='Test')
    hist = ax[1].plot(best_model.predict(X1_te, y=y_te)[n_train:,:].sum(axis=1), label='Model')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs', 'test_runs',f'{prefix}_{model_name}.pdf'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(best_model)
    try:
        results['PARS'].append(None)
    except Exception:
        results['PARS'].append(best_model.final_model)
# Out:
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.8084903723645827
#         R2 score OSA (Test): 0.7890897119148192
#         R2 score FS (Train): 0.5621290060913309
#         R2 score FS (Test): 0.5605242068532861
#     Trying order: 3
#         R2 score OSA (Train): 0.8259996159745195
#         R2 score OSA (Test): 0.8124521765890819
#         R2 score FS (Train): 0.5789215783676223
#         R2 score FS (Test): 0.5749444674713087
#     Trying order: 4
#         R2 score OSA (Train): 0.8359483359699785
#         R2 score OSA (Test): 0.8200453784547901
#         R2 score FS (Train): 0.5608944662456754
#         R2 score FS (Test): 0.5495014806408711
#     Trying order: 5
#         R2 score OSA (Train): 0.8404904862659346
#         R2 score OSA (Test): 0.819499991555379
#         R2 score FS (Train): 0.5542496201613349
#         R2 score FS (Test): 0.5385851253680906
#     Trying order: 6
#         R2 score OSA (Train): 0.8379404010067886
#         R2 score OSA (Test): 0.815084017354684
#         R2 score FS (Train): 0.5630452144408875
#         R2 score FS (Test): 0.5527077909151512
#     Trying order: 7
#         R2 score OSA (Train): 0.8421440850293485
#         R2 score OSA (Test): 0.8212919552405563
#         R2 score FS (Train): 0.5685961292825084
#         R2 score FS (Test): 0.5655584689781734
#     Trying order: 8
#         R2 score OSA (Train): 0.849074856235653
#         R2 score OSA (Test): 0.8430898018569732
#         R2 score FS (Train): 0.3315255961071851
#         R2 score FS (Test): 0.3814321881885029
#     Trying order: 9
#         R2 score OSA (Train): 0.8727898341826565
#         R2 score OSA (Test): 0.8588742226909026
#         R2 score FS (Train): -20731012.218114253
#         R2 score FS (Test): -31098209.149320766
#     Trying order: 10
#         R2 score OSA (Train): 0.8940519517417288
#         R2 score OSA (Test): 0.8819567054899569
#         R2 score FS (Train): -2238515.51719022
#         R2 score FS (Test): -4355502.6042426275
#     Trying order: 11
#         R2 score OSA (Train): 0.8885631610799714
#         R2 score OSA (Test): 0.8836907440429821
#         R2 score FS (Train): -131826023801.25893
#         R2 score FS (Test): -623496617732841.4
#     Trying order: 12
#         R2 score OSA (Train): 0.8868993835816765
#         R2 score OSA (Test): 0.8771956614058687
#         R2 score FS (Train): -91454245253.28316
#         R2 score FS (Test): -315503065035563.1
#     Trying order: 13
#         R2 score OSA (Train): 0.8953723617884826
#         R2 score OSA (Test): 0.8888156769916332
#         R2 score FS (Train): -1303351059559.7063
#         R2 score FS (Test): -1.85426333582967e+16
#     Trying order: 14
#         R2 score OSA (Train): 0.8983963395923105
#         R2 score OSA (Test): 0.8941402697511716
#         R2 score FS (Train): -3.533762497206967e+19
#         R2 score FS (Test): -9.19062350752766e+27
#     Trying order: 15
#         R2 score OSA (Train): 0.8953010783585431
#         R2 score OSA (Test): 0.8886489533375304
#         R2 score FS (Train): -1679466496542.4517
#         R2 score FS (Test): -5.30261572731774e+16
#     Trying order: 16
#         R2 score OSA (Train): 0.9005395024499149
#         R2 score OSA (Test): 0.8914033541989936
#         R2 score FS (Train): -3936509815076.1855
#         R2 score FS (Test): -2.8738114802095763e+17
#     Trying order: 17
#         R2 score OSA (Train): 0.9000758146028968
#         R2 score OSA (Test): 0.886706665599628
#         R2 score FS (Train): -297587247681.7289
#         R2 score FS (Test): -3436572626501708.0
#     Trying order: 18
#         R2 score OSA (Train): 0.9012528950863661
#         R2 score OSA (Test): 0.884599954426765
#         R2 score FS (Train): -22825496883585.62
#         R2 score FS (Test): -3.196399583340541e+18
#     Trying order: 19
#         R2 score OSA (Train): 0.8930072706095623
#         R2 score OSA (Test): 0.8810269251143193
#         R2 score FS (Train): -104874507345408.03
#         R2 score FS (Test): -6.561607543857637e+19
#     Trying order: 20
#         R2 score OSA (Train): 0.8866410515692024
#         R2 score OSA (Test): 0.8752019871313145
#         R2 score FS (Train): -1219859462394.185
#         R2 score FS (Test): -9.24872389869238e+16
#
#     Tempo de execução: 0:17:02.842124
#     Best Order: 3
#     R2 score OSA (Train): 0.8259996159745195
#     R2 score OSA (Test): 0.8124521765890819
#     R2 score FS (Train): 0.5789215783676223
#     R2 score FS (Test): 0.5749444674713087
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 0.999999999999719
#         R2 score OSA (Test): 0.9270333586668118
#         R2 score FS (Train): 0.6350516614896835
#         R2 score FS (Test): 0.5938516227248354
#     Trying order: 3
#         R2 score OSA (Train): 0.9999999999999226
#         R2 score OSA (Test): 0.9156347324290722
#         R2 score FS (Train): 0.6337980332754651
#         R2 score FS (Test): 0.5920651655071998
#     Trying order: 4
#         R2 score OSA (Train): 0.9999999999998488
#         R2 score OSA (Test): 0.9127029368157835
#         R2 score FS (Train): 0.6434793821853249
#         R2 score FS (Test): 0.5953018665734047
#     Trying order: 5
#         R2 score OSA (Train): 0.9999999999998255
#         R2 score OSA (Test): 0.9061840915999275
#         R2 score FS (Train): 0.661398064372722
#         R2 score FS (Test): 0.6076955363121161
#     Trying order: 6
#         R2 score OSA (Train): 0.9999999999998048
#         R2 score OSA (Test): 0.9019454884900553
#         R2 score FS (Train): 0.6609872523745177
#         R2 score FS (Test): 0.6187329342182466
#     Trying order: 7
#         R2 score OSA (Train): 0.9999999999998592
#         R2 score OSA (Test): 0.9002129728376234
#         R2 score FS (Train): 0.6732183148606996
#         R2 score FS (Test): 0.635807435370759
#     Trying order: 8
#         R2 score OSA (Train): 0.9999999999998401
#         R2 score OSA (Test): 0.9020902122219284
#         R2 score FS (Train): 0.7006312992728935
#         R2 score FS (Test): 0.6649315082626717
#     Trying order: 9
#         R2 score OSA (Train): 0.9999999999999362
#         R2 score OSA (Test): 0.9116196103345453
#         R2 score FS (Train): 0.7032665601478119
#         R2 score FS (Test): 0.6851454868911726
#     Trying order: 10
#         R2 score OSA (Train): 0.9999999999998301
#         R2 score OSA (Test): 0.9145942928927205
#         R2 score FS (Train): 0.7102874952519158
#         R2 score FS (Test): 0.6969973720671223
#     Trying order: 11
#         R2 score OSA (Train): 0.999999999999891
#         R2 score OSA (Test): 0.9141905051949207
#         R2 score FS (Train): 0.707444595590843
#         R2 score FS (Test): 0.6937437221492728
#     Trying order: 12
#         R2 score OSA (Train): 0.9999999999998614
#         R2 score OSA (Test): 0.910827776452572
#         R2 score FS (Train): 0.7143194924291181
#         R2 score FS (Test): 0.6956696469784088
#     Trying order: 13
#         R2 score OSA (Train): 0.9999999999999639
#         R2 score OSA (Test): 0.9020822852700388
#         R2 score FS (Train): 0.7281984002123115
#         R2 score FS (Test): 0.7035912122086097
#     Trying order: 14
#         R2 score OSA (Train): 0.9999999999999333
#         R2 score OSA (Test): 0.9070582687831286
#         R2 score FS (Train): 0.7231866181523245
#         R2 score FS (Test): 0.6840240776096211
#     Trying order: 15
#         R2 score OSA (Train): 0.9999999999999521
#         R2 score OSA (Test): 0.8977682333055705
#         R2 score FS (Train): 0.7095903905419065
#         R2 score FS (Test): 0.6653814427194124
#     Trying order: 16
#         R2 score OSA (Train): 0.9999999999999276
#         R2 score OSA (Test): 0.9023247790562946
#         R2 score FS (Train): 0.7117689698838794
#         R2 score FS (Test): 0.6749462529506611
#     Trying order: 17
#         R2 score OSA (Train): 0.999999999999963
#         R2 score OSA (Test): 0.8980604023439664
#         R2 score FS (Train): 0.7203386472328279
#         R2 score FS (Test): 0.673433520968418
#     Trying order: 18
#         R2 score OSA (Train): 0.9999999999999154
#         R2 score OSA (Test): 0.8968906708020072
#         R2 score FS (Train): 0.7272088608953629
#         R2 score FS (Test): 0.6886277442494466
#     Trying order: 19
#         R2 score OSA (Train): 0.9999999999999516
#         R2 score OSA (Test): 0.8969408248292398
#         R2 score FS (Train): 0.7432952670577379
#         R2 score FS (Test): 0.707951026783173
#     Trying order: 20
#         R2 score OSA (Train): 0.9999999999999325
#         R2 score OSA (Test): 0.8952523783119761
#         R2 score FS (Train): 0.7420138548517734
#         R2 score FS (Test): 0.7027823202132957
#
#     Tempo de execução: 0:07:33.315495
#     Best Order: 19
#     R2 score OSA (Train): 0.9999999999999516
#     R2 score OSA (Test): 0.8969408248292398
#     R2 score FS (Train): 0.7432952670577379
#     R2 score FS (Test): 0.707951026783173
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.8603748908870685
#         R2 score OSA (Test): 0.8352588632535277
#         R2 score FS (Train): -0.4555610158666148
#         R2 score FS (Test): -0.511751388820024
#     Trying order: 3
#         R2 score OSA (Train): 0.8327534274961106
#         R2 score OSA (Test): 0.8237157835599364
#         R2 score FS (Train): -0.7629626985561078
#         R2 score FS (Test): -0.7663707180525992
#     Trying order: 4
#         R2 score OSA (Train): 0.8467454083137943
#         R2 score OSA (Test): 0.8370804152624768
#         R2 score FS (Train): -0.11963002116356414
#         R2 score FS (Test): -0.1691734529735307
#     Trying order: 5
#         R2 score OSA (Train): 0.8839000237568304
#         R2 score OSA (Test): 0.8588007999664773
#         R2 score FS (Train): 0.07636332651704791
#         R2 score FS (Test): 0.08913732619658887
#     Trying order: 6
#         R2 score OSA (Train): 0.8869690347045553
#         R2 score OSA (Test): 0.8576209705221265
#         R2 score FS (Train): -0.04116327602898284
#         R2 score FS (Test): -0.1404175257857363
#     Trying order: 7
#         R2 score OSA (Train): 0.8648954407371247
#         R2 score OSA (Test): 0.8501171762041068
#         R2 score FS (Train): 0.482811397205251
#         R2 score FS (Test): 0.4638532720870515
#     Trying order: 8
#         R2 score OSA (Train): 0.8618455434482606
#         R2 score OSA (Test): 0.8479623376946556
#         R2 score FS (Train): -0.03519918623609164
#         R2 score FS (Test): -0.058223843858897784
#     Trying order: 9
#         R2 score OSA (Train): 0.8512066122490131
#         R2 score OSA (Test): 0.8274494538993966
#         R2 score FS (Train): -0.11113429962392729
#         R2 score FS (Test): 0.06669066909716426
#     Trying order: 10
#         R2 score OSA (Train): 0.8518144276158479
#         R2 score OSA (Test): 0.8274017141256733
#         R2 score FS (Train): -0.09536846689336165
#         R2 score FS (Test): -0.1506600785823502
#     Trying order: 11
#         R2 score OSA (Train): 0.866989088941544
#         R2 score OSA (Test): 0.8559346404866707
#         R2 score FS (Train): -0.022048720175234626
#         R2 score FS (Test): -0.05679798115167234
#     Trying order: 12
#         R2 score OSA (Train): 0.8270012025709175
#         R2 score OSA (Test): 0.8080895065262
#         R2 score FS (Train): 0.22209212283887747
#         R2 score FS (Test): 0.20396019102621643
#     Trying order: 13
#         R2 score OSA (Train): 0.8346703002121164
#         R2 score OSA (Test): 0.825546074454758
#         R2 score FS (Train): -0.04447748053826861
#         R2 score FS (Test): 0.022865235550094898
#     Trying order: 14
#         R2 score OSA (Train): 0.8594138073927635
#         R2 score OSA (Test): 0.8436273888568581
#         R2 score FS (Train): -0.14427741776635616
#         R2 score FS (Test): -0.2058109209915362
#     Trying order: 15
#         R2 score OSA (Train): 0.8774993173015144
#         R2 score OSA (Test): 0.8307874361284856
#         R2 score FS (Train): 0.12620139192482027
#         R2 score FS (Test): 0.08877324283378474
#     Trying order: 16
#         R2 score OSA (Train): 0.880177485861668
#         R2 score OSA (Test): 0.8494119827989779
#         R2 score FS (Train): -0.031968144666087106
#         R2 score FS (Test): -0.02017095777794653
#     Trying order: 17
#         R2 score OSA (Train): 0.886777271746954
#         R2 score OSA (Test): 0.8505116076666248
#         R2 score FS (Train): -0.28818608185106664
#         R2 score FS (Test): -0.17703255799572415
#     Trying order: 18
#         R2 score OSA (Train): 0.8457726251907872
#         R2 score OSA (Test): 0.8322662399188767
#         R2 score FS (Train): 0.04424979788254635
#         R2 score FS (Test): 0.1467472186290344
#     Trying order: 19
#         R2 score OSA (Train): 0.8489510305164063
#         R2 score OSA (Test): 0.8299429183664436
#         R2 score FS (Train): 0.2679469107914991
#         R2 score FS (Test): 0.2706554192238422
#     Trying order: 20
#         R2 score OSA (Train): 0.8369617532847264
#         R2 score OSA (Test): 0.8195385550130967
#         R2 score FS (Train): 0.16493948176002804
#         R2 score FS (Test): 0.2055055000512953
#
#     Tempo de execução: 0:04:31.403675
#     Best Order: 7
#     R2 score OSA (Train): 0.8648954407371247
#     R2 score OSA (Test): 0.8501171762041068
#     R2 score FS (Train): 0.482811397205251
#     R2 score FS (Test): 0.4638532720870515
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.9517999252811224
#         R2 score OSA (Test): 0.9105327571814245
#         R2 score FS (Train): 0.1828564990848991
#         R2 score FS (Test): 0.25681793304500733
#     Trying order: 3
#         R2 score OSA (Train): 0.9560083672839564
#         R2 score OSA (Test): 0.9153271721102535
#         R2 score FS (Train): 0.1794822189810592
#         R2 score FS (Test): 0.02979467963235949
#     Trying order: 4
#         R2 score OSA (Train): 0.9567169488397101
#         R2 score OSA (Test): 0.9140738642397952
#         R2 score FS (Train): 0.49489214409289284
#         R2 score FS (Test): 0.4747688795380459
#     Trying order: 5
#         R2 score OSA (Train): 0.9395584914603222
#         R2 score OSA (Test): 0.9020482731424507
#         R2 score FS (Train): 0.32018458620915446
#         R2 score FS (Test): 0.2961407333718943
#     Trying order: 6
#         R2 score OSA (Train): 0.9393634698452812
#         R2 score OSA (Test): 0.905687171055278
#         R2 score FS (Train): 0.15481589893025727
#         R2 score FS (Test): 0.09382377881312853
#     Trying order: 7
#         R2 score OSA (Train): 0.9477886660928748
#         R2 score OSA (Test): 0.9112645244694255
#         R2 score FS (Train): 0.2899550663565216
#         R2 score FS (Test): 0.3055764732222056
#     Trying order: 8
#         R2 score OSA (Train): 0.9484298528837007
#         R2 score OSA (Test): 0.9114199050113488
#         R2 score FS (Train): 0.47999420872681786
#         R2 score FS (Test): 0.5122302552672542
#     Trying order: 9
#         R2 score OSA (Train): 0.9503647561858601
#         R2 score OSA (Test): 0.9173995545895194
#         R2 score FS (Train): 0.45319786492134073
#         R2 score FS (Test): 0.4782641007467121
#     Trying order: 10
#         R2 score OSA (Train): 0.9411829112729517
#         R2 score OSA (Test): 0.9076708906391118
#         R2 score FS (Train): 0.46861605179142285
#         R2 score FS (Test): 0.4745629545386415
#     Trying order: 11
#         R2 score OSA (Train): 0.9633357078778051
#         R2 score OSA (Test): 0.9224207049873941
#         R2 score FS (Train): 0.3438762112182403
#         R2 score FS (Test): 0.3469359931366204
#     Trying order: 12
#         R2 score OSA (Train): 0.9499609479331333
#         R2 score OSA (Test): 0.9160747835124996
#         R2 score FS (Train): 0.45390173561899816
#         R2 score FS (Test): 0.442206696138972
#     Trying order: 13
#         R2 score OSA (Train): 0.9433220235760869
#         R2 score OSA (Test): 0.9093470549995708
#         R2 score FS (Train): 0.4613299914719694
#         R2 score FS (Test): 0.4853107101455202
#     Trying order: 14
#         R2 score OSA (Train): 0.9632595303647434
#         R2 score OSA (Test): 0.9191963177972257
#         R2 score FS (Train): 0.47855513397105975
#         R2 score FS (Test): 0.5084560462569307
#     Trying order: 15
#         R2 score OSA (Train): 0.9411281578717037
#         R2 score OSA (Test): 0.9056503025243099
#         R2 score FS (Train): 0.4732334617151358
#         R2 score FS (Test): 0.4783117041257422
#     Trying order: 16
#         R2 score OSA (Train): 0.9491700703108953
#         R2 score OSA (Test): 0.9133510468486415
#         R2 score FS (Train): 0.3482623837954928
#         R2 score FS (Test): 0.4012116393898567
#     Trying order: 17
#         R2 score OSA (Train): 0.9484904061452801
#         R2 score OSA (Test): 0.9115184453248705
#         R2 score FS (Train): 0.42663274612661717
#         R2 score FS (Test): 0.465280069524563
#     Trying order: 18
#         R2 score OSA (Train): 0.964062291197584
#         R2 score OSA (Test): 0.9238661645075011
#         R2 score FS (Train): 0.3354454084652534
#         R2 score FS (Test): 0.3512861357746139
#     Trying order: 19
#         R2 score OSA (Train): 0.9445132650111915
#         R2 score OSA (Test): 0.9106959611447157
#         R2 score FS (Train): 0.3600604978914429
#         R2 score FS (Test): 0.40683341022211383
#     Trying order: 20
#         R2 score OSA (Train): 0.94961239561293
#         R2 score OSA (Test): 0.9136824448033956
#         R2 score FS (Train): 0.40746354747864744
#         R2 score FS (Test): 0.4337690095303164
#
#     Tempo de execução: 2:50:02.505089
#     Best Order: 4
#     R2 score OSA (Train): 0.9567169488397101
#     R2 score OSA (Test): 0.9140738642397952
#     R2 score FS (Train): 0.49489214409289284
#     R2 score FS (Test): 0.4747688795380459
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.9193972214583294
#         R2 score OSA (Test): 0.8945255283991358
#         R2 score FS (Train): 0.39396792579330175
#         R2 score FS (Test): 0.4471220105467174
#     Trying order: 3
#         R2 score OSA (Train): 0.9159407611610643
#         R2 score OSA (Test): 0.8889788545686008
#         R2 score FS (Train): 0.47274256447641116
#         R2 score FS (Test): 0.5093072435894508
#     Trying order: 4
#         R2 score OSA (Train): 0.9367561026173719
#         R2 score OSA (Test): 0.9057570690159903
#         R2 score FS (Train): 0.4956412759276103
#         R2 score FS (Test): 0.5124217468142095
#     Trying order: 5
#         R2 score OSA (Train): 0.9458072457801161
#         R2 score OSA (Test): 0.9105298499024479
#         R2 score FS (Train): 0.5668431513098738
#         R2 score FS (Test): 0.5535691436737733
#     Trying order: 6
#         R2 score OSA (Train): 0.9470843162786994
#         R2 score OSA (Test): 0.9133754015156548
#         R2 score FS (Train): 0.574213179956951
#         R2 score FS (Test): 0.5571526049957672
#     Trying order: 7
#         R2 score OSA (Train): 0.9524123242692638
#         R2 score OSA (Test): 0.9117208009907481
#         R2 score FS (Train): 0.368453741730597
#         R2 score FS (Test): 0.3966976283717726
#     Trying order: 8
#         R2 score OSA (Train): 0.9514227666735603
#         R2 score OSA (Test): 0.916161711241888
#         R2 score FS (Train): 0.505582598678007
#         R2 score FS (Test): 0.506395869813637
#     Trying order: 9
#         R2 score OSA (Train): 0.9510572816014942
#         R2 score OSA (Test): 0.9165366179921676
#         R2 score FS (Train): 0.5215484995939783
#         R2 score FS (Test): 0.5186587384878447
#     Trying order: 10
#         R2 score OSA (Train): 0.9521718202999533
#         R2 score OSA (Test): 0.9183074565777269
#         R2 score FS (Train): 0.38360322206975117
#         R2 score FS (Test): 0.41601619927083133
#     Trying order: 11
#         R2 score OSA (Train): 0.9546164181096987
#         R2 score OSA (Test): 0.9219869490464508
#         R2 score FS (Train): 0.40104803087013563
#         R2 score FS (Test): 0.4284222865119549
#     Trying order: 12
#         R2 score OSA (Train): 0.9561210688537287
#         R2 score OSA (Test): 0.9218802154698774
#         R2 score FS (Train): 0.509997655945474
#         R2 score FS (Test): 0.5089709719028988
#     Trying order: 13
#         R2 score OSA (Train): 0.9556993759619793
#         R2 score OSA (Test): 0.9190999719016095
#         R2 score FS (Train): 0.51508263638339
#         R2 score FS (Test): 0.539766142951408
#     Trying order: 14
#         R2 score OSA (Train): 0.954291614121939
#         R2 score OSA (Test): 0.9186860172480013
#         R2 score FS (Train): 0.5240158566863691
#         R2 score FS (Test): 0.5616461846789145
#     Trying order: 15
#         R2 score OSA (Train): 0.9610124310038716
#         R2 score OSA (Test): 0.9239465691480517
#         R2 score FS (Train): 0.4325861893462494
#         R2 score FS (Test): 0.4530778472397039
#     Trying order: 16
#         R2 score OSA (Train): 0.9563746945217121
#         R2 score OSA (Test): 0.9171495604794475
#         R2 score FS (Train): 0.4905594372595983
#         R2 score FS (Test): 0.49038114913166564
#     Trying order: 17
#         R2 score OSA (Train): 0.9567166258546617
#         R2 score OSA (Test): 0.9184599889326431
#         R2 score FS (Train): 0.49252587611205056
#         R2 score FS (Test): 0.5142544840088905
#     Trying order: 18
#         R2 score OSA (Train): 0.9543180842772131
#         R2 score OSA (Test): 0.9162341721889588
#         R2 score FS (Train): 0.4863993187664716
#         R2 score FS (Test): 0.46978946331259763
#     Trying order: 19
#         R2 score OSA (Train): 0.9553808883107292
#         R2 score OSA (Test): 0.916480524992761
#         R2 score FS (Train): 0.5199654923374528
#         R2 score FS (Test): 0.5105698207361742
#     Trying order: 20
#         R2 score OSA (Train): 0.958923655948088
#         R2 score OSA (Test): 0.9214856824477171
#         R2 score FS (Train): 0.45685173996372064
#         R2 score FS (Test): 0.48640940127268806
#
#     Tempo de execução: 3:33:27.921055
#     Best Order: 6
#     R2 score OSA (Train): 0.9470843162786994
#     R2 score OSA (Test): 0.9133754015156548
#     R2 score FS (Train): 0.574213179956951
#     R2 score FS (Test): 0.5571526049957672
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.9202112321940702
#         R2 score OSA (Test): 0.889081114645007
#         R2 score FS (Train): 0.41701055638365625
#         R2 score FS (Test): 0.4747212558291568
#     Trying order: 3
#         R2 score OSA (Train): 0.9698968900298547
#         R2 score OSA (Test): 0.9224212017164872
#         R2 score FS (Train): 0.5348744815126107
#         R2 score FS (Test): 0.5693060839244508
#     Trying order: 4
#         R2 score OSA (Train): 0.9527619325856419
#         R2 score OSA (Test): 0.9125919285618381
#         R2 score FS (Train): 0.5477949914373609
#         R2 score FS (Test): 0.5762606749789738
#     Trying order: 5
#         R2 score OSA (Train): 0.976794917430908
#         R2 score OSA (Test): 0.9324262299779852
#         R2 score FS (Train): 0.4981519495925395
#         R2 score FS (Test): 0.5526534804128735
#     Trying order: 6
#         R2 score OSA (Train): 0.9651646046768417
#         R2 score OSA (Test): 0.9252656647191785
#         R2 score FS (Train): 0.4704570568479379
#         R2 score FS (Test): 0.5175797205530501
#     Trying order: 7
#         R2 score OSA (Train): 0.9582989459106985
#         R2 score OSA (Test): 0.9184592590078094
#         R2 score FS (Train): 0.44346413839502197
#         R2 score FS (Test): 0.49599063471015337
#     Trying order: 8
#         R2 score OSA (Train): 0.984006272859938
#         R2 score OSA (Test): 0.9369705164874786
#         R2 score FS (Train): 0.5014571886044298
#         R2 score FS (Test): 0.5458817874123876
#     Trying order: 9
#         R2 score OSA (Train): 0.9850111032092624
#         R2 score OSA (Test): 0.9355149665737104
#         R2 score FS (Train): 0.5062220413166408
#         R2 score FS (Test): 0.5526952808767182
#     Trying order: 10
#         R2 score OSA (Train): 0.9851052428815587
#         R2 score OSA (Test): 0.9383681922567672
#         R2 score FS (Train): 0.49778100021519367
#         R2 score FS (Test): 0.5364855207068198
#     Trying order: 11
#         R2 score OSA (Train): 0.9857745028390912
#         R2 score OSA (Test): 0.9385987074354438
#         R2 score FS (Train): 0.5750518127938788
#         R2 score FS (Test): 0.5976741963340102
#     Trying order: 12
#         R2 score OSA (Train): 0.9866475352760252
#         R2 score OSA (Test): 0.9357173979252017
#         R2 score FS (Train): 0.6072071446130671
#         R2 score FS (Test): 0.623345791738263
#     Trying order: 13
#         R2 score OSA (Train): 0.9856317997393468
#         R2 score OSA (Test): 0.9333518006600812
#         R2 score FS (Train): 0.5132569981746273
#         R2 score FS (Test): 0.5564530414056421
#     Trying order: 14
#         R2 score OSA (Train): 0.9867401035081131
#         R2 score OSA (Test): 0.9343382991835999
#         R2 score FS (Train): 0.5410306481803585
#         R2 score FS (Test): 0.5733890499590684
#     Trying order: 15
#         R2 score OSA (Train): 0.9745169048990252
#         R2 score OSA (Test): 0.9314615974431575
#         R2 score FS (Train): 0.3812017940185751
#         R2 score FS (Test): 0.4344029605797016
#     Trying order: 16
#         R2 score OSA (Train): 0.9876014948386562
#         R2 score OSA (Test): 0.9375715325446129
#         R2 score FS (Train): 0.599968700231756
#         R2 score FS (Test): 0.6269610291800383
#     Trying order: 17
#         R2 score OSA (Train): 0.9878005285890579
#         R2 score OSA (Test): 0.9380941221135434
#         R2 score FS (Train): 0.5472514542187963
#         R2 score FS (Test): 0.5748449411368206
#     Trying order: 18
#         R2 score OSA (Train): 0.9689839465718078
#         R2 score OSA (Test): 0.9233172117060771
#         R2 score FS (Train): 0.6028809601486327
#         R2 score FS (Test): 0.6232170739866844
#     Trying order: 19
#         R2 score OSA (Train): 0.9770435719170324
#         R2 score OSA (Test): 0.9307869362155522
#         R2 score FS (Train): 0.6341925130217085
#         R2 score FS (Test): 0.639914128863134
#     Trying order: 20
#         R2 score OSA (Train): 0.9780667670584053
#         R2 score OSA (Test): 0.9326697159271997
#         R2 score FS (Train): 0.5535515355468729
#         R2 score FS (Test): 0.5947151300447049
#
#     Tempo de execução: 3:55:07.610176
#     Best Order: 19
#     R2 score OSA (Train): 0.9770435719170324
#     R2 score OSA (Test): 0.9307869362155522
#     R2 score FS (Train): 0.6341925130217085
#     R2 score FS (Test): 0.639914128863134
#
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.8940316470540247
#         R2 score OSA (Test): 0.8642026660000295
#         R2 score FS (Train): -2.377414743468685
#         R2 score FS (Test): -1.3481297946401272
#     Trying order: 3
#         R2 score OSA (Train): 0.8627455743926116
#         R2 score OSA (Test): 0.8492524672079181
#         R2 score FS (Train): 0.6137700950503315
#         R2 score FS (Test): 0.607258742049533
#     Trying order: 4
#         R2 score OSA (Train): 0.8680003552728257
#         R2 score OSA (Test): 0.8600375199565634
#         R2 score FS (Train): 0.5610426760128671
#         R2 score FS (Test): 0.5787416550548334
#     Trying order: 5
#         R2 score OSA (Train): 0.8718560842768116
#         R2 score OSA (Test): 0.8535961035371641
#         R2 score FS (Train): 0.5252842633740498
#         R2 score FS (Test): 0.5436437740749298
#     Trying order: 6
#         R2 score OSA (Train): 0.9474150976938405
#         R2 score OSA (Test): 0.8893388402095495
#         R2 score FS (Train): 0.566321985997845
#         R2 score FS (Test): 0.5779679175196992
#     Trying order: 7
#         R2 score OSA (Train): 0.9748524898595511
#         R2 score OSA (Test): 0.914103922959655
#         R2 score FS (Train): 0.5155709982143208
#         R2 score FS (Test): 0.5335695638692977
#     Trying order: 8
#         R2 score OSA (Train): 0.9689441582872423
#         R2 score OSA (Test): 0.9073249828755267
#         R2 score FS (Train): 0.4771601033965188
#         R2 score FS (Test): 0.4978328467490559
#     Trying order: 9
#         R2 score OSA (Train): 0.9692933066456195
#         R2 score OSA (Test): 0.9302823272317245
#         R2 score FS (Train): 0.4546495564893581
#         R2 score FS (Test): 0.5051079045737008
#     Trying order: 10
#         R2 score OSA (Train): 0.9768750673980322
#         R2 score OSA (Test): 0.9151196231398998
#         R2 score FS (Train): 0.5703445688318924
#         R2 score FS (Test): 0.6037889797512219
#     Trying order: 11
#         R2 score OSA (Train): 0.9718170128720524
#         R2 score OSA (Test): 0.9129728484187448
#         R2 score FS (Train): 0.5156604842781214
#         R2 score FS (Test): 0.48206492398595346
#     Trying order: 12
#         R2 score OSA (Train): 0.9757972425553187
#         R2 score OSA (Test): 0.9315972687602604
#         R2 score FS (Train): 0.48700536054535637
#         R2 score FS (Test): 0.3563465722859823
#     Trying order: 13
#         R2 score OSA (Train): 0.9240432161677418
#         R2 score OSA (Test): 0.8753587370721043
#         R2 score FS (Train): 0.3655538047859769
#         R2 score FS (Test): 0.3987897847439743
#     Trying order: 14
#         R2 score OSA (Train): 0.958061906262965
#         R2 score OSA (Test): 0.9033984995837867
#         R2 score FS (Train): 0.3804676919337614
#         R2 score FS (Test): 0.3717534007016777
#     Trying order: 15
#         R2 score OSA (Train): 0.980536822127125
#         R2 score OSA (Test): 0.9347161025319043
#         R2 score FS (Train): 0.20479284795370445
#         R2 score FS (Test): 0.21553028789931528
#     Trying order: 16
#         R2 score OSA (Train): 0.9747107149455382
#         R2 score OSA (Test): 0.9270447366055534
#         R2 score FS (Train): 0.3061799367175879
#         R2 score FS (Test): 0.14820281627605036
#     Trying order: 17
#         R2 score OSA (Train): 0.9686021082307654
#         R2 score OSA (Test): 0.9206666262985751
#         R2 score FS (Train): 0.3103198982415416
#         R2 score FS (Test): 0.28169063038588904
#     Trying order: 18
#         R2 score OSA (Train): 0.9831716998658994
#         R2 score OSA (Test): 0.930530279589363
#         R2 score FS (Train): 0.5764869867439371
#         R2 score FS (Test): 0.3969540726911567
#     Trying order: 19
#         R2 score OSA (Train): 0.9839002554484448
#         R2 score OSA (Test): 0.9328296733091341
#         R2 score FS (Train): 0.42856250798432405
#         R2 score FS (Test): 0.29194560634625033
#     Trying order: 20
#         R2 score OSA (Train): 0.9884942009453863
#         R2 score OSA (Test): 0.935158653038491
#         R2 score FS (Train): 0.5836750068128472
#         R2 score FS (Test): 0.5295602882512338
#
#     Tempo de execução: 5:19:38.954453
#     Best Order: 3
#     R2 score OSA (Train): 0.8627455743926116
#     R2 score OSA (Test): 0.8492524672079181
#     R2 score FS (Train): 0.6137700950503315
#     R2 score FS (Test): 0.607258742049533

# %%
pd.DataFrame(results)
# Out:
#               MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS
# 0               SVM      5      0.833743     0.818713     0.354921  \
# 1               KNN     20      1.000000     0.906645     0.597370
# 2      DecisionTree      3      0.860965     0.848027     0.487857
# 3      RandomForest     20      0.962777     0.925155     0.355083
# 4  GradientBoosting      4      0.890394     0.874607     0.400308
# 5        ExtraTrees     20      0.962685     0.923844     0.415137
# 6               MLP      3      0.888098     0.855385     0.390086
#
#    R2 TEST FS                                          MODEL OBJ  PARS
# 0    0.367209  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 1    0.609567  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 2    0.506319  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 3    0.357324  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 4    0.392639  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 5    0.456329  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 6    0.413949  SYSIDRegressor(estimator=RandomizedSearchCV(cv...  None

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#     MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA   R2 TRAIN FS    R2 TEST FS
# 0     SVM      2      0.794880     0.793057  3.516021e-01  3.758325e-01  \
# 1     SVM      3      0.775315     0.772981 -7.453757e-01 -7.137210e-01
# 2     SVM      4      0.801775     0.796401  1.885072e-01  1.969365e-01
# 3     SVM      5      0.833743     0.818713  3.549214e-01  3.672090e-01
# 4     SVM      6      0.812048     0.803681  2.473766e-01  2.523032e-01
# ..    ...    ...           ...          ...           ...           ...
# 128   MLP     16      0.980841     0.941261 -2.805598e+22 -9.153365e+34
# 129   MLP     17      0.981003     0.948997 -3.586419e-01 -2.752128e-01
# 130   MLP     18      0.987735     0.948834 -1.527535e+00 -1.550983e+00
# 131   MLP     19      0.984346     0.944894 -7.339868e+01 -3.098073e+02
# 132   MLP     20      0.987259     0.951596 -1.023120e-01 -5.300869e-02
#
#                                              MODEL OBJ
# 0    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 1    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 2    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 3    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 4    SYSIDRegressor(estimator=MultiOutputRegressor(...
# ..                                                 ...
# 128  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 129  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 130  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 131  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 132  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
#
# [133 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[data_filt['R2 TEST FS'] >= 0]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', 'test_runs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/outputs/test_runs/SISO-Decomp.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# None

# %% [markdown]
# # SYSID - Trabalho (ML - MISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import copy
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.multioutput import MultiOutputRegressor

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %%
import sys
sys.path.insert(0, os.path.abspath('..'))
from sklearn_sid.regressors.sklearn import SYSIDRegressor

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# /mnt/d/OneDrive/Mestrado/gits/sklearn-sid/Volve-Dataset/data/volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        #'AVG_DOWNHOLE_PRESSURE',
        #'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        #'AVG_WHT_P',
        #'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        'BORE_OIL_VOL',
        #'BORE_LIQ_VOL',
        'BORE_GAS_VOL',
        'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 1) (718, 1)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X_tr = X_scale.fit_transform(X1_tr)
X_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    #{
    #    'activation'            : ['relu', 'logistic', 'tanh'],
    #    'early_stopping'        : [True, False],
    #    'alpha'                 : stats.loguniform(1e-9, 1e0),
    #    'hidden_layer_sizes'    : [(100,), (100, 100,), (100, 100, 100,), (100, 100, 100, 100,)],
    #    'max_iter'              : [10000],#stats.randint(200,10000),
    #    'batch_size'            : [32, 64, 128, 256, 'auto'],
    #    'solver'                : ['adam'], #'lbfgs'],
    #    'tol'                   : stats.loguniform(1e-7, 1e-1),
    #},
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    if model[0] == 'MLP':
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=rdmsearch, 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    else:
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=MultiOutputRegressor(rdmsearch, n_jobs=1), 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
n_models = len(models)

results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

# %%
for model in models:
    print(model[0])
# Out:
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'SIMO.W1'
#Loop principal, iterando sobre as listas
for model in models[::-1]:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1))
        r2_te_osa = r2_score(y_te, sidmodel.predict(X1_te, y=y_te, steps_ahead=1))
        try:
            r2_tr_fs = r2_score(y_tr, sidmodel.predict(X1_tr, y=y_tr))
            r2_te_fs = r2_score(y_te, sidmodel.predict(X1_te, y=y_te))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = copy.deepcopy(sidmodel)
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(copy.deepcopy(sidmodel))
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr[:,0], 'k', label='Train Qo')
    hist = ax[0].plot(y_tr[:,1], 'r', label='Train Qg')
    hist = ax[0].plot(y_tr[:,2], 'b', label='Train Qw')
    y_tr_pr = best_model.predict(X1_tr, y=y_tr)
    hist = ax[0].plot(y_tr_pr[:,0], 'k--', label='Model Qo')
    hist = ax[0].plot(y_tr_pr[:,1], 'r--', label='Model Qg')
    hist = ax[0].plot(y_tr_pr[:,2], 'b--', label='Model Qw') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,0], 'k', label='Test Qo')
    hist = ax[1].plot(y_te[n_train:,1], 'r', label='Test Qg')
    hist = ax[1].plot(y_te[n_train:,2], 'b', label='Test Qw')
    y_te_pr = best_model.predict(X1_te, y=y_te)
    hist = ax[1].plot(y_te_pr[n_train:,0], 'k--', label='Model Qo')
    hist = ax[1].plot(y_te_pr[n_train:,1], 'r--', label='Model Qg')
    hist = ax[1].plot(y_te_pr[n_train:,2], 'b--', label='Model Qw')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs', 'test_runs',f'{prefix}_{model_name}.pdf'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(best_model)
    try:
        results['PARS'].append(None)
    except Exception:
        results['PARS'].append(best_model.final_model)
# Out:
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.8585296004174858
#         R2 score OSA (Test): 0.788613590096776
#         R2 score FS (Train): -4.412004448080871
#         R2 score FS (Test): -4.650184863670076
#     Trying order: 3
#         R2 score OSA (Train): 0.8570216188719294
#         R2 score OSA (Test): 0.7907754757002815
#         R2 score FS (Train): -1.6757200163921924
#         R2 score FS (Test): -2.020231963954293
#     Trying order: 4
#         R2 score OSA (Train): 0.8299304828094295
#         R2 score OSA (Test): 0.7618482653255425
#         R2 score FS (Train): -0.43037521679270413
#         R2 score FS (Test): -0.6129227292977147
#     Trying order: 5
#         R2 score OSA (Train): 0.8735785086743993
#         R2 score OSA (Test): 0.7903666451528899
#         R2 score FS (Train): -1.281479136125457
#         R2 score FS (Test): -1.1935542179670167
#     Trying order: 6
#         R2 score OSA (Train): 0.8656942830378042
#         R2 score OSA (Test): 0.7931097432928306
#         R2 score FS (Train): -2.7311699844025186
#         R2 score FS (Test): -2.8615117194023028
#     Trying order: 7
#         R2 score OSA (Train): 0.868858509431063
#         R2 score OSA (Test): 0.7948997175661215
#         R2 score FS (Train): 0.010308160285325663
#         R2 score FS (Test): -0.03803555192719943
#     Trying order: 8
#         R2 score OSA (Train): 0.8755156808275646
#         R2 score OSA (Test): 0.7952783893616684
#         R2 score FS (Train): -2.5029101095501964
#         R2 score FS (Test): -3.0675656275168137
#     Trying order: 9
#         R2 score OSA (Train): 0.8734287213503632
#         R2 score OSA (Test): 0.7899208653498825
#         R2 score FS (Train): -0.6580994126984545
#         R2 score FS (Test): -0.9141443399941105
#     Trying order: 10
#         R2 score OSA (Train): 0.878475811907934
#         R2 score OSA (Test): 0.7843814822337761
#         R2 score FS (Train): 0.012583527970390048
#         R2 score FS (Test): 0.07522112869960888
#     Trying order: 11
#         R2 score OSA (Train): 0.889936169068056
#         R2 score OSA (Test): 0.7986432980665441
#         R2 score FS (Train): -0.11646722883620435
#         R2 score FS (Test): -0.2872785899620891
#     Trying order: 12
#         R2 score OSA (Train): 0.9022374485152476
#         R2 score OSA (Test): 0.8052428918129301
#         R2 score FS (Train): 0.38534974046972
#         R2 score FS (Test): 0.3874530240594736
#     Trying order: 13
#         R2 score OSA (Train): 0.8930393209703618
#         R2 score OSA (Test): 0.7959421289379994
#         R2 score FS (Train): -1.3124981479685651
#         R2 score FS (Test): -1.5576393760666827
#     Trying order: 14
#         R2 score OSA (Train): 0.9010826810016627
#         R2 score OSA (Test): 0.8047334004701209
#         R2 score FS (Train): -0.18086356186589803
#         R2 score FS (Test): -0.18605388467139203
#     Trying order: 15
#         R2 score OSA (Train): 0.9088660747250419
#         R2 score OSA (Test): 0.8014118611063639
#         R2 score FS (Train): 0.21883780255614216
#         R2 score FS (Test): 0.13616932719033825
#     Trying order: 16
#         R2 score OSA (Train): 0.9061883723043372
#         R2 score OSA (Test): 0.8013530328264259
#         R2 score FS (Train): -1.4303027036781213
#         R2 score FS (Test): -1.4911141695486825
#     Trying order: 17
#         R2 score OSA (Train): 0.9191905089749371
#         R2 score OSA (Test): 0.7924609024628788
#         R2 score FS (Train): -1.9803383925698208
#         R2 score FS (Test): -2.7027681752354975
#     Trying order: 18
#         R2 score OSA (Train): 0.906096835194529
#         R2 score OSA (Test): 0.7959047878349755
#         R2 score FS (Train): -0.2581247339402333
#         R2 score FS (Test): -0.0832878909074403
#     Trying order: 19
#         R2 score OSA (Train): 0.9019727128929675
#         R2 score OSA (Test): 0.7861943314337729
#         R2 score FS (Train): 0.37213672948111015
#         R2 score FS (Test): 0.3640709685050038
#     Trying order: 20
#         R2 score OSA (Train): 0.8202423531826128
#         R2 score OSA (Test): 0.7518885193679526
#         R2 score FS (Train): 0.6146136534278552
#         R2 score FS (Test): 0.5859740379537813
#
#     Tempo de execução: 5:27:01.331046
#     Best Order: 20
#     R2 score OSA (Train): 0.8202423531826128
#     R2 score OSA (Test): 0.7518885193679526
#     R2 score FS (Train): 0.6146136534278552
#     R2 score FS (Test): 0.5859740379537813
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.918117176116067
#         R2 score OSA (Test): 0.8317741401151765
#         R2 score FS (Train): 0.364594172823456
#         R2 score FS (Test): 0.33462662429251105
#     Trying order: 3
#         R2 score OSA (Train): 0.8919752419335855
#         R2 score OSA (Test): 0.8148689738551093
#         R2 score FS (Train): 0.3068347283679805
#         R2 score FS (Test): 0.25431183314537203
#     Trying order: 4
#         R2 score OSA (Train): 0.8833258978733478
#         R2 score OSA (Test): 0.8047260574291593
#         R2 score FS (Train): 0.33459146991537286
#         R2 score FS (Test): 0.28270212968614006
#     Trying order: 5
#         R2 score OSA (Train): 0.914009005990589
#         R2 score OSA (Test): 0.8247786494892905
#         R2 score FS (Train): 0.4072446797561183
#         R2 score FS (Test): 0.3522667157102721
#     Trying order: 6
#         R2 score OSA (Train): 0.8999761267792602
#         R2 score OSA (Test): 0.8195055641953662
#         R2 score FS (Train): 0.42283162205823843
#         R2 score FS (Test): 0.3894281190414368
#     Trying order: 7
#         R2 score OSA (Train): 0.8928363948486746
#         R2 score OSA (Test): 0.8161758739121437
#         R2 score FS (Train): 0.39562356054573256
#         R2 score FS (Test): 0.34358132600011054
#     Trying order: 8
#         R2 score OSA (Train): 0.9049764064650399
#         R2 score OSA (Test): 0.8238647248026657
#         R2 score FS (Train): 0.36751534261519175
#         R2 score FS (Test): 0.307641850744211
#     Trying order: 9
#         R2 score OSA (Train): 0.9190291883138171
#         R2 score OSA (Test): 0.8304699924871869
#         R2 score FS (Train): 0.42610534316221615
#         R2 score FS (Test): 0.37474377108614254
#     Trying order: 10
#         R2 score OSA (Train): 0.9118149191109849
#         R2 score OSA (Test): 0.825155961743249
#         R2 score FS (Train): 0.45795786708292613
#         R2 score FS (Test): 0.3977038373129647
#     Trying order: 11
#         R2 score OSA (Train): 0.9007081591822711
#         R2 score OSA (Test): 0.8183514710993999
#         R2 score FS (Train): 0.4554741066833614
#         R2 score FS (Test): 0.39261507927738465
#     Trying order: 12
#         R2 score OSA (Train): 0.9092039662049963
#         R2 score OSA (Test): 0.8260846678308523
#         R2 score FS (Train): 0.3844826227535574
#         R2 score FS (Test): 0.34845993740985604
#     Trying order: 13
#         R2 score OSA (Train): 0.9147566284341554
#         R2 score OSA (Test): 0.8314889237928224
#         R2 score FS (Train): 0.4187910907479768
#         R2 score FS (Test): 0.3675137876598593
#     Trying order: 14
#         R2 score OSA (Train): 0.9165440867663648
#         R2 score OSA (Test): 0.8293444171002617
#         R2 score FS (Train): 0.4800125979472654
#         R2 score FS (Test): 0.4426968848123625
#     Trying order: 15
#         R2 score OSA (Train): 0.9166983167667621
#         R2 score OSA (Test): 0.8290367128614032
#         R2 score FS (Train): 0.4841669035649409
#         R2 score FS (Test): 0.4428802616707915
#     Trying order: 16
#         R2 score OSA (Train): 0.9201111574772275
#         R2 score OSA (Test): 0.8307421465066137
#         R2 score FS (Train): 0.49866937315710774
#         R2 score FS (Test): 0.4569234426380322
#     Trying order: 17
#         R2 score OSA (Train): 0.9049759919690418
#         R2 score OSA (Test): 0.824654836594591
#         R2 score FS (Train): 0.46667286341197595
#         R2 score FS (Test): 0.4228914933260965
#     Trying order: 18
#         R2 score OSA (Train): 0.9189389524092983
#         R2 score OSA (Test): 0.8271637786000182
#         R2 score FS (Train): 0.4731196921357464
#         R2 score FS (Test): 0.43628122172893075
#     Trying order: 19
#         R2 score OSA (Train): 0.9221271012827902
#         R2 score OSA (Test): 0.8348493187545692
#         R2 score FS (Train): 0.49354462407224103
#         R2 score FS (Test): 0.44934019330866937
#     Trying order: 20
#         R2 score OSA (Train): 0.9019322221926752
#         R2 score OSA (Test): 0.8187069109411289
#         R2 score FS (Train): 0.526393496558209
#         R2 score FS (Test): 0.4736968879804455
#
#     Tempo de execução: 2:11:58.161358
#     Best Order: 20
#     R2 score OSA (Train): 0.9019322221926752
#     R2 score OSA (Test): 0.8187069109411289
#     R2 score FS (Train): 0.526393496558209
#     R2 score FS (Test): 0.4736968879804455
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.8660017303296864
#         R2 score OSA (Test): 0.7902847202463038
#         R2 score FS (Train): 0.10401141036268768
#         R2 score FS (Test): -0.032887989374175954
#     Trying order: 3
#         R2 score OSA (Train): 0.8639098607935202
#         R2 score OSA (Test): 0.7956295019533371
#         R2 score FS (Train): -0.07582892155116579
#         R2 score FS (Test): -0.3136782885061183
#     Trying order: 4
#         R2 score OSA (Train): 0.9038172587936207
#         R2 score OSA (Test): 0.8267240358226916
#         R2 score FS (Train): -0.019449353940903674
#         R2 score FS (Test): -0.24436659004174943
#     Trying order: 5
#         R2 score OSA (Train): 0.9334732615820253
#         R2 score OSA (Test): 0.8380609590245879
#         R2 score FS (Train): 0.12879957853916038
#         R2 score FS (Test): -0.05359782047616746
#     Trying order: 6
#         R2 score OSA (Train): 0.9071045086266031
#         R2 score OSA (Test): 0.8222090487498699
#         R2 score FS (Train): 0.3486926360744005
#         R2 score FS (Test): 0.25442535337748173
#     Trying order: 7
#         R2 score OSA (Train): 0.9377981106757566
#         R2 score OSA (Test): 0.8413325817590821
#         R2 score FS (Train): 0.2629418263789275
#         R2 score FS (Test): 0.12390936723113073
#     Trying order: 8
#         R2 score OSA (Train): 0.9401706322857032
#         R2 score OSA (Test): 0.837020799234133
#         R2 score FS (Train): 0.36106461924406935
#         R2 score FS (Test): 0.23293531035514325
#     Trying order: 9
#         R2 score OSA (Train): 0.940837164379357
#         R2 score OSA (Test): 0.8374028068073164
#         R2 score FS (Train): 0.30106328535539834
#         R2 score FS (Test): 0.2005337515863872
#     Trying order: 10
#         R2 score OSA (Train): 0.921338723751474
#         R2 score OSA (Test): 0.8318586982185954
#         R2 score FS (Train): 0.38126302361007475
#         R2 score FS (Test): 0.2887801294704757
#     Trying order: 11
#         R2 score OSA (Train): 0.9162710301460519
#         R2 score OSA (Test): 0.8318697540073003
#         R2 score FS (Train): 0.34590614111015583
#         R2 score FS (Test): 0.26400486098254944
#     Trying order: 12
#         R2 score OSA (Train): 0.9479304737391946
#         R2 score OSA (Test): 0.8466697871681644
#         R2 score FS (Train): 0.39021412713296044
#         R2 score FS (Test): 0.311715672403396
#     Trying order: 13
#         R2 score OSA (Train): 0.9511315352187383
#         R2 score OSA (Test): 0.8481618085650003
#         R2 score FS (Train): 0.4702303234324099
#         R2 score FS (Test): 0.37706755504615136
#     Trying order: 14
#         R2 score OSA (Train): 0.9504725947976796
#         R2 score OSA (Test): 0.8472783928683794
#         R2 score FS (Train): 0.43082211558904215
#         R2 score FS (Test): 0.3186159893786509
#     Trying order: 15
#         R2 score OSA (Train): 0.949021847988094
#         R2 score OSA (Test): 0.850502457807131
#         R2 score FS (Train): 0.3937723599820268
#         R2 score FS (Test): 0.29791434879640677
#     Trying order: 16
#         R2 score OSA (Train): 0.950224123289643
#         R2 score OSA (Test): 0.8435169018291268
#         R2 score FS (Train): 0.3887766042527782
#         R2 score FS (Test): 0.28088287998174355
#     Trying order: 17
#         R2 score OSA (Train): 0.9511743500428386
#         R2 score OSA (Test): 0.8504452508956866
#         R2 score FS (Train): 0.43348248665132694
#         R2 score FS (Test): 0.34215906567217047
#     Trying order: 18
#         R2 score OSA (Train): 0.9399294033947222
#         R2 score OSA (Test): 0.8439183283267848
#         R2 score FS (Train): 0.44138526662559663
#         R2 score FS (Test): 0.35840089969847
#     Trying order: 19
#         R2 score OSA (Train): 0.9389950410863216
#         R2 score OSA (Test): 0.8387564049683007
#         R2 score FS (Train): 0.49822777393100015
#         R2 score FS (Test): 0.4109467691251621
#     Trying order: 20
#         R2 score OSA (Train): 0.9365339520808521
#         R2 score OSA (Test): 0.8305028313601951
#         R2 score FS (Train): 0.5582174016071244
#         R2 score FS (Test): 0.48160492569719954
#
#     Tempo de execução: 2:46:41.514692
#     Best Order: 20
#     R2 score OSA (Train): 0.9365339520808521
#     R2 score OSA (Test): 0.8305028313601951
#     R2 score FS (Train): 0.5582174016071244
#     R2 score FS (Test): 0.48160492569719954
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.9027531281116034
#         R2 score OSA (Test): 0.8132150000971259
#         R2 score FS (Train): 0.3389383599519508
#         R2 score FS (Test): 0.2938131800240384
#     Trying order: 3
#         R2 score OSA (Train): 0.9111047377158553
#         R2 score OSA (Test): 0.821357482905551
#         R2 score FS (Train): -0.045595391349818236
#         R2 score FS (Test): -0.21830503666752876
#     Trying order: 4
#         R2 score OSA (Train): 0.8973404638781082
#         R2 score OSA (Test): 0.8161536905043013
#         R2 score FS (Train): 0.13145197161587482
#         R2 score FS (Test): 0.07375453911863265
#     Trying order: 5
#         R2 score OSA (Train): 0.904243675405826
#         R2 score OSA (Test): 0.8195036030222621
#         R2 score FS (Train): 0.2706737357747355
#         R2 score FS (Test): 0.1854875801065009
#     Trying order: 6
#         R2 score OSA (Train): 0.9082807024499172
#         R2 score OSA (Test): 0.8203384401266631
#         R2 score FS (Train): 0.25208287103619637
#         R2 score FS (Test): 0.16515588797308514
#     Trying order: 7
#         R2 score OSA (Train): 0.9088002732340842
#         R2 score OSA (Test): 0.8225509489284922
#         R2 score FS (Train): 0.2428229163635417
#         R2 score FS (Test): 0.1506923646891558
#     Trying order: 8
#         R2 score OSA (Train): 0.9189227541367915
#         R2 score OSA (Test): 0.8294566732047112
#         R2 score FS (Train): 0.29502966004544984
#         R2 score FS (Test): 0.19758264130555672
#     Trying order: 9
#         R2 score OSA (Train): 0.924521900333846
#         R2 score OSA (Test): 0.828355867487943
#         R2 score FS (Train): 0.32798306815616995
#         R2 score FS (Test): 0.23765016546184425
#     Trying order: 10
#         R2 score OSA (Train): 0.9072316156500774
#         R2 score OSA (Test): 0.8221363860321507
#         R2 score FS (Train): 0.2952205356856569
#         R2 score FS (Test): 0.20310904166848298
#     Trying order: 11
#         R2 score OSA (Train): 0.9242966807939358
#         R2 score OSA (Test): 0.8327645908874276
#         R2 score FS (Train): 0.2344021934090412
#         R2 score FS (Test): 0.14439101483101333
#     Trying order: 12
#         R2 score OSA (Train): 0.9231565107941861
#         R2 score OSA (Test): 0.8320070274636074
#         R2 score FS (Train): 0.31830034451909045
#         R2 score FS (Test): 0.23354913330163843
#     Trying order: 13
#         R2 score OSA (Train): 0.9159117104603706
#         R2 score OSA (Test): 0.8310345865278039
#         R2 score FS (Train): 0.3407042007755088
#         R2 score FS (Test): 0.2548216965623631
#     Trying order: 14
#         R2 score OSA (Train): 0.9229906876243077
#         R2 score OSA (Test): 0.8355876848124607
#         R2 score FS (Train): 0.4041449017675996
#         R2 score FS (Test): 0.3323587988770145
#     Trying order: 15
#         R2 score OSA (Train): 0.9226073510379061
#         R2 score OSA (Test): 0.8342139748401168
#         R2 score FS (Train): 0.39830293205503536
#         R2 score FS (Test): 0.3460207836915869
#     Trying order: 16
#         R2 score OSA (Train): 0.9136520263579767
#         R2 score OSA (Test): 0.8271329856212105
#         R2 score FS (Train): 0.3857529718484682
#         R2 score FS (Test): 0.3134057720521653
#     Trying order: 17
#         R2 score OSA (Train): 0.9265614340592584
#         R2 score OSA (Test): 0.837608135427326
#         R2 score FS (Train): 0.4329082616652394
#         R2 score FS (Test): 0.36980220911347167
#     Trying order: 18
#         R2 score OSA (Train): 0.9177620467206765
#         R2 score OSA (Test): 0.8317444688170187
#         R2 score FS (Train): 0.3186328421457529
#         R2 score FS (Test): 0.24021994805960922
#     Trying order: 19
#         R2 score OSA (Train): 0.9137428286766892
#         R2 score OSA (Test): 0.8283698337061601
#         R2 score FS (Train): 0.3925551635451356
#         R2 score FS (Test): 0.31390964463661014
#     Trying order: 20
#         R2 score OSA (Train): 0.9251610296459152
#         R2 score OSA (Test): 0.831756710980868
#         R2 score FS (Train): 0.4061005947290381
#         R2 score FS (Test): 0.34500151178673494
#
#     Tempo de execução: 1:46:50.761624
#     Best Order: 17
#     R2 score OSA (Train): 0.9265614340592584
#     R2 score OSA (Test): 0.837608135427326
#     R2 score FS (Train): 0.4329082616652394
#     R2 score FS (Test): 0.36980220911347167
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.828383331319341
#         R2 score OSA (Test): 0.7512125022856325
#         R2 score FS (Train): -1.4823315244148734
#         R2 score FS (Test): -1.8701465001430417
#     Trying order: 3
#         R2 score OSA (Train): 0.8377991882268391
#         R2 score OSA (Test): 0.7761142410379239
#         R2 score FS (Train): -0.465145327361912
#         R2 score FS (Test): -0.6965375741698567
#     Trying order: 4
#         R2 score OSA (Train): 0.8269873989475288
#         R2 score OSA (Test): 0.7526437602935635
#         R2 score FS (Train): 0.41336332481632315
#         R2 score FS (Test): 0.430642225401575
#     Trying order: 5
#         R2 score OSA (Train): 0.8726945921330594
#         R2 score OSA (Test): 0.7640461217849149
#         R2 score FS (Train): 0.08841124191479965
#         R2 score FS (Test): 0.12955948654762442
#     Trying order: 6
#         R2 score OSA (Train): 0.865125869293986
#         R2 score OSA (Test): 0.7961291108496065
#         R2 score FS (Train): -0.40891266556105443
#         R2 score FS (Test): -0.5757231196845706
#     Trying order: 7
#         R2 score OSA (Train): 0.8507805431869494
#         R2 score OSA (Test): 0.7637724013712123
#         R2 score FS (Train): -0.5455712243520094
#         R2 score FS (Test): -0.9840825982408865
#     Trying order: 8
#         R2 score OSA (Train): 0.855147893579374
#         R2 score OSA (Test): 0.7721954815475449
#         R2 score FS (Train): -0.5357447804786983
#         R2 score FS (Test): -0.7768431811489181
#     Trying order: 9
#         R2 score OSA (Train): 0.8613886163861221
#         R2 score OSA (Test): 0.781937228375215
#         R2 score FS (Train): -1.2683753675868372
#         R2 score FS (Test): -1.7434032362734404
#     Trying order: 10
#         R2 score OSA (Train): 0.8383064615759531
#         R2 score OSA (Test): 0.7620570128168888
#         R2 score FS (Train): -1.2779439983240966
#         R2 score FS (Test): -1.7351712280080316
#     Trying order: 11
#         R2 score OSA (Train): 0.8678902535157141
#         R2 score OSA (Test): 0.7880145464062385
#         R2 score FS (Train): 0.17168632337166892
#         R2 score FS (Test): 0.09951209696078005
#     Trying order: 12
#         R2 score OSA (Train): 0.8627863378171529
#         R2 score OSA (Test): 0.7908613127857901
#         R2 score FS (Train): 0.3749921945462697
#         R2 score FS (Test): 0.41157286337672977
#     Trying order: 13
#         R2 score OSA (Train): 0.8429667028668973
#         R2 score OSA (Test): 0.7660038274180753
#         R2 score FS (Train): -0.08696385799261656
#         R2 score FS (Test): -0.2995905549500842
#     Trying order: 14
#         R2 score OSA (Train): 0.884862708390688
#         R2 score OSA (Test): 0.798872301356103
#         R2 score FS (Train): -1.830522387847795
#         R2 score FS (Test): -2.3751922159866914
#     Trying order: 15
#         R2 score OSA (Train): 0.865051484108105
#         R2 score OSA (Test): 0.7979467181816581
#         R2 score FS (Train): -1.6411695483792574
#         R2 score FS (Test): -2.0311377872163847
#     Trying order: 16
#         R2 score OSA (Train): 0.8699576508328875
#         R2 score OSA (Test): 0.7770028021419525
#         R2 score FS (Train): -0.48301289716403933
#         R2 score FS (Test): -0.5940932081025012
#     Trying order: 17
#         R2 score OSA (Train): 0.862034096344253
#         R2 score OSA (Test): 0.77747463093589
#         R2 score FS (Train): 0.44199394510290396
#         R2 score FS (Test): 0.44509562899243277
#     Trying order: 18
#         R2 score OSA (Train): 0.8414629032867281
#         R2 score OSA (Test): 0.7783821886135209
#         R2 score FS (Train): -1.801442980507688
#         R2 score FS (Test): -2.241730125382695
#     Trying order: 19
#         R2 score OSA (Train): 0.8511598082073372
#         R2 score OSA (Test): 0.7885644998998135
#         R2 score FS (Train): 0.2033247404286875
#         R2 score FS (Test): 0.19959135604072806
#     Trying order: 20
#         R2 score OSA (Train): 0.8395622901507175
#         R2 score OSA (Test): 0.7801770646550992
#         R2 score FS (Train): -1.5980947277353448
#         R2 score FS (Test): -2.0827458121370035
#
#     Tempo de execução: 0:02:27.792680
#     Best Order: 17
#     R2 score OSA (Train): 0.862034096344253
#     R2 score OSA (Test): 0.77747463093589
#     R2 score FS (Train): 0.44199394510290396
#     R2 score FS (Test): 0.44509562899243277
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 0.9282388961497118
#         R2 score OSA (Test): 0.8325699123869098
#         R2 score FS (Train): -0.04579432368339531
#         R2 score FS (Test): 0.09452413477669774
#     Trying order: 3
#         R2 score OSA (Train): 0.992582683929073
#         R2 score OSA (Test): 0.8639276239024186
#         R2 score FS (Train): -1.0780256289448513
#         R2 score FS (Test): -0.6412987171829134
#     Trying order: 4
#         R2 score OSA (Train): 0.9972400998043155
#         R2 score OSA (Test): 0.8569860483955557
#         R2 score FS (Train): -0.7869896101929497
#         R2 score FS (Test): -1.0945695690088202
#     Trying order: 5
#         R2 score OSA (Train): 0.9972400998042289
#         R2 score OSA (Test): 0.8502925665560775
#         R2 score FS (Train): -0.736889674572326
#         R2 score FS (Test): -1.0694429530050362
#     Trying order: 6
#         R2 score OSA (Train): 0.9972633176209754
#         R2 score OSA (Test): 0.8428616710258804
#         R2 score FS (Train): 0.21385053687509714
#         R2 score FS (Test): 0.13568667799774614
#     Trying order: 7
#         R2 score OSA (Train): 0.9970985190538784
#         R2 score OSA (Test): 0.8369074532446209
#         R2 score FS (Train): 0.5472750646136345
#         R2 score FS (Test): 0.4419192212294405
#     Trying order: 8
#         R2 score OSA (Train): 0.997207818509116
#         R2 score OSA (Test): 0.8365488861528103
#         R2 score FS (Train): 0.30148025900996717
#         R2 score FS (Test): 0.2560982782538532
#     Trying order: 9
#         R2 score OSA (Train): 0.9972853414368141
#         R2 score OSA (Test): 0.8325598902264306
#         R2 score FS (Train): 0.20410712097284642
#         R2 score FS (Test): 0.1831989177444974
#     Trying order: 10
#         R2 score OSA (Train): 0.9969955570865628
#         R2 score OSA (Test): 0.8259303661225473
#         R2 score FS (Train): 0.36656809142986857
#         R2 score FS (Test): 0.2803896592590365
#     Trying order: 11
#         R2 score OSA (Train): 0.998913443254322
#         R2 score OSA (Test): 0.8233711524853219
#         R2 score FS (Train): 0.018444440279358505
#         R2 score FS (Test): -0.12242448323378914
#     Trying order: 12
#         R2 score OSA (Train): 0.9461174455469609
#         R2 score OSA (Test): 0.7860035212732187
#         R2 score FS (Train): 0.06651511201119505
#         R2 score FS (Test): -0.006245950494335332
#     Trying order: 13
#         R2 score OSA (Train): 0.9989534669298598
#         R2 score OSA (Test): 0.8132346159346371
#         R2 score FS (Train): 0.1830235149808458
#         R2 score FS (Test): 0.07696995201548373
#     Trying order: 14
#         R2 score OSA (Train): 0.9990036730267712
#         R2 score OSA (Test): 0.8298441710698113
#         R2 score FS (Train): 0.15663963615213816
#         R2 score FS (Test): 0.00033967212548883613
#     Trying order: 15
#         R2 score OSA (Train): 0.9989748157208201
#         R2 score OSA (Test): 0.8302520980087092
#         R2 score FS (Train): 0.06452524382663867
#         R2 score FS (Test): -0.14547858878272393
#     Trying order: 16
#         R2 score OSA (Train): 0.9356314863213754
#         R2 score OSA (Test): 0.7965982182462441
#         R2 score FS (Train): 0.2623702591995703
#         R2 score FS (Test): 0.16324222405820618
#     Trying order: 17
#         R2 score OSA (Train): 0.9348939442827034
#         R2 score OSA (Test): 0.7990380190292758
#         R2 score FS (Train): 0.3545119114807351
#         R2 score FS (Test): 0.3775519542232475
#     Trying order: 18
#         R2 score OSA (Train): 0.9993376518496846
#         R2 score OSA (Test): 0.8396867751535182
#         R2 score FS (Train): 0.46345779783124735
#         R2 score FS (Test): 0.456302520805749
#     Trying order: 19
#         R2 score OSA (Train): 0.9998803047470156
#         R2 score OSA (Test): 0.8309380701534951
#         R2 score FS (Train): 0.3854149786201788
#         R2 score FS (Test): 0.39499404927245924
#     Trying order: 20
#         R2 score OSA (Train): 0.9999999999999313
#         R2 score OSA (Test): 0.8385331171934175
#         R2 score FS (Train): 0.44246975211362666
#         R2 score FS (Test): 0.44566822815031104
#
#     Tempo de execução: 0:05:35.258650
#     Best Order: 7
#     R2 score OSA (Train): 0.9970985190538784
#     R2 score OSA (Test): 0.8369074532446209
#     R2 score FS (Train): 0.5472750646136345
#     R2 score FS (Test): 0.4419192212294405
#
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.7499850820488546
#         R2 score OSA (Test): 0.6851488933456983
#         R2 score FS (Train): -1.6937489386424414
#         R2 score FS (Test): -2.2368017605435235
#     Trying order: 3
#         R2 score OSA (Train): 0.7688814313693788
#         R2 score OSA (Test): 0.7055553180682671
#         R2 score FS (Train): -1.8388217966256868
#         R2 score FS (Test): -2.2890102355836635
#     Trying order: 4
#         R2 score OSA (Train): 0.7729166387465004
#         R2 score OSA (Test): 0.7046473394255924
#         R2 score FS (Train): -2.6665510611395455
#         R2 score FS (Test): -3.4678804329609285
#     Trying order: 5
#         R2 score OSA (Train): 0.7893749682743656
#         R2 score OSA (Test): 0.6970705900176997
#         R2 score FS (Train): -3.05678486581914
#         R2 score FS (Test): -2.9948118976988822
#     Trying order: 6
#         R2 score OSA (Train): 0.7607282153398
#         R2 score OSA (Test): 0.7003412958053081
#         R2 score FS (Train): -3.356298493942124
#         R2 score FS (Test): -4.30736863482562
#     Trying order: 7
#         R2 score OSA (Train): 0.788603792399795
#         R2 score OSA (Test): 0.6949040548531235
#         R2 score FS (Train): -2.1136166487549284
#         R2 score FS (Test): -2.6567891801484267
#     Trying order: 8
#         R2 score OSA (Train): 0.8002724070393304
#         R2 score OSA (Test): 0.6943842651508962
#         R2 score FS (Train): -5.813347690286803
#         R2 score FS (Test): -6.752787739730007
#     Trying order: 9
#         R2 score OSA (Train): 0.781242310121911
#         R2 score OSA (Test): 0.7110398128208786
#         R2 score FS (Train): -1.8043012943467156
#         R2 score FS (Test): -1.9354655169701183
#     Trying order: 10
#         R2 score OSA (Train): 0.7980853171460153
#         R2 score OSA (Test): 0.7071705991796705
#         R2 score FS (Train): -0.13627739256793794
#         R2 score FS (Test): -0.3448196719298305
#     Trying order: 11
#         R2 score OSA (Train): 0.7747393739193563
#         R2 score OSA (Test): 0.7154860987278138
#         R2 score FS (Train): -0.048859858382509946
#         R2 score FS (Test): -0.2529088853372408
#     Trying order: 12
#         R2 score OSA (Train): 0.7827388429941909
#         R2 score OSA (Test): 0.7218105133465912
#         R2 score FS (Train): 0.06875399963377722
#         R2 score FS (Test): -0.14845817346664128
#     Trying order: 13
#         R2 score OSA (Train): 0.7808525240024414
#         R2 score OSA (Test): 0.7203398095012202
#         R2 score FS (Train): 0.22200371808331718
#         R2 score FS (Test): 0.029722261431811486
#     Trying order: 14
#         R2 score OSA (Train): 0.7817149788863859
#         R2 score OSA (Test): 0.7212138714686462
#         R2 score FS (Train): 0.21846480612042277
#         R2 score FS (Test): 0.01281160831273398
#     Trying order: 15
#         R2 score OSA (Train): 0.7943259790863352
#         R2 score OSA (Test): 0.72893451372268
#         R2 score FS (Train): -1.9706215547920092
#         R2 score FS (Test): -2.7231474413712093
#     Trying order: 16
#         R2 score OSA (Train): 0.801699231818497
#         R2 score OSA (Test): 0.7312320186303284
#         R2 score FS (Train): -1.394273607483428
#         R2 score FS (Test): -1.9541829381744371
#     Trying order: 17
#         R2 score OSA (Train): 0.7990077919042959
#         R2 score OSA (Test): 0.7309994077679612
#         R2 score FS (Train): 0.14576617898092584
#         R2 score FS (Test): -0.07633799275930797
#     Trying order: 18
#         R2 score OSA (Train): 0.7982234942682066
#         R2 score OSA (Test): 0.7284497366255964
#         R2 score FS (Train): 0.2729320644180658
#         R2 score FS (Test): 0.22327360165129037
#     Trying order: 19
#         R2 score OSA (Train): 0.7988907806913512
#         R2 score OSA (Test): 0.7293041848937047
#         R2 score FS (Train): 0.2867341291087025
#         R2 score FS (Test): 0.06948174618383618
#     Trying order: 20
#         R2 score OSA (Train): 0.7972647230812216
#         R2 score OSA (Test): 0.7291260329018013
#         R2 score FS (Train): 0.4149222505907335
#         R2 score FS (Test): 0.3309426543137193
#
#     Tempo de execução: 1:01:06.419338
#     Best Order: 20
#     R2 score OSA (Train): 0.7972647230812216
#     R2 score OSA (Test): 0.7291260329018013
#     R2 score FS (Train): 0.4149222505907335
#     R2 score FS (Test): 0.3309426543137193
#
# Starting evaluation of model: PolyReg
#     Trying order: 2
#         R2 score OSA (Train): 0.763419024551002
#         R2 score OSA (Test): 0.7255569248251014
#         R2 score FS (Train): 0.21069612195173026
#         R2 score FS (Test): 0.2022693754531313
#     Trying order: 3
#         R2 score OSA (Train): 0.7741871315372374
#         R2 score OSA (Test): 0.742046696812353
#         R2 score FS (Train): 0.2813640469286243
#         R2 score FS (Test): 0.2695006104769183
#     Trying order: 4
#         R2 score OSA (Train): 0.7747551952603989
#         R2 score OSA (Test): 0.742585876030977
#         R2 score FS (Train): 0.2888377494296522
#         R2 score FS (Test): 0.27758162758679367
#     Trying order: 5
#         R2 score OSA (Train): 0.7826733764315245
#         R2 score OSA (Test): 0.7491414365070529
#         R2 score FS (Train): 0.20236649849186836
#         R2 score FS (Test): 0.20738180535160278
#     Trying order: 6
#         R2 score OSA (Train): 0.7876978648573378
#         R2 score OSA (Test): 0.7533304140508248
#         R2 score FS (Train): 0.28633027135827294
#         R2 score FS (Test): 0.25847142163290593
#     Trying order: 7
#         R2 score OSA (Train): 0.7879790920218331
#         R2 score OSA (Test): 0.7534661628372225
#         R2 score FS (Train): 0.29654951406372726
#         R2 score FS (Test): 0.27093991894720965
#     Trying order: 8
#         R2 score OSA (Train): 0.7881372332480018
#         R2 score OSA (Test): 0.7535755060218025
#         R2 score FS (Train): 0.3003808583471534
#         R2 score FS (Test): 0.27608864052773646
#     Trying order: 9
#         R2 score OSA (Train): 0.7883391437201609
#         R2 score OSA (Test): 0.7537122594125815
#         R2 score FS (Train): 0.30398090871575023
#         R2 score FS (Test): 0.28000547652955843
#     Trying order: 10
#         R2 score OSA (Train): 0.7885284163285649
#         R2 score OSA (Test): 0.7538438187481344
#         R2 score FS (Train): 0.31261948094361564
#         R2 score FS (Test): 0.2882345424031065
#     Trying order: 11
#         R2 score OSA (Train): 0.7886740170257821
#         R2 score OSA (Test): 0.7539577021260313
#         R2 score FS (Train): 0.3184379803867006
#         R2 score FS (Test): 0.2926449072611354
#     Trying order: 12
#         R2 score OSA (Train): 0.788781924394776
#         R2 score OSA (Test): 0.754047960304856
#         R2 score FS (Train): 0.3239504454498839
#         R2 score FS (Test): 0.2976742088665276
#     Trying order: 13
#         R2 score OSA (Train): 0.7889451618118536
#         R2 score OSA (Test): 0.754183727578935
#         R2 score FS (Train): 0.3308285413287966
#         R2 score FS (Test): 0.3030537884978474
#     Trying order: 14
#         R2 score OSA (Train): 0.7892209187671985
#         R2 score OSA (Test): 0.7543745722932433
#         R2 score FS (Train): 0.3386897003890601
#         R2 score FS (Test): 0.3091251337961309
#     Trying order: 15
#         R2 score OSA (Train): 0.7893564464789229
#         R2 score OSA (Test): 0.7545120215675761
#         R2 score FS (Train): 0.3402355825145728
#         R2 score FS (Test): 0.31074275456871775
#     Trying order: 16
#         R2 score OSA (Train): 0.7894785635465545
#         R2 score OSA (Test): 0.7546066768338403
#         R2 score FS (Train): 0.34351969239545443
#         R2 score FS (Test): 0.31359445460747504
#     Trying order: 17
#         R2 score OSA (Train): 0.7896071715051282
#         R2 score OSA (Test): 0.7547740043109211
#         R2 score FS (Train): 0.3465956084850023
#         R2 score FS (Test): 0.3164418505147212
#     Trying order: 18
#         R2 score OSA (Train): 0.7897160901829601
#         R2 score OSA (Test): 0.7548815586746672
#         R2 score FS (Train): 0.34798922071091104
#         R2 score FS (Test): 0.3177843909481179
#     Trying order: 19
#         R2 score OSA (Train): 0.7901175248478433
#         R2 score OSA (Test): 0.7552393673425074
#         R2 score FS (Train): 0.35887915764981443
#         R2 score FS (Test): 0.32794148355359504
#     Trying order: 20
#         R2 score OSA (Train): 0.7908770315636137
#         R2 score OSA (Test): 0.7558183028667305
#         R2 score FS (Train): 0.3699967881745149
#         R2 score FS (Test): 0.3395958891529048
#
#     Tempo de execução: 0:02:34.515608
#     Best Order: 20
#     R2 score OSA (Train): 0.7908770315636137
#     R2 score OSA (Test): 0.7558183028667305
#     R2 score FS (Train): 0.3699967881745149
#     R2 score FS (Test): 0.3395958891529048
#
# Starting evaluation of model: LinReg
#     Trying order: 2
#         R2 score OSA (Train): 0.7715382020209569
#         R2 score OSA (Test): 0.7269180178847332
#         R2 score FS (Train): 0.18901360195278116
#         R2 score FS (Test): 0.1885468694795173
#     Trying order: 3
#         R2 score OSA (Train): 0.7841220399840886
#         R2 score OSA (Test): 0.7456645694209435
#         R2 score FS (Train): 0.2544971210383899
#         R2 score FS (Test): 0.23492719680693094
#     Trying order: 4
#         R2 score OSA (Train): 0.7729282899690411
#         R2 score OSA (Test): 0.741251365559385
#         R2 score FS (Train): 0.241317606171237
#         R2 score FS (Test): 0.21489149404754604
#     Trying order: 5
#         R2 score OSA (Train): 0.7810350426703468
#         R2 score OSA (Test): 0.7475516122171878
#         R2 score FS (Train): 0.1442185060126098
#         R2 score FS (Test): 0.13217277586353438
#     Trying order: 6
#         R2 score OSA (Train): 0.7867391072118286
#         R2 score OSA (Test): 0.7521542582130335
#         R2 score FS (Train): 0.25303872886895923
#         R2 score FS (Test): 0.21731354978022674
#     Trying order: 7
#         R2 score OSA (Train): 0.7868219138435703
#         R2 score OSA (Test): 0.7521794845500063
#         R2 score FS (Train): 0.2529346068140821
#         R2 score FS (Test): 0.21790735307827647
#     Trying order: 8
#         R2 score OSA (Train): 0.7868828155467464
#         R2 score OSA (Test): 0.7522289032774729
#         R2 score FS (Train): 0.2517976670375979
#         R2 score FS (Test): 0.21726729228253486
#     Trying order: 9
#         R2 score OSA (Train): 0.786953434947943
#         R2 score OSA (Test): 0.7522730930695944
#         R2 score FS (Train): 0.2536332742086219
#         R2 score FS (Test): 0.21937528482729263
#     Trying order: 10
#         R2 score OSA (Train): 0.7870177828173843
#         R2 score OSA (Test): 0.7523249230278712
#         R2 score FS (Train): 0.2543905106695343
#         R2 score FS (Test): 0.2203598919538464
#     Trying order: 11
#         R2 score OSA (Train): 0.7871653903683254
#         R2 score OSA (Test): 0.7524397102643334
#         R2 score FS (Train): 0.2610475383143726
#         R2 score FS (Test): 0.22648146029923566
#     Trying order: 12
#         R2 score OSA (Train): 0.7872533268255216
#         R2 score OSA (Test): 0.7524938966910808
#         R2 score FS (Train): 0.26487998795234874
#         R2 score FS (Test): 0.23034951061342832
#     Trying order: 13
#         R2 score OSA (Train): 0.7874454675262514
#         R2 score OSA (Test): 0.7526364447948476
#         R2 score FS (Train): 0.27253549732522275
#         R2 score FS (Test): 0.23744066230395997
#     Trying order: 14
#         R2 score OSA (Train): 0.7876841304006218
#         R2 score OSA (Test): 0.7527906365741002
#         R2 score FS (Train): 0.28029975433645354
#         R2 score FS (Test): 0.24494463847948547
#     Trying order: 15
#         R2 score OSA (Train): 0.7877622490729644
#         R2 score OSA (Test): 0.7528548310017324
#         R2 score FS (Train): 0.2804306765098118
#         R2 score FS (Test): 0.2454877992547877
#     Trying order: 16
#         R2 score OSA (Train): 0.7878658308191159
#         R2 score OSA (Test): 0.7529205609939388
#         R2 score FS (Train): 0.28373948472113614
#         R2 score FS (Test): 0.24893148426250958
#     Trying order: 17
#         R2 score OSA (Train): 0.7879426618857063
#         R2 score OSA (Test): 0.752978584756673
#         R2 score FS (Train): 0.28429581647853625
#         R2 score FS (Test): 0.2498719848199352
#     Trying order: 18
#         R2 score OSA (Train): 0.7880515351144443
#         R2 score OSA (Test): 0.7530462556069336
#         R2 score FS (Train): 0.28747851147695197
#         R2 score FS (Test): 0.25315420464825594
#     Trying order: 19
#         R2 score OSA (Train): 0.788136164849365
#         R2 score OSA (Test): 0.75313017892744
#         R2 score FS (Train): 0.29628290562723747
#         R2 score FS (Test): 0.2630008054008311
#     Trying order: 20
#         R2 score OSA (Train): 0.7885350073296614
#         R2 score OSA (Test): 0.7535740405443558
#         R2 score FS (Train): 0.3192738323199133
#         R2 score FS (Test): 0.29006167434481384
#
#     Tempo de execução: 0:00:20.914398
#     Best Order: 20
#     R2 score OSA (Train): 0.7885350073296614
#     R2 score OSA (Test): 0.7535740405443558
#     R2 score FS (Train): 0.3192738323199133
#     R2 score FS (Test): 0.29006167434481384

# %%
pd.DataFrame(results)
# Out:
#               MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS
# 0               MLP     20      0.820242     0.751889     0.614614  \
# 1        ExtraTrees     20      0.901932     0.818707     0.526393
# 2  GradientBoosting     20      0.936534     0.830503     0.558217
# 3      RandomForest     17      0.926561     0.837608     0.432908
# 4      DecisionTree     17      0.862034     0.777475     0.441994
# 5               KNN      7      0.997099     0.836907     0.547275
# 6               SVM     20      0.797265     0.729126     0.414922
# 7           PolyReg     20      0.790877     0.755818     0.369997
# 8            LinReg     20      0.788535     0.753574     0.319274
#
#    R2 TEST FS                                          MODEL OBJ  PARS
# 0    0.585974  SYSIDRegressor(estimator=RandomizedSearchCV(cv...  None
# 1    0.473697  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 2    0.481605  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 3    0.369802  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 4    0.445096  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 5    0.441919  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 6    0.330943  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 7    0.339596  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 8    0.290062  SYSIDRegressor(estimator=MultiOutputRegressor(...  None

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#       MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS  R2 TEST FS
# 0       MLP      2      0.858530     0.788614    -4.412004   -4.650185  \
# 1       MLP      3      0.857022     0.790775    -1.675720   -2.020232
# 2       MLP      4      0.829930     0.761848    -0.430375   -0.612923
# 3       MLP      5      0.873579     0.790367    -1.281479   -1.193554
# 4       MLP      6      0.865694     0.793110    -2.731170   -2.861512
# ..      ...    ...           ...          ...          ...         ...
# 166  LinReg     16      0.787866     0.752921     0.283739    0.248931
# 167  LinReg     17      0.787943     0.752979     0.284296    0.249872
# 168  LinReg     18      0.788052     0.753046     0.287479    0.253154
# 169  LinReg     19      0.788136     0.753130     0.296283    0.263001
# 170  LinReg     20      0.788535     0.753574     0.319274    0.290062
#
#                                              MODEL OBJ
# 0    SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 1    SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 2    SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 3    SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 4    SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# ..                                                 ...
# 166  SYSIDRegressor(estimator=MultiOutputRegressor(...
# 167  SYSIDRegressor(estimator=MultiOutputRegressor(...
# 168  SYSIDRegressor(estimator=MultiOutputRegressor(...
# 169  SYSIDRegressor(estimator=MultiOutputRegressor(...
# 170  SYSIDRegressor(estimator=MultiOutputRegressor(...
#
# [171 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[(data_filt['R2 TEST FS'] >= 0)&(data_filt['R2 TEST FS'] < 10)]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', 'test_runs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/OneDrive/Mestrado/gits/sklearn-sid/Volve-Dataset/outputs/test_runs/SIMO.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# None

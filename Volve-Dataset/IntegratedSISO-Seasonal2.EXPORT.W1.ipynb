# %% [markdown]
# # SYSID - Trabalho (ML - SISO.LM)
#
# Alunos:
#
# Pedro Henrique Cardoso Paulo</br>
# Felipe da Costa Pereira
#
# Professor: Helon

# %% [markdown]
# ## Objetivo

# %% [markdown]
# TBD

# %% [markdown]
# ## Passo 0 - Importando bibliotecas

# %%
# Pacotes padrao
import os
import pickle
import copy
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

#Pipeline
from sklearn.pipeline import Pipeline

#Tratamento
from sklearn.decomposition import PCA
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#Modelos
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.multioutput import MultiOutputRegressor

#sisidentpy
from sysidentpy.model_structure_selection import FROLS
from sysidentpy.basis_function._basis_function import Polynomial, Fourier
from sysidentpy.utils.narmax_tools import regressor_code

#Busca de modelos
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# Scores
from sklearn.metrics import r2_score

#Seasonal decomposition
from statsmodels.tsa.seasonal import seasonal_decompose

# Disabling warnings
import warnings
from sklearn.exceptions import DataConversionWarning

#Definindo random_state
rs = 85

# %%
from sklearn_sid.regressors.sklearn import SYSIDRegressor
from sklearn_sid.preprocessors.fourier_decompose import SFFTEnergyExpansor, SFFTFrequencyExpansor
from sklearn_sid.preprocessors.seasonal_decompose import SeasonalDecomposeExpansor

# %% [markdown]
# ## Passo 0 - Importando os dados

# %% [markdown]
# ### 0.1 - Lendo dados

# %%
binary = os.path.join(os.getcwd(), 'data', 'volve_compiled.pkl')
print(binary)

with open(binary, 'rb') as bin_file:
    data = pickle.load(bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/data/volve_compiled.pkl

# %%
for wellp in data['OP'].keys():
    print(wellp)
# Out:
# 15/9-F-1 C
# 15/9-F-11
# 15/9-F-12
# 15/9-F-14
# 15/9-F-15 D
# 15/9-F-5

# %% [markdown]
# ### 0.2 - Visualizando dados

# %%
case = "15/9-F-1 C"
#case = "15/9-F-11"

data_case = data['OP'][case]

filt_vars_IN_Q =  [
        #'BORE_OIL_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
        #'BORE_OIL_CUM',
        #'BORE_LIQ_CUM',
        #'BORE_GAS_CUM',
        #'BORE_WAT_CUM',
]

filt_vars_IN_QINJ = [
        'BORE_WI_VOL',
        'BORE_WI_CUM',
]

filt_vars_IN_P = [
        #'AVG_DOWNHOLE_PRESSURE',
        #'AVG_WHP_P',
        #'AVG_DP_TUBING',
        #'AVG_ANNULUS_PRESS',
        'AVG_CHOKE_SIZE_P',
        #'DP_CHOKE_SIZE',
]

filt_vars_IN_T = [
        #'AVG_WHT_P',
        #'AVG_DOWNHOLE_TEMPERATURE',
]

filt_vars_OUT = [
        #'BORE_OIL_VOL',
        'BORE_LIQ_VOL',
        #'BORE_GAS_VOL',
        #'BORE_WAT_VOL',
]

time = data_case['N']
fig, ax = plt.subplots(4,1, figsize=(10, 20))
for var in filt_vars_IN_P:
    ax[0].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_Q:
    ax[1].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_IN_T:
    ax[2].plot(time, data_case[var], '-o', label=var)
for var in filt_vars_OUT:
    ax[3].plot(time, data_case[var], '-o', label=var)
ax[0].legend()
ax[1].legend()
ax[2].legend()
ax[3].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data_case = data_case.iloc[28:,:]
#data_case = data_case[data_case['AVG_DOWNHOLE_PRESSURE']>0]
data_case = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T + filt_vars_OUT].dropna()
X1 = data_case[filt_vars_IN_Q + filt_vars_IN_P + filt_vars_IN_T].values
y =  data_case[filt_vars_OUT].values

# %% [markdown]
# ## Passo 1 - Separando os dados em treino e teste

# %% [markdown]
# ### 1.1 - Definindo a parcela de treino e de teste

# %%
p_train = 0.7 #70% treino

# %% [markdown]
# ### 1.2 - Separando os conjuntos

# %%
n_train = int(X1.shape[0]*p_train)
X1_tr = X1[:n_train,:]
y_tr = y[:n_train,:]
X1_te = X1[:,:]
y_te = y[:,:]

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 1) (718, 1)

# %% [markdown]
# ### 1.3 - Removendo a escala

# %%
X_scale = MinMaxScaler()
y_scale = MinMaxScaler()
X1_tr = X_scale.fit_transform(X1_tr)
X1_te = X_scale.transform(X1_te)
y_tr = y_scale.fit_transform(y_tr)
y_te = y_scale.transform(y_te)

# %% [markdown]
# ### 1.4 - Decompondo a série

# %%
period=30
kr = True
fft_y = SeasonalDecomposeExpansor(period=period, keep_residuals=kr)
fft_X = SeasonalDecomposeExpansor(period=period, keep_residuals=kr)
y_tr_copy = y_tr.copy()
X1_tr_copy = X1_tr.copy()
y_tr = fft_y.fit_transform(y_tr)
y_te = fft_y.transform(y_te)
X1_tr = fft_X.fit_transform(X1_tr)
X1_te = fft_X.transform(X1_te)

# %%
print(
    X1_tr.shape,
    X1_te.shape
)
# Out:
# (502, 3) (718, 3)

# %%
fig, ax = plt.subplots(2,1, figsize=(20,14))

for i in range(X1_te.shape[1]):
    try:
        ax[0].plot(y_tr[:,i], label=f'Energy level {i+1}')
    except Exception:
        pass
    try:
        ax[1].plot(X1_tr[:,i], label=f'Energy level {i+1}')
    except Exception:
        pass
ax[0].plot(y_tr.sum(axis=1), label='Reconstituted data')
ax[1].plot(X1_tr.sum(axis=1), label='Reconstituted data')
ax[0].plot(y_tr_copy, 'k--', label='Real data')
ax[1].plot(X1_tr_copy, 'k--', label='Real data')
ax[0].legend()
ax[1].legend()

# %% [markdown]
# ## Passo 2 - Declarando os modelos

# %%
models = []

# %% [markdown]
# ### 2.1 - ARMAX (sysidentpy)

# %% [markdown]
# ### 2.2 - NARMAX (sysidentpy)

# %% [markdown]
# ### 2.3 - Modelos de ML (sklearn)

# %% [markdown]
# #### 2.3.1 - Modelos

# %%
models_ml = [
    ('LinReg'          ,      LinearRegression(copy_X=True)), #ARX Equivalent
    ('PolyReg'         ,      Pipeline([('Poly', PolynomialFeatures(degree=2)), ('Reg', LinearRegression(copy_X=True))])), #NARX Equivalent
    ('SVM'             ,      SVR(max_iter=-1)),
    ('KNN'             ,      KNeighborsRegressor()),
    ('DecisionTree'    ,      DecisionTreeRegressor(random_state=rs)),
    ('RandomForest'    ,      RandomForestRegressor(random_state=rs)),
    ('GradientBoosting',      GradientBoostingRegressor(random_state=rs)),
    ('ExtraTrees'      ,      ExtraTreesRegressor(random_state=rs)),
    ('MLP'             ,      MLPRegressor(random_state=rs, )),
]

# %% [markdown]
# #### 2.3.2 - Parâmetros (RandomSearchCV)

# %%
parameters = [
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'positive'                     : [True, False],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'           : stats.uniform(loc=0.7, scale=0.3),
        'Reg__positive'                : [True, False],
        #'Poly__degree'                : [2, 3, 4, 5],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'C'                     : stats.loguniform(1e-3, 1e3),
        'kernel'                : ['poly', 'rbf', 'sigmoid','linear'],
        'degree'                : stats.randint(2,6),
        'gamma'                 : stats.loguniform(1e-4, 1e0),
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_neighbors'           : stats.randint(1,100),
        'weights'               : ['uniform', 'distance'],
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        #'DT__criterion'              : ['gini', 'entropy'],
        'splitter'               : ['best', 'random'],
        'max_depth'              : stats.randint(5,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'loss'                   : ['squared_error', 'absolute_error', 'huber', 'quantile'],
        'learning_rate'          : stats.loguniform(1e-5, 1e1),
        'criterion'              : ['friedman_mse', 'squared_error'],
        'subsample'              : stats.uniform(), 
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        #'PCA__n_components'          : stats.uniform(loc=0.7, scale=0.3),
        'n_estimators'           : stats.randint(5,100), #Numero de arvores
        'criterion'              : ['squared_error', 'absolute_error'],
        #'RF__criterion'              : ['gini', 'entropy'],
        'max_depth'              : stats.randint(1,20), #maxima profundidade da arvore
        'min_samples_split'      : stats.randint(2,20), #minima quantidade de amostras para splitar
        'min_samples_leaf'       : stats.randint(1,20), #minima quantidade de amostras por folha
        'max_features'           : stats.uniform(),      #maxima quantidade de features para embasar a decisao de divisao
        'max_leaf_nodes'         : stats.randint(10,150), #maxima quantidade de folhas
        #'expansor'                    : [None, PolynomialFeatures(degree=2)],
        #'nX'                          : stats.randint(2,10),
        #'ny'                          : stats.randint(2,10),
    },
    {
        'activation'            : ['relu'], #'logistic', 'tanh'],
        'early_stopping'        : [True, False],
        'alpha'                 : stats.loguniform(1e-4, 1e0),
        'hidden_layer_sizes'    : [] 
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=1)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=2)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=3)]
        + [n_neurons for n_neurons in itertools.product([20, 40, 60, 80, 100], repeat=4)],
        'max_iter'              : [10000],#stats.randint(200,10000),
        'batch_size'            : [16, 32, 64, 128, 256],
        'solver'                : ['adam'], #'lbfgs'],
        'tol'                   : stats.loguniform(1e-7, 1e-1),

    },
]

# %%
kfolds = 5
niters = 10
rkf = RepeatedKFold(n_splits=kfolds, n_repeats=niters, random_state=71)

# %%
n_iter = 100 #Numero de iterações do rdmsearch 

for model, params in zip(models_ml, parameters):
    rdmsearch = RandomizedSearchCV(model[1], verbose=0, scoring='r2', 
                                   param_distributions=params, n_iter=n_iter, n_jobs=6, 
                                   cv=rkf, random_state=rs)
    
    if model[0] == 'MLP':
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=rdmsearch, 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    else:
        sidmodel = SYSIDRegressor(
            nX=6, ny=6,
            estimator=MultiOutputRegressor(rdmsearch, n_jobs=1), 
            preprocessor=MinMaxScaler(),
            #expansor=PolynomialFeatures(degree=2)
            )
    
    models.append(
        (model[0], sidmodel)
    )

#models = models[-1:]

# %%
results = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
    'PARS':[]
}

order_progression = {
    'MODEL':[],
    'ORDER':[],
    'R2 TRAIN OSA':[],
    'R2 TEST OSA':[],
    'R2 TRAIN FS':[],
    'R2 TEST FS':[],
    'MODEL OBJ':[],
}

#models = models[-1:]

# %%
for model in models:
    print(model[0])
# Out:
# LinReg
# PolyReg
# SVM
# KNN
# DecisionTree
# RandomForest
# GradientBoosting
# ExtraTrees
# MLP

# %%
#fig, axs = plt.subplots(ncols=2, nrows=n_models, figsize=(25,n_models*7))
orders = range(2,21)
prefix = 'SISO-Seasonal.W1'
#Loop principal, iterando sobre as listas
for model in models[2:]:
    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,7))

    model_name, sidmodel = model

    print('Starting evaluation of model: {}'.format(model_name))
    
    t0 = datetime.now()

    best_r2_tr_fs = 1e6
    best_r2_te_fs = 1e6
    best_r2_tr_osa = 1e6
    best_r2_te_osa = 1e6
    best_order = 0
    best_model = sidmodel
    
    for order in orders:
        print(f'    Trying order: {order}')
        if hasattr(sidmodel, 'nX'): # is from our package
            sidmodel.nX = order
            sidmodel.ny = order
        else:
            sidmodel.xlag = [order]*X1_tr.shape[1]
            sidmodel.ylag = order
            sidmodel.elag = order
            regressors = regressor_code(X=X1_tr,
                                        xlag=[order]*X1_tr.shape[1],
                                        ylag=order,
                                        model_type="NARMAX",
                                        model_representation="neural_network",
                                        basis_function=sidmodel.basis_function
                                        )

            n_features = regressors.shape[0]
            
            #sidmodel.n_terms = n_features

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sidmodel.fit(X=X1_tr, y=y_tr)
        r2_tr_osa = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr, steps_ahead=1).sum(axis=1))
        r2_te_osa = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te, steps_ahead=1).sum(axis=1))
        try:
            r2_tr_fs = r2_score(y_tr.sum(axis=1), sidmodel.predict(X1_tr, y=y_tr).sum(axis=1))
            r2_te_fs = r2_score(y_te.sum(axis=1), sidmodel.predict(X1_te, y=y_te).sum(axis=1))
        except ValueError:
            r2_tr_fs = 1e290
            r2_te_fs = 1e290
        if np.abs(r2_tr_fs - 1) < np.abs(best_r2_tr_fs - 1):
            best_r2_tr_fs = r2_tr_fs
            best_r2_te_fs = r2_te_fs
            best_r2_tr_osa = r2_tr_osa
            best_r2_te_osa = r2_te_osa
            best_order = order
            best_model = copy.deepcopy(sidmodel)
        order_progression['MODEL'].append(model_name)
        order_progression['ORDER'].append(order)
        order_progression['R2 TRAIN OSA'].append(r2_tr_osa)
        order_progression['R2 TEST OSA'].append(r2_te_osa)
        order_progression['R2 TRAIN FS'].append(r2_tr_fs)
        order_progression['R2 TEST FS'].append(r2_te_fs)
        order_progression['MODEL OBJ'].append(copy.deepcopy(sidmodel))
        print('        R2 score OSA (Train):', r2_tr_osa)
        print('        R2 score OSA (Test):', r2_te_osa)
        print('        R2 score FS (Train):', r2_tr_fs)
        print('        R2 score FS (Test):', r2_te_fs)
    print()
    print('    Tempo de execução: {}'.format(datetime.now() - t0))
    print('    Best Order:', best_order)
    print('    R2 score OSA (Train):', best_r2_tr_osa)
    print('    R2 score OSA (Test):', best_r2_te_osa)
    print('    R2 score FS (Train):', best_r2_tr_fs)
    print('    R2 score FS (Test):', best_r2_te_fs)

    hist = ax[0].plot(y_tr.sum(axis=1), label='Train')
    hist = ax[0].plot(best_model.predict(X1_tr, y=y_tr).sum(axis=1), label='Model') 
    ax[0].set_title(f'Train fit')
    ax[0].legend()
    hist = ax[1].plot(y_te[n_train:,:].sum(axis=1), label='Test')
    hist = ax[1].plot(best_model.predict(X1_te, y=y_te)[n_train:,:].sum(axis=1), label='Model')
    ax[1].set_title(f'Test prediction')
    ax[1].legend()
    fig.suptitle(f'{model_name} ({case})')
    fig.savefig(os.path.join(os.getcwd(),'outputs', 'test_runs',f'{prefix}_{model_name}.pdf'))
    print()
    
    results['MODEL'].append(model_name) 
    results['ORDER'].append(best_order)
    results['R2 TRAIN OSA'].append(best_r2_tr_osa)
    results['R2 TEST OSA'].append(best_r2_te_osa)
    results['R2 TRAIN FS'].append(best_r2_tr_fs)
    results['R2 TEST FS'].append(best_r2_te_fs) 
    results['MODEL OBJ'].append(best_model)
    try:
        results['PARS'].append(None)
    except Exception:
        results['PARS'].append(best_model.final_model)
# Out:
# Starting evaluation of model: SVM
#     Trying order: 2
#         R2 score OSA (Train): 0.7290081899444562
#         R2 score OSA (Test): 0.72382727167621
#         R2 score FS (Train): 0.4587612785115116
#         R2 score FS (Test): 0.48495412523463766
#     Trying order: 3
#         R2 score OSA (Train): 0.7361142032850319
#         R2 score OSA (Test): 0.7286224778842771
#         R2 score FS (Train): 0.3327490880155284
#         R2 score FS (Test): 0.4050512312924588
#     Trying order: 4
#         R2 score OSA (Train): 0.7329181401331577
#         R2 score OSA (Test): 0.7255750906089145
#         R2 score FS (Train): -40055144.00847175
#         R2 score FS (Test): -51437551.559054054
#     Trying order: 5
#         R2 score OSA (Train): 0.7602048222675938
#         R2 score OSA (Test): 0.753668776686427
#         R2 score FS (Train): 0.47966555507891095
#         R2 score FS (Test): 0.4944559551094425
#     Trying order: 6
#         R2 score OSA (Train): 0.7623331775964516
#         R2 score OSA (Test): 0.7528012166806288
#         R2 score FS (Train): 0.48413512369179457
#         R2 score FS (Test): 0.49897256573986093
#     Trying order: 7
#         R2 score OSA (Train): 0.7640147166718732
#         R2 score OSA (Test): 0.7558499244653087
#         R2 score FS (Train): 0.4935093814425786
#         R2 score FS (Test): 0.5163484787779369
#     Trying order: 8
#         R2 score OSA (Train): 0.763724938768527
#         R2 score OSA (Test): 0.7562886065443908
#         R2 score FS (Train): 0.49954721091136567
#         R2 score FS (Test): 0.5247834585343902
#     Trying order: 9
#         R2 score OSA (Train): 0.7652398827782697
#         R2 score OSA (Test): 0.7544551213682875
#         R2 score FS (Train): 0.5004416161935108
#         R2 score FS (Test): 0.5235497568372516
#     Trying order: 10
#         R2 score OSA (Train): 0.7658051635705866
#         R2 score OSA (Test): 0.7539639307035217
#         R2 score FS (Train): 0.47526039941323905
#         R2 score FS (Test): 0.5069873448554881
#     Trying order: 11
#         R2 score OSA (Train): 0.7689600454564496
#         R2 score OSA (Test): 0.7571238209417266
#         R2 score FS (Train): 0.4593342360387763
#         R2 score FS (Test): 0.4968980107122588
#     Trying order: 12
#         R2 score OSA (Train): 0.7666312291733648
#         R2 score OSA (Test): 0.7550665618726082
#         R2 score FS (Train): 0.46498264530607625
#         R2 score FS (Test): 0.5011787618062544
#     Trying order: 13
#         R2 score OSA (Train): 0.7659590079036264
#         R2 score OSA (Test): 0.7522228324138619
#         R2 score FS (Train): 0.4944161369345451
#         R2 score FS (Test): 0.5298074668683715
#     Trying order: 14
#         R2 score OSA (Train): 0.7571605813135112
#         R2 score OSA (Test): 0.7499994297440495
#         R2 score FS (Train): 0.4721338082624974
#         R2 score FS (Test): 0.5246686048103907
#     Trying order: 15
#         R2 score OSA (Train): 0.7589616346282382
#         R2 score OSA (Test): 0.7532960038218982
#         R2 score FS (Train): 0.46861418447952785
#         R2 score FS (Test): 0.5156581037417942
#     Trying order: 16
#         R2 score OSA (Train): 0.7594779816076241
#         R2 score OSA (Test): 0.7516581578293947
#         R2 score FS (Train): 0.43601118749849677
#         R2 score FS (Test): 0.47735439764449616
#     Trying order: 17
#         R2 score OSA (Train): 0.7544063651832014
#         R2 score OSA (Test): 0.7471819654178251
#         R2 score FS (Train): 0.40294258047416676
#         R2 score FS (Test): 0.4395812881881598
#     Trying order: 18
#         R2 score OSA (Train): 0.7409761795372188
#         R2 score OSA (Test): 0.7385823345899973
#         R2 score FS (Train): 0.4041777558831391
#         R2 score FS (Test): 0.44799754613535336
#     Trying order: 19
#         R2 score OSA (Train): 0.7428941989640402
#         R2 score OSA (Test): 0.7403776249792586
#         R2 score FS (Train): 0.4173185276973389
#         R2 score FS (Test): 0.46082627174668667
#     Trying order: 20
#         R2 score OSA (Train): 0.7630371169341756
#         R2 score OSA (Test): 0.7485349516279375
#         R2 score FS (Train): 0.44755301231359
#         R2 score FS (Test): 0.4734949097945832
#
#     Tempo de execução: 1:09:22.338212
#     Best Order: 9
#     R2 score OSA (Train): 0.7652398827782697
#     R2 score OSA (Test): 0.7544551213682875
#     R2 score FS (Train): 0.5004416161935108
#     R2 score FS (Test): 0.5235497568372516
#
# Starting evaluation of model: KNN
#     Trying order: 2
#         R2 score OSA (Train): 0.7800180105187742
#         R2 score OSA (Test): 0.7366718451724665
#         R2 score FS (Train): 0.5187035809728688
#         R2 score FS (Test): 0.4428511106323675
#     Trying order: 3
#         R2 score OSA (Train): 0.7955305905602588
#         R2 score OSA (Test): 0.7589072245199482
#         R2 score FS (Train): 0.4606459903001209
#         R2 score FS (Test): 0.3076228635239503
#     Trying order: 4
#         R2 score OSA (Train): 0.7771320943524314
#         R2 score OSA (Test): 0.7535505121053583
#         R2 score FS (Train): 0.34966703163310153
#         R2 score FS (Test): 0.29361154518580523
#     Trying order: 5
#         R2 score OSA (Train): 0.7730264112490797
#         R2 score OSA (Test): 0.7395581756203824
#         R2 score FS (Train): 0.41053324840426053
#         R2 score FS (Test): 0.2972046016400509
#     Trying order: 6
#         R2 score OSA (Train): 0.9999999999999631
#         R2 score OSA (Test): 0.7521133754274194
#         R2 score FS (Train): 0.3531273881130228
#         R2 score FS (Test): 0.24021429683420104
#     Trying order: 7
#         R2 score OSA (Train): 0.9999999999999809
#         R2 score OSA (Test): 0.7768780708899337
#         R2 score FS (Train): 0.5007918271703304
#         R2 score FS (Test): 0.33700663624971916
#     Trying order: 8
#         R2 score OSA (Train): 0.8048908420794507
#         R2 score OSA (Test): 0.7540396813990545
#         R2 score FS (Train): 0.5060649140030373
#         R2 score FS (Test): 0.3966833277359738
#     Trying order: 9
#         R2 score OSA (Train): 0.9999999999999769
#         R2 score OSA (Test): 0.7816296794206012
#         R2 score FS (Train): 0.5297166908692412
#         R2 score FS (Test): 0.4210125469559183
#     Trying order: 10
#         R2 score OSA (Train): 0.9999999999999841
#         R2 score OSA (Test): 0.7856130642638668
#         R2 score FS (Train): 0.5770296095460514
#         R2 score FS (Test): 0.44566632999197553
#     Trying order: 11
#         R2 score OSA (Train): 0.9999999999999765
#         R2 score OSA (Test): 0.7873300459516477
#         R2 score FS (Train): 0.608285925524837
#         R2 score FS (Test): 0.47868287023080647
#     Trying order: 12
#         R2 score OSA (Train): 0.9999999999999875
#         R2 score OSA (Test): 0.7902476239691733
#         R2 score FS (Train): 0.6236232820652355
#         R2 score FS (Test): 0.4933876334500489
#     Trying order: 13
#         R2 score OSA (Train): 0.9999999999999932
#         R2 score OSA (Test): 0.7864744152922624
#         R2 score FS (Train): 0.7111095956544369
#         R2 score FS (Test): 0.6115550636134645
#     Trying order: 14
#         R2 score OSA (Train): 0.9999999999999911
#         R2 score OSA (Test): 0.7822734980264644
#         R2 score FS (Train): 0.70940931581117
#         R2 score FS (Test): 0.6214254964379198
#     Trying order: 15
#         R2 score OSA (Train): 0.9999999999999896
#         R2 score OSA (Test): 0.7793639011455095
#         R2 score FS (Train): 0.719438311691192
#         R2 score FS (Test): 0.6304710061446411
#     Trying order: 16
#         R2 score OSA (Train): 0.9999999999999927
#         R2 score OSA (Test): 0.7768737053850692
#         R2 score FS (Train): 0.7295802939247131
#         R2 score FS (Test): 0.6250578005000371
#     Trying order: 17
#         R2 score OSA (Train): 0.9999999999999953
#         R2 score OSA (Test): 0.7723668356801024
#         R2 score FS (Train): 0.7240115944171903
#         R2 score FS (Test): 0.6261587968086019
#     Trying order: 18
#         R2 score OSA (Train): 0.9999999999999957
#         R2 score OSA (Test): 0.7771006585393083
#         R2 score FS (Train): 0.7222632969542524
#         R2 score FS (Test): 0.6342938128572987
#     Trying order: 19
#         R2 score OSA (Train): 0.9999999999999956
#         R2 score OSA (Test): 0.7702042989425042
#         R2 score FS (Train): 0.717381596431321
#         R2 score FS (Test): 0.6488040828686514
#     Trying order: 20
#         R2 score OSA (Train): 0.999999999999996
#         R2 score OSA (Test): 0.765782074531524
#         R2 score FS (Train): 0.7250039460164439
#         R2 score FS (Test): 0.6441695850160406
#
#     Tempo de execução: 1:14:56.950051
#     Best Order: 16
#     R2 score OSA (Train): 0.9999999999999927
#     R2 score OSA (Test): 0.7768737053850692
#     R2 score FS (Train): 0.7295802939247131
#     R2 score FS (Test): 0.6250578005000371
#
# Starting evaluation of model: DecisionTree
#     Trying order: 2
#         R2 score OSA (Train): 0.8243891076964948
#         R2 score OSA (Test): 0.7502813458044926
#         R2 score FS (Train): -0.3185080438430816
#         R2 score FS (Test): -0.3645975833063697
#     Trying order: 3
#         R2 score OSA (Train): 0.8237300381057324
#         R2 score OSA (Test): 0.7634802543727864
#         R2 score FS (Train): 0.1706913635844085
#         R2 score FS (Test): 0.16634864734425392
#     Trying order: 4
#         R2 score OSA (Train): 0.8993538752656652
#         R2 score OSA (Test): 0.7689199106905371
#         R2 score FS (Train): -0.1909384850221163
#         R2 score FS (Test): -0.3283487381008612
#     Trying order: 5
#         R2 score OSA (Train): 0.7883988358432195
#         R2 score OSA (Test): 0.7438375741133115
#         R2 score FS (Train): 0.036175623688780245
#         R2 score FS (Test): -0.015054811067339635
#     Trying order: 6
#         R2 score OSA (Train): 0.8524762091629571
#         R2 score OSA (Test): 0.7609434197042436
#         R2 score FS (Train): -2.296802274580994
#         R2 score FS (Test): -2.908570866277474
#     Trying order: 7
#         R2 score OSA (Train): 0.8487839119206833
#         R2 score OSA (Test): 0.7672135385603414
#         R2 score FS (Train): -0.21539475943908482
#         R2 score FS (Test): -0.31711935607330766
#     Trying order: 8
#         R2 score OSA (Train): 0.8621557147017018
#         R2 score OSA (Test): 0.7802287664265461
#         R2 score FS (Train): -0.1941669385424447
#         R2 score FS (Test): -0.26451029368892853
#     Trying order: 9
#         R2 score OSA (Train): 0.8643624396512258
#         R2 score OSA (Test): 0.7638929666536945
#         R2 score FS (Train): -0.3091625138678493
#         R2 score FS (Test): -0.42368511546127197
#     Trying order: 10
#         R2 score OSA (Train): 0.8451691628699282
#         R2 score OSA (Test): 0.771704912796643
#         R2 score FS (Train): -0.6223236593143198
#         R2 score FS (Test): -0.8037931208567879
#     Trying order: 11
#         R2 score OSA (Train): 0.8516294532956004
#         R2 score OSA (Test): 0.7630964011723376
#         R2 score FS (Train): -2.3949611146255436
#         R2 score FS (Test): -2.782385966157133
#     Trying order: 12
#         R2 score OSA (Train): 0.819645836413484
#         R2 score OSA (Test): 0.7900938056290515
#         R2 score FS (Train): 0.17743511820444846
#         R2 score FS (Test): 0.160208360865419
#     Trying order: 13
#         R2 score OSA (Train): 0.8460858453084605
#         R2 score OSA (Test): 0.7457874347110647
#         R2 score FS (Train): -0.3588135372140484
#         R2 score FS (Test): -0.3483541234477776
#     Trying order: 14
#         R2 score OSA (Train): 0.8487812570777125
#         R2 score OSA (Test): 0.7627355534604969
#         R2 score FS (Train): -1.1145284605283026
#         R2 score FS (Test): -0.9231368902536738
#     Trying order: 15
#         R2 score OSA (Train): 0.875468519997016
#         R2 score OSA (Test): 0.7407238097062778
#         R2 score FS (Train): -0.20939422966897037
#         R2 score FS (Test): -0.22711114095287122
#     Trying order: 16
#         R2 score OSA (Train): 0.8525331626304564
#         R2 score OSA (Test): 0.7458531015853096
#         R2 score FS (Train): -0.05148174466789146
#         R2 score FS (Test): -0.20789171706110898
#     Trying order: 17
#         R2 score OSA (Train): 0.8671001887256037
#         R2 score OSA (Test): 0.7868905887487195
#         R2 score FS (Train): -0.0665168432686356
#         R2 score FS (Test): -0.02561174999322202
#     Trying order: 18
#         R2 score OSA (Train): 0.8504644585282243
#         R2 score OSA (Test): 0.7691096677163616
#         R2 score FS (Train): 0.016786273107538552
#         R2 score FS (Test): 0.012073886779770948
#     Trying order: 19
#         R2 score OSA (Train): 0.8552511031569107
#         R2 score OSA (Test): 0.7559279102042951
#         R2 score FS (Train): 0.08698522297223754
#         R2 score FS (Test): 0.06879656477575391
#     Trying order: 20
#         R2 score OSA (Train): 0.8528505766717966
#         R2 score OSA (Test): 0.7581107232104765
#         R2 score FS (Train): 0.028842867201523847
#         R2 score FS (Test): 0.004715186406855976
#
#     Tempo de execução: 0:05:39.046022
#     Best Order: 12
#     R2 score OSA (Train): 0.819645836413484
#     R2 score OSA (Test): 0.7900938056290515
#     R2 score FS (Train): 0.17743511820444846
#     R2 score FS (Test): 0.160208360865419
#
# Starting evaluation of model: RandomForest
#     Trying order: 2
#         R2 score OSA (Train): 0.9357882135254911
#         R2 score OSA (Test): 0.8460892709998934
#         R2 score FS (Train): 0.6028424227886025
#         R2 score FS (Test): 0.5778667789470859
#     Trying order: 3
#         R2 score OSA (Train): 0.9389964080757205
#         R2 score OSA (Test): 0.8476812414212633
#         R2 score FS (Train): 0.5679927904371909
#         R2 score FS (Test): 0.5308613884715234
#     Trying order: 4
#         R2 score OSA (Train): 0.9411799179705503
#         R2 score OSA (Test): 0.8546721007086961
#         R2 score FS (Train): 0.5091064427207408
#         R2 score FS (Test): 0.4697506335149546
#     Trying order: 5
#         R2 score OSA (Train): 0.9415179148134208
#         R2 score OSA (Test): 0.8546066537615117
#         R2 score FS (Train): 0.5127176625784291
#         R2 score FS (Test): 0.467048179236657
#     Trying order: 6
#         R2 score OSA (Train): 0.9447606672405012
#         R2 score OSA (Test): 0.8539928662801074
#         R2 score FS (Train): 0.6206955455950162
#         R2 score FS (Test): 0.5720136777610441
#     Trying order: 7
#         R2 score OSA (Train): 0.9139431416807615
#         R2 score OSA (Test): 0.8421951954941791
#         R2 score FS (Train): 0.6110319897886735
#         R2 score FS (Test): 0.5991268513521103
#     Trying order: 8
#         R2 score OSA (Train): 0.904278958199989
#         R2 score OSA (Test): 0.8381509245230196
#         R2 score FS (Train): 0.5741207028905944
#         R2 score FS (Test): 0.5663849300747226
#     Trying order: 9
#         R2 score OSA (Train): 0.9459554150824797
#         R2 score OSA (Test): 0.8604740255989713
#         R2 score FS (Train): 0.625227527484925
#         R2 score FS (Test): 0.5903712532522714
#     Trying order: 10
#         R2 score OSA (Train): 0.919280179458251
#         R2 score OSA (Test): 0.8414621396072336
#         R2 score FS (Train): 0.4481376527686143
#         R2 score FS (Test): 0.4206248042590792
#     Trying order: 11
#         R2 score OSA (Train): 0.9164177602808821
#         R2 score OSA (Test): 0.8416787648460659
#         R2 score FS (Train): 0.501731357604942
#         R2 score FS (Test): 0.47955097529613444
#     Trying order: 12
#         R2 score OSA (Train): 0.9457954626279234
#         R2 score OSA (Test): 0.8555283181847242
#         R2 score FS (Train): 0.619861040747256
#         R2 score FS (Test): 0.6004114649351531
#     Trying order: 13
#         R2 score OSA (Train): 0.922126147756592
#         R2 score OSA (Test): 0.8460623833546459
#         R2 score FS (Train): 0.6105573983143864
#         R2 score FS (Test): 0.6101778280939271
#     Trying order: 14
#         R2 score OSA (Train): 0.9187962273243874
#         R2 score OSA (Test): 0.8448342292856086
#         R2 score FS (Train): 0.6300765010129672
#         R2 score FS (Test): 0.6221134115081627
#     Trying order: 15
#         R2 score OSA (Train): 0.9246178834823477
#         R2 score OSA (Test): 0.8412169960178608
#         R2 score FS (Train): 0.612958999331629
#         R2 score FS (Test): 0.6142116167138103
#     Trying order: 16
#         R2 score OSA (Train): 0.946737073902954
#         R2 score OSA (Test): 0.8558961838785945
#         R2 score FS (Train): 0.5931622308765265
#         R2 score FS (Test): 0.5702448715754859
#     Trying order: 17
#         R2 score OSA (Train): 0.906272300958633
#         R2 score OSA (Test): 0.8392783441653193
#         R2 score FS (Train): 0.638635983696334
#         R2 score FS (Test): 0.6457638835379678
#     Trying order: 18
#         R2 score OSA (Train): 0.9210672036656302
#         R2 score OSA (Test): 0.8443748088132741
#         R2 score FS (Train): 0.570105620598836
#         R2 score FS (Test): 0.5843816169969716
#     Trying order: 19
#         R2 score OSA (Train): 0.9249623030502754
#         R2 score OSA (Test): 0.8439247621831969
#         R2 score FS (Train): 0.6170447803924078
#         R2 score FS (Test): 0.6066911750584061
#     Trying order: 20
#         R2 score OSA (Train): 0.9307391925354411
#         R2 score OSA (Test): 0.848322881257651
#         R2 score FS (Train): 0.610024460266247
#         R2 score FS (Test): 0.5895069676055886
#
#     Tempo de execução: 3:35:26.377523
#     Best Order: 17
#     R2 score OSA (Train): 0.906272300958633
#     R2 score OSA (Test): 0.8392783441653193
#     R2 score FS (Train): 0.638635983696334
#     R2 score FS (Test): 0.6457638835379678
#
# Starting evaluation of model: GradientBoosting
#     Trying order: 2
#         R2 score OSA (Train): 0.8920573963794828
#         R2 score OSA (Test): 0.8214679916848613
#         R2 score FS (Train): 0.542646966356357
#         R2 score FS (Test): 0.5268585290137805
#     Trying order: 3
#         R2 score OSA (Train): 0.89942740216028
#         R2 score OSA (Test): 0.8251852719328439
#         R2 score FS (Train): 0.532071581176482
#         R2 score FS (Test): 0.5231707436083552
#     Trying order: 4
#         R2 score OSA (Train): 0.9668734584510313
#         R2 score OSA (Test): 0.8548241529693921
#         R2 score FS (Train): 0.561418548028664
#         R2 score FS (Test): 0.5480837294877647
#     Trying order: 5
#         R2 score OSA (Train): 0.906779533855566
#         R2 score OSA (Test): 0.8260457841976883
#         R2 score FS (Train): 0.5353278474922454
#         R2 score FS (Test): 0.5173954389867952
#     Trying order: 6
#         R2 score OSA (Train): 0.9249221329651071
#         R2 score OSA (Test): 0.8336630589074623
#         R2 score FS (Train): 0.6179966835684019
#         R2 score FS (Test): 0.5771245788403567
#     Trying order: 7
#         R2 score OSA (Train): 0.9116254186361736
#         R2 score OSA (Test): 0.8339868021393009
#         R2 score FS (Train): 0.5392449897511145
#         R2 score FS (Test): 0.5647682706685464
#     Trying order: 8
#         R2 score OSA (Train): 0.9674965309008338
#         R2 score OSA (Test): 0.8578140157487905
#         R2 score FS (Train): 0.5912365779686806
#         R2 score FS (Test): 0.5856153302687002
#     Trying order: 9
#         R2 score OSA (Train): 0.9266503200600917
#         R2 score OSA (Test): 0.831748424556883
#         R2 score FS (Train): 0.4790998810159771
#         R2 score FS (Test): 0.4741782740080206
#     Trying order: 10
#         R2 score OSA (Train): 0.9153827418801089
#         R2 score OSA (Test): 0.8359439930966299
#         R2 score FS (Train): 0.5486803528958709
#         R2 score FS (Test): 0.5453435731767746
#     Trying order: 11
#         R2 score OSA (Train): 0.9758600848537513
#         R2 score OSA (Test): 0.852727005713322
#         R2 score FS (Train): 0.4949532635434941
#         R2 score FS (Test): 0.38100618133206166
#     Trying order: 12
#         R2 score OSA (Train): 0.9163923816214194
#         R2 score OSA (Test): 0.8350726369469309
#         R2 score FS (Train): 0.442315094408095
#         R2 score FS (Test): 0.44261080768884464
#     Trying order: 13
#         R2 score OSA (Train): 0.9206958346956421
#         R2 score OSA (Test): 0.8436420290863037
#         R2 score FS (Train): 0.6037977165980197
#         R2 score FS (Test): 0.5907541779614379
#     Trying order: 14
#         R2 score OSA (Train): 0.9805807482852743
#         R2 score OSA (Test): 0.8661837947389621
#         R2 score FS (Train): 0.6330183179583438
#         R2 score FS (Test): 0.5975500205130593
#     Trying order: 15
#         R2 score OSA (Train): 0.9202070403264769
#         R2 score OSA (Test): 0.8365005716383507
#         R2 score FS (Train): 0.5581102103400675
#         R2 score FS (Test): 0.5316059494554871
#     Trying order: 16
#         R2 score OSA (Train): 0.924974178260803
#         R2 score OSA (Test): 0.8414990702051302
#         R2 score FS (Train): 0.5961278979319681
#         R2 score FS (Test): 0.5986361711758433
#     Trying order: 17
#         R2 score OSA (Train): 0.9794884488736743
#         R2 score OSA (Test): 0.86948385541323
#         R2 score FS (Train): 0.5512985882729703
#         R2 score FS (Test): 0.5208355173496286
#     Trying order: 18
#         R2 score OSA (Train): 0.9366146313012726
#         R2 score OSA (Test): 0.8429210984859506
#         R2 score FS (Train): 0.6218487778045413
#         R2 score FS (Test): 0.6203687251039114
#     Trying order: 19
#         R2 score OSA (Train): 0.9389682315804853
#         R2 score OSA (Test): 0.8477781602021885
#         R2 score FS (Train): 0.6261405401686948
#         R2 score FS (Test): 0.607370952152209
#     Trying order: 20
#         R2 score OSA (Train): 0.9395647243502565
#         R2 score OSA (Test): 0.8489563236428147
#         R2 score FS (Train): 0.6107087848053194
#         R2 score FS (Test): 0.5804266537947909
#
#     Tempo de execução: 6:53:13.747612
#     Best Order: 14
#     R2 score OSA (Train): 0.9805807482852743
#     R2 score OSA (Test): 0.8661837947389621
#     R2 score FS (Train): 0.6330183179583438
#     R2 score FS (Test): 0.5975500205130593
#
# Starting evaluation of model: ExtraTrees
#     Trying order: 2
#         R2 score OSA (Train): 0.9399585784230476
#         R2 score OSA (Test): 0.8609468566679708
#         R2 score FS (Train): 0.6216100309482693
#         R2 score FS (Test): 0.6101419757186783
#     Trying order: 3
#         R2 score OSA (Train): 0.9539975853751317
#         R2 score OSA (Test): 0.869033198268936
#         R2 score FS (Train): 0.6094517793003217
#         R2 score FS (Test): 0.5996292037624017
#     Trying order: 4
#         R2 score OSA (Train): 0.958206553998412
#         R2 score OSA (Test): 0.8654536295522004
#         R2 score FS (Train): 0.607562638978737
#         R2 score FS (Test): 0.5967906925613076
#     Trying order: 5
#         R2 score OSA (Train): 0.9633279674645341
#         R2 score OSA (Test): 0.8620921934068945
#         R2 score FS (Train): 0.5878646368633378
#         R2 score FS (Test): 0.5848498620382139
#     Trying order: 6
#         R2 score OSA (Train): 0.898302356927554
#         R2 score OSA (Test): 0.8431197069404727
#         R2 score FS (Train): 0.5472561700386229
#         R2 score FS (Test): 0.5586822277648266
#     Trying order: 7
#         R2 score OSA (Train): 0.9465683974172567
#         R2 score OSA (Test): 0.8586412524231051
#         R2 score FS (Train): 0.6019665468491304
#         R2 score FS (Test): 0.5843868860173693
#     Trying order: 8
#         R2 score OSA (Train): 0.9712162112316081
#         R2 score OSA (Test): 0.8721588942044877
#         R2 score FS (Train): 0.6520952565234677
#         R2 score FS (Test): 0.630603914701473
#     Trying order: 9
#         R2 score OSA (Train): 0.970952360446796
#         R2 score OSA (Test): 0.8703222853469414
#         R2 score FS (Train): 0.644314207390274
#         R2 score FS (Test): 0.627433851034668
#     Trying order: 10
#         R2 score OSA (Train): 0.9538918905191176
#         R2 score OSA (Test): 0.86403578490715
#         R2 score FS (Train): 0.616186542683884
#         R2 score FS (Test): 0.6094459931197069
#     Trying order: 11
#         R2 score OSA (Train): 0.974382710900542
#         R2 score OSA (Test): 0.873664336033039
#         R2 score FS (Train): 0.6342142067353811
#         R2 score FS (Test): 0.6228240215220355
#     Trying order: 12
#         R2 score OSA (Train): 0.9551898031145893
#         R2 score OSA (Test): 0.8606024786537255
#         R2 score FS (Train): 0.6422056267748615
#         R2 score FS (Test): 0.619488545342826
#     Trying order: 13
#         R2 score OSA (Train): 0.9749424921445066
#         R2 score OSA (Test): 0.8758364072745962
#         R2 score FS (Train): 0.6690609646133975
#         R2 score FS (Test): 0.6464552708476341
#     Trying order: 14
#         R2 score OSA (Train): 0.9597411320834424
#         R2 score OSA (Test): 0.8645984956215143
#         R2 score FS (Train): 0.6679593504714343
#         R2 score FS (Test): 0.6482597116208726
#     Trying order: 15
#         R2 score OSA (Train): 0.9780404313370729
#         R2 score OSA (Test): 0.8708426123755455
#         R2 score FS (Train): 0.677549314412165
#         R2 score FS (Test): 0.658531729144979
#     Trying order: 16
#         R2 score OSA (Train): 0.9596132389449838
#         R2 score OSA (Test): 0.8632767646638461
#         R2 score FS (Train): 0.6511097052435924
#         R2 score FS (Test): 0.6345781857854946
#     Trying order: 17
#         R2 score OSA (Train): 0.9620608860804047
#         R2 score OSA (Test): 0.8693590561192326
#         R2 score FS (Train): 0.6545912001073169
#         R2 score FS (Test): 0.6417143740231188
#     Trying order: 18
#         R2 score OSA (Train): 0.963638961561483
#         R2 score OSA (Test): 0.8643351354931197
#         R2 score FS (Train): 0.6661222856328713
#         R2 score FS (Test): 0.656128438101521
#     Trying order: 19
#         R2 score OSA (Train): 0.9637441312118847
#         R2 score OSA (Test): 0.872010497013698
#         R2 score FS (Train): 0.6625752537120928
#         R2 score FS (Test): 0.6432789919805688
#     Trying order: 20
#         R2 score OSA (Train): 0.9540420265236841
#         R2 score OSA (Test): 0.8588734294086284
#         R2 score FS (Train): 0.6627470602835936
#         R2 score FS (Test): 0.6378511035935879
#
#     Tempo de execução: 4:59:01.958738
#     Best Order: 15
#     R2 score OSA (Train): 0.9780404313370729
#     R2 score OSA (Test): 0.8708426123755455
#     R2 score FS (Train): 0.677549314412165
#     R2 score FS (Test): 0.658531729144979
#
# Starting evaluation of model: MLP
#     Trying order: 2
#         R2 score OSA (Train): 0.9001369423223728
#         R2 score OSA (Test): 0.8315408356785516
#         R2 score FS (Train): 0.49036577060626785
#         R2 score FS (Test): 0.39146463240943363
#     Trying order: 3
#         R2 score OSA (Train): 0.9385310677531065
#         R2 score OSA (Test): 0.8124166982006638
#         R2 score FS (Train): 0.13778069751109723
#         R2 score FS (Test): -0.05096130525890574
#     Trying order: 4
#         R2 score OSA (Train): 0.8787202373941105
#         R2 score OSA (Test): 0.8088608014588158
#         R2 score FS (Train): 0.4095789257112311
#         R2 score FS (Test): 0.4277430055128404
#     Trying order: 5
#         R2 score OSA (Train): 0.9585682559048738
#         R2 score OSA (Test): 0.7868232008026785
#         R2 score FS (Train): 0.5358364191130622
#         R2 score FS (Test): 0.2707517893082375
#     Trying order: 6
#         R2 score OSA (Train): 0.9432016094044648
#         R2 score OSA (Test): 0.7680093115214239
#         R2 score FS (Train): 0.10395232008460853
#         R2 score FS (Test): 0.05698764004348589
#     Trying order: 7
#         R2 score OSA (Train): 0.9274828552038599
#         R2 score OSA (Test): 0.8061936038368136
#         R2 score FS (Train): 0.525058278227054
#         R2 score FS (Test): 0.4942789693112637
#     Trying order: 8
#         R2 score OSA (Train): 0.961200862426025
#         R2 score OSA (Test): 0.7986864234480462
#         R2 score FS (Train): 0.5121735837549216
#         R2 score FS (Test): 0.318234200281841
#     Trying order: 9
#         R2 score OSA (Train): 0.9699592401624406
#         R2 score OSA (Test): 0.7888912360141502
#         R2 score FS (Train): 0.647608336872005
#         R2 score FS (Test): 0.47276426539367855
#     Trying order: 10
#         R2 score OSA (Train): 0.9554476636727953
#         R2 score OSA (Test): 0.7803957195443587
#         R2 score FS (Train): 0.4958244492264495
#         R2 score FS (Test): 0.38590239270783844
#     Trying order: 11
#         R2 score OSA (Train): 0.9685762590576956
#         R2 score OSA (Test): 0.7719529367382132
#         R2 score FS (Train): 0.356536085597013
#         R2 score FS (Test): 0.2727688574083005
#     Trying order: 12
#         R2 score OSA (Train): 0.985791887271327
#         R2 score OSA (Test): 0.7925447853005756
#         R2 score FS (Train): 0.645041212961821
#         R2 score FS (Test): 0.49607990663291723
#     Trying order: 13
#         R2 score OSA (Train): 0.9740397039701726
#         R2 score OSA (Test): 0.7804787461322957
#         R2 score FS (Train): 0.6113542035798873
#         R2 score FS (Test): 0.494398648610044
#     Trying order: 14
#         R2 score OSA (Train): 0.9619808283945974
#         R2 score OSA (Test): 0.7558502688604117
#         R2 score FS (Train): 0.5379897261882428
#         R2 score FS (Test): 0.49317449454383167
#     Trying order: 15
#         R2 score OSA (Train): 0.9846294480436445
#         R2 score OSA (Test): 0.7737100582550012
#         R2 score FS (Train): 0.4790796589763039
#         R2 score FS (Test): 0.4083069317252791
#     Trying order: 16
#         R2 score OSA (Train): 0.986206284695691
#         R2 score OSA (Test): 0.8099329207000343
#         R2 score FS (Train): 0.4829670029172701
#         R2 score FS (Test): 0.27443931686381484
#     Trying order: 17
#         R2 score OSA (Train): 0.9819081893342374
#         R2 score OSA (Test): 0.7987046052828191
#         R2 score FS (Train): 0.5769170309744331
#         R2 score FS (Test): 0.4943095866919157
#     Trying order: 18
#         R2 score OSA (Train): 0.9706812427230833
#         R2 score OSA (Test): 0.739587272318177
#         R2 score FS (Train): 0.3617433595587586
#         R2 score FS (Test): 0.07095881886759448
#     Trying order: 19
#         R2 score OSA (Train): 0.9871979537034871
#         R2 score OSA (Test): 0.7523795061533902
#         R2 score FS (Train): 0.6327522668301679
#         R2 score FS (Test): 0.49468199405788427
#     Trying order: 20
#         R2 score OSA (Train): 0.9683584333769837
#         R2 score OSA (Test): 0.6950055320206673
#         R2 score FS (Train): 0.3098998437216197
#         R2 score FS (Test): 0.10582385629321722
#
#     Tempo de execução: 9:12:52.811208
#     Best Order: 9
#     R2 score OSA (Train): 0.9699592401624406
#     R2 score OSA (Test): 0.7888912360141502
#     R2 score FS (Train): 0.647608336872005
#     R2 score FS (Test): 0.47276426539367855

# %%
pd.DataFrame(results)
# Out:
#               MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA  R2 TRAIN FS
# 0               SVM      9      0.765240     0.754455     0.500442  \
# 1               KNN     16      1.000000     0.776874     0.729580
# 2      DecisionTree     12      0.819646     0.790094     0.177435
# 3      RandomForest     17      0.906272     0.839278     0.638636
# 4  GradientBoosting     14      0.980581     0.866184     0.633018
# 5        ExtraTrees     15      0.978040     0.870843     0.677549
# 6               MLP      9      0.969959     0.788891     0.647608
#
#    R2 TEST FS                                          MODEL OBJ  PARS
# 0    0.523550  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 1    0.625058  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 2    0.160208  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 3    0.645764  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 4    0.597550  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 5    0.658532  SYSIDRegressor(estimator=MultiOutputRegressor(...  None
# 6    0.472764  SYSIDRegressor(estimator=RandomizedSearchCV(cv...  None

# %%
order_progression = pd.DataFrame(order_progression)
order_progression
# Out:
#     MODEL  ORDER  R2 TRAIN OSA  R2 TEST OSA   R2 TRAIN FS    R2 TEST FS
# 0     SVM      2      0.729008     0.723827  4.587613e-01  4.849541e-01  \
# 1     SVM      3      0.736114     0.728622  3.327491e-01  4.050512e-01
# 2     SVM      4      0.732918     0.725575 -4.005514e+07 -5.143755e+07
# 3     SVM      5      0.760205     0.753669  4.796656e-01  4.944560e-01
# 4     SVM      6      0.762333     0.752801  4.841351e-01  4.989726e-01
# ..    ...    ...           ...          ...           ...           ...
# 128   MLP     16      0.986206     0.809933  4.829670e-01  2.744393e-01
# 129   MLP     17      0.981908     0.798705  5.769170e-01  4.943096e-01
# 130   MLP     18      0.970681     0.739587  3.617434e-01  7.095882e-02
# 131   MLP     19      0.987198     0.752380  6.327523e-01  4.946820e-01
# 132   MLP     20      0.968358     0.695006  3.098998e-01  1.058239e-01
#
#                                              MODEL OBJ
# 0    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 1    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 2    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 3    SYSIDRegressor(estimator=MultiOutputRegressor(...
# 4    SYSIDRegressor(estimator=MultiOutputRegressor(...
# ..                                                 ...
# 128  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 129  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 130  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 131  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
# 132  SYSIDRegressor(estimator=RandomizedSearchCV(cv...
#
# [133 rows x 7 columns]

# %%
fig, ax = plt.subplots()
for model in np.unique(order_progression.MODEL):
    #if model == 'DT': continue
    data_filt = order_progression[order_progression.MODEL == model]
    data_filt = data_filt[data_filt['R2 TEST FS'] >= 0]
    ax.plot(data_filt.ORDER, data_filt['R2 TEST FS'], label=model)
ax.legend()

# %%
binary = os.path.join(os.getcwd(), 'outputs', 'test_runs', f'{prefix}_ml.pkl')
print(binary)

with open(binary, 'wb') as bin_file:
    pickle.dump((X1_tr, y_tr, X1_te, y_te, results, order_progression), bin_file)
# Out:
# /mnt/d/Onedrive/Mestrado/gits/sklearn-sid/Volve-Dataset/outputs/test_runs/SISO-Seasonal2.W1_ml.pkl

# %%
print(results['PARS'][-1])
# Out:
# None
